# %% [markdown]
# # Prepare some things
# ## Load some modules

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from keras.utils import to_categorical

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler
import sklearn.metrics

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../')
from models import get_autoencoder_model, get_dec_model, get_vae_model, get_clustering_vae_model, get_vade_models, compute_p, compute_delta
from clustering_metrics import evaluate_model, evaluate_clustering
from draw_embeddings import draw_embeddings, draw_clusters_assignments

# %% [markdown]
# ## Load the dataset

# %%
codebook = pd.read_csv("ExposomeChallengeData/datasets/codebook.csv", index_col=0)
phenotype = pd.read_csv("ExposomeChallengeData/datasets/phenotype.csv", index_col=0)
exposome = pd.read_csv("ExposomeChallengeData/datasets/exposome.csv", index_col=0)
covariates = pd.read_csv("ExposomeChallengeData/datasets/covariates.csv", index_col=0)

metabol_serum_exprs = pd.read_csv("ExposomeChallengeData/datasets/metabol_serum_exprs.csv", index_col=0).T
metabol_serum_pdata = pd.read_csv("ExposomeChallengeData/datasets/metabol_serum_pData.csv", index_col=0)
metabol_serum_fdata = pd.read_csv("ExposomeChallengeData/datasets/metabol_serum_fData.csv", index_col=0)

metabol_urine_exprs = pd.read_csv("ExposomeChallengeData/datasets/metabol_urine_exprs.csv", index_col=0).T
metabol_urine_pdata = pd.read_csv("ExposomeChallengeData/datasets/metabol_urine_pData.csv", index_col=0)
metabol_urine_fdata = pd.read_csv("ExposomeChallengeData/datasets/metabol_urine_fData.csv", index_col=0)

proteome_exprs = pd.read_csv("ExposomeChallengeData/datasets/proteome_exprs.csv", index_col=0).T
proteome_pdata = pd.read_csv("ExposomeChallengeData/datasets/proteome_pData.csv", index_col=0)
proteome_fdata = pd.read_csv("ExposomeChallengeData/datasets/proteome_fData.csv", index_col=0)

# %% [markdown]
# ## Join all the metabolomic data

# %%
metabol_exprs = pd.concat([metabol_serum_exprs.rename('serum_{}'.format, axis=1),
                           metabol_urine_exprs.rename('urine_{}'.format, axis=1)], axis=1)
metabol_exprs
# Out:
#       serum_metab_1  serum_metab_2  serum_metab_3  serum_metab_4  \
# 430       -2.145605      -0.714302       8.599913       0.552377
# 1187      -0.685014      -0.368663       9.154818      -1.334607
# 940       -0.685014      -0.361231       8.954196      -0.127368
# 936       -0.194295      -0.339163       8.535275      -0.618163
# 788       -1.960160      -0.346481       8.727920      -0.797112
# ...             ...            ...            ...            ...
# 680        2.359240      -0.346481       8.797662       0.065572
# 634        1.299245      -0.719044       8.661778      -1.144010
# 574       -0.739372      -0.472930       8.714246      -1.199255
# 840       -1.522841      -0.435378       8.643856      -0.154410
# 862       -2.582080      -0.591832       8.233620      -0.505328
#
#       serum_metab_5  serum_metab_6  serum_metab_7  serum_metab_8  \
# 430        7.051481       5.785289       3.747387       5.070389
# 1187       6.894211       5.806066       4.257765       5.083213
# 940        7.104861       5.859224       4.345538       5.918863
# 936        7.007308       5.950702       4.242603       5.405992
# 788        6.895424       5.950702       4.884109       5.388878
# ...             ...            ...            ...            ...
# 680        6.687201       5.912889       3.820690       5.469235
# 634        7.104861       5.881420       3.508429       5.402586
# 574        6.996050       5.390599       4.106851       5.378512
# 840        6.774128       5.499846       3.880686       5.442943
# 862        6.818263       5.470862       3.789729       5.350497
#
#       serum_metab_9  serum_metab_10  ...  urine_metab_35  urine_metab_36  \
# 430       -1.867752       -2.771027  ...        5.185867        5.057450
# 1187      -2.300448       -3.418890  ...        4.977280        7.870365
# 940       -1.965784       -3.403542  ...        4.986411        5.040016
# 936       -1.894322       -2.841663  ...        4.827819        6.697663
# 788       -1.552156       -2.454032  ...        4.754888        5.221104
# ...             ...             ...  ...             ...             ...
# 680       -1.657445       -2.666576  ...        4.419539        4.371559
# 634       -1.988504       -2.971431  ...        5.944858        4.277985
# 574       -2.171368       -3.258425  ...        4.596935        5.894818
# 840       -2.017417       -3.204233  ...        5.961160        5.705978
# 862       -1.582080       -3.139236  ...        5.395748        5.004501
#
#       urine_metab_37  urine_metab_38  urine_metab_39  urine_metab_40  \
# 430        12.117805        2.906891        4.446256        4.529821
# 1187       11.985735       -4.321928        4.990955        4.738768
# 940        12.200040       -4.321928        4.104337        4.385431
# 936        11.570899       -2.321928        4.765535        3.292782
# 788        11.679524       -0.321928        3.700440        4.781360
# ...              ...             ...             ...             ...
# 680        12.044155        4.224966        5.189825        3.837943
# 634        12.047533        3.807355        5.247928        4.343408
# 574        11.645073        3.104337        4.504620        3.536053
# 840        12.249321        2.678072        4.542258        4.070389
# 862        12.306347        4.666757        4.504620        3.827819
#
#       urine_metab_41  urine_metab_42  urine_metab_43  urine_metab_44
# 430         3.877744       -0.152003        3.087463        2.459432
# 1187       -0.321928        0.263034        2.944858        2.584963
# 940         3.817623       -4.321928        3.744161        2.981853
# 936         3.017922       -4.321928        3.990955        3.523562
# 788         3.201634       -0.321928        2.765535        2.944858
# ...              ...             ...             ...             ...
# 680         3.336283       -4.321928        2.035624        3.485427
# 634         3.419539       -4.321928        4.802193        2.827819
# 574         4.095924       -4.321928        3.786596        4.336283
# 840         3.000000        2.000000        3.776104        2.405992
# 862         4.000000       -4.321928        1.722466        3.572890
#
# [1152 rows x 221 columns]

# %%
# Standarize data (min-max method)
metabol_exprs = MinMaxScaler().fit_transform(metabol_exprs)
metabol_exprs
# Out:
# array([[0.22454216, 0.20502398, 0.49047013, ..., 0.36017712, 0.58703102,
#         0.60511422],
#        [0.40250332, 0.54948899, 0.82835403, ..., 0.39602597, 0.57265825,
#         0.61973214],
#        [0.40250332, 0.55689555, 0.70619466, ..., 0.        , 0.65321816,
#         0.66594953],
#        ...,
#        [0.39588017, 0.44557634, 0.56008773, ..., 0.        , 0.65749512,
#         0.82367136],
#        [0.30042092, 0.48300051, 0.5172274 , ..., 0.54605631, 0.65643761,
#         0.59889129],
#        [0.1713613 , 0.32707824, 0.26743285, ..., 0.        , 0.44945607,
#         0.73477508]])

# %%
# Number of data points
np.multiply(*metabol_exprs.shape)
# Out:
# 254592

# %% [markdown]
# ## Categorical data (possible groups to compare)
#
# The phenotype data has two categorical variables:
# - has asthma (2 groups)
# - bmi category (4 groups)

# %%
# Asthma groups distribution:
asthma_class = phenotype['hs_asthma']
asthma_counts = asthma_class.value_counts()
plt.bar(asthma_counts.index, asthma_counts)
# Out:
# <BarContainer object of 2 artists>

# %%
# BMI groups distribution:
bmi_class = phenotype['hs_bmi_c_cat']
bmi_counts = bmi_class.value_counts()
plt.bar(bmi_counts.index, bmi_counts)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Raw data

# %% [markdown]
# ## K-means

# %% [markdown]
# Try fitting K-means with a range of clusters. Compute the silhouette as a metric of QC. Plot the results.

# %%
MIN_K = 2
MAX_K = 10

ks = np.arange(MIN_K, MAX_K)
sils = []
for k in ks:
    kmeans = KMeans(n_clusters=k, n_init=30)
    labels = kmeans.fit_predict(metabol_exprs)
    sils.append(sklearn.metrics.silhouette_score(metabol_exprs, labels))

plt.plot(sils)
plt.xticks(np.arange(0, len(ks)), ks, rotation=90)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette');

# %% [markdown]
# The best result is achieved with K=2.
#
# Since we know our categorical data has 2 and 4 classes, let's plot the 2D t-SNE representation for K=2 and K=4.

# %%
tsne = TSNE(n_components=2, init='pca')
raw_data_tsne = tsne.fit_transform(metabol_exprs)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
for k in (2,4):
    kmeans = KMeans(n_clusters=k, n_init=30)
    labels = kmeans.fit_predict(metabol_exprs)
    draw_embeddings(raw_data_tsne, labels, alpha=1, figsize=(5,5))
    
draw_embeddings(raw_data_tsne, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
draw_embeddings(raw_data_tsne, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")

# %% [markdown]
# ## GMM

# %%
MIN_K = 2
MAX_K = 10

ks = np.arange(MIN_K, MAX_K)
sils = []
for k in ks:
    gmm = GaussianMixture(n_components=k, covariance_type='diag', n_init=10)
    labels = gmm.fit_predict(metabol_exprs)
    sils.append(sklearn.metrics.silhouette_score(metabol_exprs, labels))

plt.plot(sils)
plt.xticks(np.arange(0, len(ks)), ks, rotation=90)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette');

# %%
for k in (2,4):
    gmm = GaussianMixture(n_components=k, covariance_type='diag', n_init=10)
    labels = gmm.fit_predict(metabol_exprs)
    draw_embeddings(raw_data_tsne, labels, alpha=1, figsize=(5,5))

draw_embeddings(raw_data_tsne, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
draw_embeddings(raw_data_tsne, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")

# %% [markdown]
# # PCA

# %%
# Find the number of PCs to explain 0.8 of the variance:
pca = PCA(n_components=0.8)
pca.fit(metabol_exprs)
# Out:
# PCA(n_components=0.8)

# %%
plt.plot(np.arange(0, pca.n_components_),np.cumsum(pca.explained_variance_ratio_))
plt.axhline(y = 0.8, color='black', linestyle='-', alpha=0.5, label="0.8")
plt.xticks(np.arange(9, pca.n_components_, 10), np.arange(10, pca.n_components_+1, 10), rotation=45, rotation_mode="anchor", ha='right')
plt.xlabel('Number of PCs')
plt.ylabel('Cumlative explained variance');
plt.legend();

# %%
plt.plot(np.arange(0, pca.n_components_), pca.explained_variance_)
plt.axhline(y = np.mean(pca.explained_variance_), color='black', linestyle='-', alpha=0.5, label="mean")
# plt.axvline(x = pca.n_components_-1, color='grey', linestyle='dotted', alpha=0.5)
plt.xticks(np.arange(9, pca.n_components_, 10), np.arange(10, pca.n_components_+1, 10), rotation=45, rotation_mode="anchor", ha='right')
plt.xlabel('Number of PCs')
plt.ylabel('Explained variance');
plt.legend();

# %%
# Number of PCs:
pca.n_components_
# Out:
# 36

# %%
z_pca = pca.transform(metabol_exprs)

# %% [markdown]
# ## K-means

# %%
MIN_K = 2
MAX_K = 10

ks = np.arange(MIN_K, MAX_K)
sils = []
for k in ks:
    kmeans = KMeans(n_clusters=k, n_init=30)
    labels = kmeans.fit_predict(z_pca)
    sils.append(sklearn.metrics.silhouette_score(z_pca, labels))

plt.plot(sils)
plt.xticks(np.arange(0, len(ks)), ks, rotation=90)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette');

# %%
tsne = TSNE(n_components=2, init='pca')
z_pca_tsne = tsne.fit_transform(z_pca)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
for k in (2,4):
    kmeans = KMeans(n_clusters=k, n_init=30)
    c_pca_kmeans = kmeans.fit_predict(z_pca)
    draw_embeddings(z_pca_tsne, c_pca_kmeans, alpha=1, figsize=(5,5), legend_title="Clusters")

draw_embeddings(z_pca_tsne, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
draw_embeddings(z_pca_tsne, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")

# %% [markdown]
# ## GMM

# %%
MIN_K = 2
MAX_K = 10

ks = np.arange(MIN_K, MAX_K)
sils = []
for k in ks:
    gmm = GaussianMixture(n_components=k, covariance_type='diag', n_init=10)
    labels = gmm.fit_predict(z_pca)
    sils.append(sklearn.metrics.silhouette_score(z_pca, labels))

plt.plot(sils)
plt.xticks(np.arange(0, len(ks)), ks, rotation=90)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette');

# %%
for k in (2,4):
    gmm = GaussianMixture(n_components=k, covariance_type='diag', n_init=10)
    c_pca_gmm = gmm.fit_predict(z_pca)
    draw_embeddings(z_pca_tsne, c_pca_gmm, alpha=1, figsize=(5,5), legend_title="Clusters")

draw_embeddings(z_pca_tsne, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
draw_embeddings(z_pca_tsne, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")

# %% [markdown]
# # DEC

# %% [markdown]
# ## Build and pre-train the Autoencoder

# %%
INPUT_DIM = metabol_exprs.shape[1]  # 221
LATENT_DIM = 4
INTERMEDIATE_DIMS = (64, 32)

model_ae = get_autoencoder_model(INPUT_DIM, LATENT_DIM, INTERMEDIATE_DIMS)

# %%
# data points / model parameters ratio:
np.multiply(*metabol_exprs.shape) / (model_ae.encoder.count_params()+model_ae.decoder.count_params())
# Out:
# 7.701606316362646

# %%
EPOCHS = 100
BATCH_SIZE = 32  # 1152 observations
LEARNING_RATE = 1
MOMENTUM = 0.5

# model_ae.compile(optimizer=keras.optimizers.Adam(),
model_ae.compile(optimizer=keras.optimizers.SGD(learning_rate=LEARNING_RATE, momentum=MOMENTUM),
                 loss="mse")

model_ae.fit(metabol_exprs, metabol_exprs,
             epochs=EPOCHS,
             batch_size=BATCH_SIZE,
             verbose=2,
            )

model_ae.save_weights("model_weights/dec/pretrained/ae")

# model_ae.load_weights("model_weights/dec/pretrained/ae")
# Out:
# Epoch 1/100
# 36/36 - 0s - loss: 0.0351 - 431ms/epoch - 12ms/step
# Epoch 2/100
# 36/36 - 0s - loss: 0.0323 - 81ms/epoch - 2ms/step
# Epoch 3/100
# 36/36 - 0s - loss: 0.0267 - 70ms/epoch - 2ms/step
# Epoch 4/100
# 36/36 - 0s - loss: 0.0215 - 73ms/epoch - 2ms/step
# Epoch 5/100
# 36/36 - 0s - loss: 0.0198 - 73ms/epoch - 2ms/step
# Epoch 6/100
# 36/36 - 0s - loss: 0.0195 - 85ms/epoch - 2ms/step
# Epoch 7/100
# 36/36 - 0s - loss: 0.0193 - 79ms/epoch - 2ms/step
# Epoch 8/100
# 36/36 - 0s - loss: 0.0193 - 70ms/epoch - 2ms/step
# Epoch 9/100
# 36/36 - 0s - loss: 0.0192 - 78ms/epoch - 2ms/step
# Epoch 10/100
# 36/36 - 0s - loss: 0.0191 - 88ms/epoch - 2ms/step
# Epoch 11/100
# 36/36 - 0s - loss: 0.0190 - 94ms/epoch - 3ms/step
# Epoch 12/100
# 36/36 - 0s - loss: 0.0188 - 87ms/epoch - 2ms/step
# Epoch 13/100
# 36/36 - 0s - loss: 0.0187 - 79ms/epoch - 2ms/step
# Epoch 14/100
# 36/36 - 0s - loss: 0.0186 - 72ms/epoch - 2ms/step
# Epoch 15/100
# 36/36 - 0s - loss: 0.0184 - 72ms/epoch - 2ms/step
# Epoch 16/100
# 36/36 - 0s - loss: 0.0183 - 72ms/epoch - 2ms/step
# Epoch 17/100
# 36/36 - 0s - loss: 0.0181 - 77ms/epoch - 2ms/step
# Epoch 18/100
# 36/36 - 0s - loss: 0.0179 - 88ms/epoch - 2ms/step
# Epoch 19/100
# 36/36 - 0s - loss: 0.0176 - 72ms/epoch - 2ms/step
# Epoch 20/100
# 36/36 - 0s - loss: 0.0174 - 78ms/epoch - 2ms/step
# Epoch 21/100
# 36/36 - 0s - loss: 0.0171 - 83ms/epoch - 2ms/step
# Epoch 22/100
# 36/36 - 0s - loss: 0.0169 - 74ms/epoch - 2ms/step
# Epoch 23/100
# 36/36 - 0s - loss: 0.0166 - 76ms/epoch - 2ms/step
# Epoch 24/100
# 36/36 - 0s - loss: 0.0164 - 82ms/epoch - 2ms/step
# Epoch 25/100
# 36/36 - 0s - loss: 0.0163 - 72ms/epoch - 2ms/step
# Epoch 26/100
# 36/36 - 0s - loss: 0.0161 - 89ms/epoch - 2ms/step
# Epoch 27/100
# 36/36 - 0s - loss: 0.0160 - 99ms/epoch - 3ms/step
# Epoch 28/100
# 36/36 - 0s - loss: 0.0159 - 77ms/epoch - 2ms/step
# Epoch 29/100
# 36/36 - 0s - loss: 0.0158 - 80ms/epoch - 2ms/step
# Epoch 30/100
# 36/36 - 0s - loss: 0.0158 - 87ms/epoch - 2ms/step
# Epoch 31/100
# 36/36 - 0s - loss: 0.0157 - 88ms/epoch - 2ms/step
# Epoch 32/100
# 36/36 - 0s - loss: 0.0157 - 90ms/epoch - 3ms/step
# Epoch 33/100
# 36/36 - 0s - loss: 0.0156 - 91ms/epoch - 3ms/step
# Epoch 34/100
# 36/36 - 0s - loss: 0.0156 - 82ms/epoch - 2ms/step
# Epoch 35/100
# 36/36 - 0s - loss: 0.0156 - 93ms/epoch - 3ms/step
# Epoch 36/100
# 36/36 - 0s - loss: 0.0155 - 78ms/epoch - 2ms/step
# Epoch 37/100
# 36/36 - 0s - loss: 0.0155 - 75ms/epoch - 2ms/step
# Epoch 38/100
# 36/36 - 0s - loss: 0.0155 - 76ms/epoch - 2ms/step
# Epoch 39/100
# 36/36 - 0s - loss: 0.0155 - 83ms/epoch - 2ms/step
# Epoch 40/100
# 36/36 - 0s - loss: 0.0155 - 74ms/epoch - 2ms/step
# Epoch 41/100
# 36/36 - 0s - loss: 0.0154 - 78ms/epoch - 2ms/step
# Epoch 42/100
# 36/36 - 0s - loss: 0.0154 - 74ms/epoch - 2ms/step
# Epoch 43/100
# 36/36 - 0s - loss: 0.0154 - 73ms/epoch - 2ms/step
# Epoch 44/100
# 36/36 - 0s - loss: 0.0154 - 77ms/epoch - 2ms/step
# Epoch 45/100
# 36/36 - 0s - loss: 0.0154 - 69ms/epoch - 2ms/step
# Epoch 46/100
# 36/36 - 0s - loss: 0.0153 - 77ms/epoch - 2ms/step
# Epoch 47/100
# 36/36 - 0s - loss: 0.0153 - 71ms/epoch - 2ms/step
# Epoch 48/100
# 36/36 - 0s - loss: 0.0153 - 77ms/epoch - 2ms/step
# Epoch 49/100
# 36/36 - 0s - loss: 0.0153 - 76ms/epoch - 2ms/step
# Epoch 50/100
# 36/36 - 0s - loss: 0.0152 - 69ms/epoch - 2ms/step
# Epoch 51/100
# 36/36 - 0s - loss: 0.0152 - 85ms/epoch - 2ms/step
# Epoch 52/100
# 36/36 - 0s - loss: 0.0152 - 81ms/epoch - 2ms/step
# Epoch 53/100
# 36/36 - 0s - loss: 0.0151 - 74ms/epoch - 2ms/step
# Epoch 54/100
# 36/36 - 0s - loss: 0.0151 - 80ms/epoch - 2ms/step
# Epoch 55/100
# 36/36 - 0s - loss: 0.0151 - 71ms/epoch - 2ms/step
# Epoch 56/100
# 36/36 - 0s - loss: 0.0150 - 72ms/epoch - 2ms/step
# Epoch 57/100
# 36/36 - 0s - loss: 0.0150 - 89ms/epoch - 2ms/step
# Epoch 58/100
# 36/36 - 0s - loss: 0.0149 - 76ms/epoch - 2ms/step
# Epoch 59/100
# 36/36 - 0s - loss: 0.0149 - 74ms/epoch - 2ms/step
# Epoch 60/100
# 36/36 - 0s - loss: 0.0148 - 80ms/epoch - 2ms/step
# Epoch 61/100
# 36/36 - 0s - loss: 0.0148 - 89ms/epoch - 2ms/step
# Epoch 62/100
# 36/36 - 0s - loss: 0.0148 - 97ms/epoch - 3ms/step
# Epoch 63/100
# 36/36 - 0s - loss: 0.0147 - 85ms/epoch - 2ms/step
# Epoch 64/100
# 36/36 - 0s - loss: 0.0147 - 89ms/epoch - 2ms/step
# Epoch 65/100
# 36/36 - 0s - loss: 0.0146 - 87ms/epoch - 2ms/step
# Epoch 66/100
# 36/36 - 0s - loss: 0.0146 - 99ms/epoch - 3ms/step
# Epoch 67/100
# 36/36 - 0s - loss: 0.0146 - 94ms/epoch - 3ms/step
# Epoch 68/100
# 36/36 - 0s - loss: 0.0146 - 79ms/epoch - 2ms/step
# Epoch 69/100
# 36/36 - 0s - loss: 0.0145 - 85ms/epoch - 2ms/step
# Epoch 70/100
# 36/36 - 0s - loss: 0.0145 - 82ms/epoch - 2ms/step
# Epoch 71/100
# 36/36 - 0s - loss: 0.0145 - 71ms/epoch - 2ms/step
# Epoch 72/100
# 36/36 - 0s - loss: 0.0144 - 84ms/epoch - 2ms/step
# Epoch 73/100
# 36/36 - 0s - loss: 0.0144 - 89ms/epoch - 2ms/step
# Epoch 74/100
# 36/36 - 0s - loss: 0.0144 - 81ms/epoch - 2ms/step
# Epoch 75/100
# 36/36 - 0s - loss: 0.0144 - 125ms/epoch - 3ms/step
# Epoch 76/100
# 36/36 - 0s - loss: 0.0144 - 136ms/epoch - 4ms/step
# Epoch 77/100
# 36/36 - 0s - loss: 0.0143 - 142ms/epoch - 4ms/step
# Epoch 78/100
# 36/36 - 0s - loss: 0.0143 - 119ms/epoch - 3ms/step
# Epoch 79/100
# 36/36 - 0s - loss: 0.0143 - 132ms/epoch - 4ms/step
# Epoch 80/100
# 36/36 - 0s - loss: 0.0143 - 117ms/epoch - 3ms/step
# Epoch 81/100
# 36/36 - 0s - loss: 0.0143 - 108ms/epoch - 3ms/step
# Epoch 82/100
# 36/36 - 0s - loss: 0.0143 - 105ms/epoch - 3ms/step
# Epoch 83/100
# 36/36 - 0s - loss: 0.0143 - 86ms/epoch - 2ms/step
# Epoch 84/100
# 36/36 - 0s - loss: 0.0142 - 82ms/epoch - 2ms/step
# Epoch 85/100
# 36/36 - 0s - loss: 0.0142 - 93ms/epoch - 3ms/step
# Epoch 86/100
# 36/36 - 0s - loss: 0.0142 - 87ms/epoch - 2ms/step
# Epoch 87/100
# 36/36 - 0s - loss: 0.0142 - 86ms/epoch - 2ms/step
# Epoch 88/100
# 36/36 - 0s - loss: 0.0142 - 75ms/epoch - 2ms/step
# Epoch 89/100
# 36/36 - 0s - loss: 0.0142 - 80ms/epoch - 2ms/step
# Epoch 90/100
# 36/36 - 0s - loss: 0.0142 - 80ms/epoch - 2ms/step
# Epoch 91/100
# 36/36 - 0s - loss: 0.0142 - 94ms/epoch - 3ms/step
# Epoch 92/100
# 36/36 - 0s - loss: 0.0142 - 143ms/epoch - 4ms/step
# Epoch 93/100
# 36/36 - 0s - loss: 0.0141 - 128ms/epoch - 4ms/step
# Epoch 94/100
# 36/36 - 0s - loss: 0.0141 - 132ms/epoch - 4ms/step
# Epoch 95/100
# 36/36 - 0s - loss: 0.0141 - 118ms/epoch - 3ms/step
# Epoch 96/100
# 36/36 - 0s - loss: 0.0141 - 118ms/epoch - 3ms/step
# Epoch 97/100
# 36/36 - 0s - loss: 0.0141 - 118ms/epoch - 3ms/step
# Epoch 98/100
# 36/36 - 0s - loss: 0.0141 - 96ms/epoch - 3ms/step
# Epoch 99/100
# 36/36 - 0s - loss: 0.0141 - 103ms/epoch - 3ms/step
# Epoch 100/100
# 36/36 - 0s - loss: 0.0141 - 88ms/epoch - 2ms/step

# %%
z_ae = model_ae.encode(metabol_exprs)

if LATENT_DIM == 2:
    draw_embeddings(z_ae, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_ae, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")
else:
    tsne = TSNE(n_components=2, init='pca')
    z_dec_tsne = tsne.fit_transform(z_ae)
    draw_embeddings(z_dec_tsne, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_dec_tsne, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# ## Build and fine-tune the DEC (initialize with K-means)

# %%
model_ae.load_weights("model_weights/dec/pretrained/ae")

# %%
N_CLUSTERS = 4

model_dec = get_dec_model(model_ae.encoder, N_CLUSTERS)

# %%
z_dec = model_dec.encode(metabol_exprs)

kmeans = KMeans(n_clusters=N_CLUSTERS, n_init=30)
kmeans.fit(z_dec)

for weight in model_dec.trainable_weights:
    if weight.name == "centroids:0":
        weight.assign(K.constant(kmeans.cluster_centers_))

# %% [markdown]
# Initialize `p`, the auxiliary distribution to compute the clustering loss, and `c_last`, the last cluster assignments to compute the number of points that changed clusters.

# %%
p = compute_p(to_categorical(kmeans.labels_))
c_last = kmeans.labels_

# %%
def dec_callback(epoch, logs):
    global p
    global c_last
    
    if (epoch+1) % SCHEDULE == 0:
        q = model_dec.soft_assignment(metabol_exprs)
        p = compute_p(q)
        
        c_new = q.numpy().argmax(1)
        delta = compute_delta(c_new, c_last)
        c_last = np.copy(c_new)
        print(f"Delta: {delta:.3f}")
        if (delta < DELTA_THRESHOLD):
            model_dec.stop_training = True
            
callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=dec_callback)

# %%
EPOCHS = 100
LEARNING_RATE = 1e-4
MOMENTUM = 0.9
SCHEDULE = 10
DELTA_THRESHOLD = 0.001

model_dec.compile(optimizer=keras.optimizers.SGD(learning_rate=LEARNING_RATE, momentum=MOMENTUM))
# model_dec.compile(optimizer=keras.optimizers.Adam())

model_dec.fit(metabol_exprs, p,
              epochs=EPOCHS,
              batch_size=BATCH_SIZE,
              callbacks = callback,
              verbose=2,
             )

model_dec.save_weights("model_weights/dec/finetuned/dec")

model_dec.load_weights("model_weights/dec/finetuned/dec")
# Out:
# Epoch 1/100
# 36/36 - 0s - loss: 7.6718 - 494ms/epoch - 14ms/step
# Epoch 2/100
# 36/36 - 0s - loss: 7.6339 - 78ms/epoch - 2ms/step
# Epoch 3/100
# 36/36 - 0s - loss: 7.5967 - 81ms/epoch - 2ms/step
# Epoch 4/100
# 36/36 - 0s - loss: 7.5208 - 92ms/epoch - 3ms/step
# Epoch 5/100
# 36/36 - 0s - loss: 7.4772 - 79ms/epoch - 2ms/step
# Epoch 6/100
# 36/36 - 0s - loss: 7.4356 - 90ms/epoch - 3ms/step
# Epoch 7/100
# 36/36 - 0s - loss: 7.4078 - 93ms/epoch - 3ms/step
# Epoch 8/100
# 36/36 - 0s - loss: 7.3982 - 80ms/epoch - 2ms/step
# Epoch 9/100
# 36/36 - 0s - loss: 7.3178 - 90ms/epoch - 3ms/step
# Epoch 10/100
# Delta: 0.040
# 36/36 - 0s - loss: 7.2918 - 90ms/epoch - 2ms/step
# Epoch 11/100
# 36/36 - 0s - loss: 7.2403 - 107ms/epoch - 3ms/step
# Epoch 12/100
# 36/36 - 0s - loss: 7.2019 - 79ms/epoch - 2ms/step
# Epoch 13/100
# 36/36 - 0s - loss: 7.2270 - 80ms/epoch - 2ms/step
# Epoch 14/100
# 36/36 - 0s - loss: 7.1584 - 83ms/epoch - 2ms/step
# Epoch 15/100
# 36/36 - 0s - loss: 7.1456 - 85ms/epoch - 2ms/step
# Epoch 16/100
# 36/36 - 0s - loss: 7.1148 - 93ms/epoch - 3ms/step
# Epoch 17/100
# 36/36 - 0s - loss: 7.0740 - 95ms/epoch - 3ms/step
# Epoch 18/100
# 36/36 - 0s - loss: 7.0448 - 83ms/epoch - 2ms/step
# Epoch 19/100
# 36/36 - 0s - loss: 6.9899 - 81ms/epoch - 2ms/step
# Epoch 20/100
# Delta: 0.048
# 36/36 - 0s - loss: 6.9721 - 98ms/epoch - 3ms/step
# Epoch 21/100
# 36/36 - 0s - loss: 6.9231 - 82ms/epoch - 2ms/step
# Epoch 22/100
# 36/36 - 0s - loss: 6.9206 - 93ms/epoch - 3ms/step
# Epoch 23/100
# 36/36 - 0s - loss: 6.9057 - 89ms/epoch - 2ms/step
# Epoch 24/100
# 36/36 - 0s - loss: 6.8443 - 89ms/epoch - 2ms/step
# Epoch 25/100
# 36/36 - 0s - loss: 6.8108 - 83ms/epoch - 2ms/step
# Epoch 26/100
# 36/36 - 0s - loss: 6.8029 - 98ms/epoch - 3ms/step
# Epoch 27/100
# 36/36 - 0s - loss: 6.8004 - 91ms/epoch - 3ms/step
# Epoch 28/100
# 36/36 - 0s - loss: 6.7224 - 79ms/epoch - 2ms/step
# Epoch 29/100
# 36/36 - 0s - loss: 6.7393 - 80ms/epoch - 2ms/step
# Epoch 30/100
# Delta: 0.082
# 36/36 - 0s - loss: 6.6946 - 84ms/epoch - 2ms/step
# Epoch 31/100
# 36/36 - 0s - loss: 6.6724 - 80ms/epoch - 2ms/step
# Epoch 32/100
# 36/36 - 0s - loss: 6.6372 - 84ms/epoch - 2ms/step
# Epoch 33/100
# 36/36 - 0s - loss: 6.6265 - 89ms/epoch - 2ms/step
# Epoch 34/100
# 36/36 - 0s - loss: 6.5918 - 82ms/epoch - 2ms/step
# Epoch 35/100
# 36/36 - 0s - loss: 6.5447 - 93ms/epoch - 3ms/step
# Epoch 36/100
# 36/36 - 0s - loss: 6.5266 - 91ms/epoch - 3ms/step
# Epoch 37/100
# 36/36 - 0s - loss: 6.4884 - 78ms/epoch - 2ms/step
# Epoch 38/100
# 36/36 - 0s - loss: 6.4479 - 101ms/epoch - 3ms/step
# Epoch 39/100
# 36/36 - 0s - loss: 6.4466 - 102ms/epoch - 3ms/step
# Epoch 40/100
# Delta: 0.057
# 36/36 - 0s - loss: 6.4086 - 115ms/epoch - 3ms/step
# Epoch 41/100
# 36/36 - 0s - loss: 6.3761 - 104ms/epoch - 3ms/step
# Epoch 42/100
# 36/36 - 0s - loss: 6.3468 - 77ms/epoch - 2ms/step
# Epoch 43/100
# 36/36 - 0s - loss: 6.3363 - 80ms/epoch - 2ms/step
# Epoch 44/100
# 36/36 - 0s - loss: 6.3235 - 96ms/epoch - 3ms/step
# Epoch 45/100
# 36/36 - 0s - loss: 6.3845 - 96ms/epoch - 3ms/step
# Epoch 46/100
# 36/36 - 0s - loss: 6.2942 - 91ms/epoch - 3ms/step
# Epoch 47/100
# 36/36 - 0s - loss: 6.2593 - 95ms/epoch - 3ms/step
# Epoch 48/100
# 36/36 - 0s - loss: 6.2671 - 84ms/epoch - 2ms/step
# Epoch 49/100
# 36/36 - 0s - loss: 6.2190 - 82ms/epoch - 2ms/step
# Epoch 50/100
# Delta: 0.042
# 36/36 - 0s - loss: 6.1875 - 96ms/epoch - 3ms/step
# Epoch 51/100
# 36/36 - 0s - loss: 6.1789 - 81ms/epoch - 2ms/step
# Epoch 52/100
# 36/36 - 0s - loss: 6.1562 - 80ms/epoch - 2ms/step
# Epoch 53/100
# 36/36 - 0s - loss: 6.1180 - 86ms/epoch - 2ms/step
# Epoch 54/100
# 36/36 - 0s - loss: 6.1213 - 87ms/epoch - 2ms/step
# Epoch 55/100
# 36/36 - 0s - loss: 6.0742 - 98ms/epoch - 3ms/step
# Epoch 56/100
# 36/36 - 0s - loss: 6.0310 - 104ms/epoch - 3ms/step
# Epoch 57/100
# 36/36 - 0s - loss: 6.0125 - 84ms/epoch - 2ms/step
# Epoch 58/100
# 36/36 - 0s - loss: 6.0247 - 79ms/epoch - 2ms/step
# Epoch 59/100
# 36/36 - 0s - loss: 5.9600 - 87ms/epoch - 2ms/step
# Epoch 60/100
# Delta: 0.041
# 36/36 - 0s - loss: 5.9604 - 99ms/epoch - 3ms/step
# Epoch 61/100
# 36/36 - 0s - loss: 5.9423 - 92ms/epoch - 3ms/step
# Epoch 62/100
# 36/36 - 0s - loss: 5.9064 - 84ms/epoch - 2ms/step
# Epoch 63/100
# 36/36 - 0s - loss: 5.9017 - 84ms/epoch - 2ms/step
# Epoch 64/100
# 36/36 - 0s - loss: 5.8651 - 107ms/epoch - 3ms/step
# Epoch 65/100
# 36/36 - 0s - loss: 5.8341 - 141ms/epoch - 4ms/step
# Epoch 66/100
# 36/36 - 0s - loss: 5.8199 - 139ms/epoch - 4ms/step
# Epoch 67/100
# 36/36 - 0s - loss: 5.7984 - 132ms/epoch - 4ms/step
# Epoch 68/100
# 36/36 - 0s - loss: 5.8104 - 133ms/epoch - 4ms/step
# Epoch 69/100
# 36/36 - 0s - loss: 5.7487 - 144ms/epoch - 4ms/step
# Epoch 70/100
# Delta: 0.048
# 36/36 - 0s - loss: 5.7352 - 106ms/epoch - 3ms/step
# Epoch 71/100
# 36/36 - 0s - loss: 5.7008 - 108ms/epoch - 3ms/step
# Epoch 72/100
# 36/36 - 0s - loss: 5.7395 - 89ms/epoch - 2ms/step
# Epoch 73/100
# 36/36 - 0s - loss: 5.6957 - 76ms/epoch - 2ms/step
# Epoch 74/100
# 36/36 - 0s - loss: 5.6450 - 85ms/epoch - 2ms/step
# Epoch 75/100
# 36/36 - 0s - loss: 5.6279 - 83ms/epoch - 2ms/step
# Epoch 76/100
# 36/36 - 0s - loss: 5.6380 - 81ms/epoch - 2ms/step
# Epoch 77/100
# 36/36 - 0s - loss: 5.5776 - 76ms/epoch - 2ms/step
# Epoch 78/100
# 36/36 - 0s - loss: 5.5585 - 81ms/epoch - 2ms/step
# Epoch 79/100
# 36/36 - 0s - loss: 5.5361 - 94ms/epoch - 3ms/step
# Epoch 80/100
# Delta: 0.079
# 36/36 - 0s - loss: 5.5245 - 109ms/epoch - 3ms/step
# Epoch 81/100
# 36/36 - 0s - loss: 5.5232 - 90ms/epoch - 2ms/step
# Epoch 82/100
# 36/36 - 0s - loss: 5.5056 - 89ms/epoch - 2ms/step
# Epoch 83/100
# 36/36 - 0s - loss: 5.4653 - 80ms/epoch - 2ms/step
# Epoch 84/100
# 36/36 - 0s - loss: 5.4397 - 81ms/epoch - 2ms/step
# Epoch 85/100
# 36/36 - 0s - loss: 5.4466 - 92ms/epoch - 3ms/step
# Epoch 86/100
# 36/36 - 0s - loss: 5.3924 - 86ms/epoch - 2ms/step
# Epoch 87/100
# 36/36 - 0s - loss: 5.4103 - 84ms/epoch - 2ms/step
# Epoch 88/100
# 36/36 - 0s - loss: 5.3606 - 79ms/epoch - 2ms/step
# Epoch 89/100
# 36/36 - 0s - loss: 5.3333 - 97ms/epoch - 3ms/step
# Epoch 90/100
# Delta: 0.053
# 36/36 - 0s - loss: 5.3089 - 87ms/epoch - 2ms/step
# Epoch 91/100
# 36/36 - 0s - loss: 5.3358 - 88ms/epoch - 2ms/step
# Epoch 92/100
# 36/36 - 0s - loss: 5.2737 - 82ms/epoch - 2ms/step
# Epoch 93/100
# 36/36 - 0s - loss: 5.2677 - 87ms/epoch - 2ms/step
# Epoch 94/100
# 36/36 - 0s - loss: 5.2681 - 89ms/epoch - 2ms/step
# Epoch 95/100
# 36/36 - 0s - loss: 5.2422 - 80ms/epoch - 2ms/step
# Epoch 96/100
# 36/36 - 0s - loss: 5.2261 - 79ms/epoch - 2ms/step
# Epoch 97/100
# 36/36 - 0s - loss: 5.2362 - 86ms/epoch - 2ms/step
# Epoch 98/100
# 36/36 - 0s - loss: 5.2030 - 86ms/epoch - 2ms/step
# Epoch 99/100
# 36/36 - 0s - loss: 5.1594 - 96ms/epoch - 3ms/step
# Epoch 100/100
# Delta: 0.040
# 36/36 - 0s - loss: 5.1545 - 94ms/epoch - 3ms/step

# %%
z_dec = model_dec.encode(metabol_exprs)
c_dec = model_dec.classify(metabol_exprs)

if LATENT_DIM == 2:
    draw_embeddings(z_dec, c_dec, alpha=1, figsize=(5,5), legend_title="Clusters")
    draw_embeddings(z_dec, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_dec, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")
else:
    tsne = TSNE(n_components=2, init='pca')
    z_dec_tsne = tsne.fit_transform(z_dec)
    draw_embeddings(z_dec_tsne, c_dec, alpha=1, figsize=(5,5), legend_title="Clusters")
    draw_embeddings(z_dec_tsne, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_dec_tsne, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# # VaDE

# %% [markdown]
# ## Build and pre-train the Autoencoder

# %%
INPUT_DIM = metabol_exprs.shape[1]  # 221
LATENT_DIM = 4

EPOCHS = 20

model_pretrain, model_vade = get_vade_models(N_CLUSTERS, INPUT_DIM, LATENT_DIM, INTERMEDIATE_DIMS)

LEARNING_RATE = 1
MOMENTUM = 0.9
model_pretrain.compile(optimizer=keras.optimizers.SGD(learning_rate=LEARNING_RATE, momentum=MOMENTUM),
                       loss=keras.losses.BinaryCrossentropy())

model_pretrain.fit(metabol_exprs, metabol_exprs,
                   epochs=EPOCHS,
                   batch_size=BATCH_SIZE,
                   verbose=2,
                  )

model_pretrain.save_weights("model_weights/vade/pretrained/ae")

model_pretrain.load_weights("model_weights/vade/pretrained/ae")
# Out:
# Epoch 1/20
# WARNING:tensorflow:Gradients do not exist for variables ['z_logvar/kernel:0', 'z_logvar/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['z_logvar/kernel:0', 'z_logvar/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 36/36 - 1s - loss: 0.6769 - 580ms/epoch - 16ms/step
# Epoch 2/20
# 36/36 - 0s - loss: 0.6582 - 82ms/epoch - 2ms/step
# Epoch 3/20
# 36/36 - 0s - loss: 0.6567 - 74ms/epoch - 2ms/step
# Epoch 4/20
# 36/36 - 0s - loss: 0.6543 - 105ms/epoch - 3ms/step
# Epoch 5/20
# 36/36 - 0s - loss: 0.6512 - 139ms/epoch - 4ms/step
# Epoch 6/20
# 36/36 - 0s - loss: 0.6505 - 155ms/epoch - 4ms/step
# Epoch 7/20
# 36/36 - 0s - loss: 0.6502 - 123ms/epoch - 3ms/step
# Epoch 8/20
# 36/36 - 0s - loss: 0.6501 - 130ms/epoch - 4ms/step
# Epoch 9/20
# 36/36 - 0s - loss: 0.6499 - 129ms/epoch - 4ms/step
# Epoch 10/20
# 36/36 - 0s - loss: 0.6496 - 116ms/epoch - 3ms/step
# Epoch 11/20
# 36/36 - 0s - loss: 0.6490 - 112ms/epoch - 3ms/step
# Epoch 12/20
# 36/36 - 0s - loss: 0.6480 - 125ms/epoch - 3ms/step
# Epoch 13/20
# 36/36 - 0s - loss: 0.6473 - 123ms/epoch - 3ms/step
# Epoch 14/20
# 36/36 - 0s - loss: 0.6465 - 124ms/epoch - 3ms/step
# Epoch 15/20
# 36/36 - 0s - loss: 0.6456 - 131ms/epoch - 4ms/step
# Epoch 16/20
# 36/36 - 0s - loss: 0.6451 - 131ms/epoch - 4ms/step
# Epoch 17/20
# 36/36 - 0s - loss: 0.6446 - 110ms/epoch - 3ms/step
# Epoch 18/20
# 36/36 - 0s - loss: 0.6444 - 118ms/epoch - 3ms/step
# Epoch 19/20
# 36/36 - 0s - loss: 0.6443 - 110ms/epoch - 3ms/step
# Epoch 20/20
# 36/36 - 0s - loss: 0.6441 - 88ms/epoch - 2ms/step

# %%
z_pretrain = model_pretrain.encode(metabol_exprs)

if LATENT_DIM == 2:
    draw_embeddings(z_pretrain, phenotype['hs_asthma'], alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_pretrain, phenotype['hs_bmi_c_cat'], alpha=1, figsize=(5,5), legend_title="BMI")
else:
    tsne = TSNE(n_components=2, init='pca')
    z_vade_tsne = tsne.fit_transform(z_pretrain)
    draw_embeddings(z_vade_tsne, phenotype['hs_asthma'], alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_vade_tsne, phenotype['hs_bmi_c_cat'], alpha=1, figsize=(5,5), legend_title="BMI")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
model_pretrain.load_weights("model_weights/vade/pretrained/ae")

# %%
z_vade = model_vade.encode_only_mu(metabol_exprs)

gmm = GaussianMixture(n_components=N_CLUSTERS, covariance_type='diag', n_init=30)
gmm.fit(z_vade)

for weight in model_vade.trainable_weights:
    if weight.name == "pi:0":
        weight.assign(K.log(K.constant(gmm.weights_)))
    elif weight.name == "mu:0":
        weight.assign(K.constant(gmm.means_))
    elif weight.name == "logvar:0":
        weight.assign(K.log(K.constant(gmm.covariances_)))

# %%
def scheduler(epoch, lr):
    if (epoch+1) % SCHEDULE == 0:
        lr = lr * 0.9
    return lr

callback = [tf.keras.callbacks.LearningRateScheduler(scheduler),]

# %%
EPOCHS = 50
SCHEDULE = 10

LEARNING_RATE = 1e-5
MOMENTUM = 0.9
model_vade.compile(optimizer=keras.optimizers.SGD(learning_rate=LEARNING_RATE, momentum=MOMENTUM))

model_vade.fit(metabol_exprs,
               epochs=EPOCHS,
               batch_size=BATCH_SIZE,
               callbacks = callback,
               verbose=2,
              )

model_vade.save_weights("model_weights/vade/finetuned/vade")

model_vade.load_weights("model_weights/vade/finetuned/vade")
# Out:
# Epoch 1/50
# 36/36 - 1s - loss: 150.1828 - lr: 1.0000e-05 - 1s/epoch - 35ms/step
# Epoch 2/50
# 36/36 - 0s - loss: 148.5939 - lr: 1.0000e-05 - 130ms/epoch - 4ms/step
# Epoch 3/50
# 36/36 - 0s - loss: 147.8408 - lr: 1.0000e-05 - 128ms/epoch - 4ms/step
# Epoch 4/50
# 36/36 - 0s - loss: 147.3818 - lr: 1.0000e-05 - 135ms/epoch - 4ms/step
# Epoch 5/50
# 36/36 - 0s - loss: 147.0757 - lr: 1.0000e-05 - 148ms/epoch - 4ms/step
# Epoch 6/50
# 36/36 - 0s - loss: 146.8423 - lr: 1.0000e-05 - 123ms/epoch - 3ms/step
# Epoch 7/50
# 36/36 - 0s - loss: 146.7045 - lr: 1.0000e-05 - 126ms/epoch - 4ms/step
# Epoch 8/50
# 36/36 - 0s - loss: 146.5608 - lr: 1.0000e-05 - 127ms/epoch - 4ms/step
# Epoch 9/50
# 36/36 - 0s - loss: 146.5414 - lr: 1.0000e-05 - 136ms/epoch - 4ms/step
# Epoch 10/50
# 36/36 - 0s - loss: 146.4294 - lr: 9.0000e-06 - 114ms/epoch - 3ms/step
# Epoch 11/50
# 36/36 - 0s - loss: 146.4229 - lr: 9.0000e-06 - 120ms/epoch - 3ms/step
# Epoch 12/50
# 36/36 - 0s - loss: 146.3175 - lr: 9.0000e-06 - 158ms/epoch - 4ms/step
# Epoch 13/50
# 36/36 - 0s - loss: 146.3330 - lr: 9.0000e-06 - 168ms/epoch - 5ms/step
# Epoch 14/50
# 36/36 - 0s - loss: 146.3070 - lr: 9.0000e-06 - 142ms/epoch - 4ms/step
# Epoch 15/50
# 36/36 - 0s - loss: 146.3058 - lr: 9.0000e-06 - 122ms/epoch - 3ms/step
# Epoch 16/50
# 36/36 - 0s - loss: 146.2687 - lr: 9.0000e-06 - 147ms/epoch - 4ms/step
# Epoch 17/50
# 36/36 - 0s - loss: 146.2270 - lr: 9.0000e-06 - 120ms/epoch - 3ms/step
# Epoch 18/50
# 36/36 - 0s - loss: 146.2028 - lr: 9.0000e-06 - 142ms/epoch - 4ms/step
# Epoch 19/50
# 36/36 - 0s - loss: 146.1877 - lr: 9.0000e-06 - 113ms/epoch - 3ms/step
# Epoch 20/50
# 36/36 - 0s - loss: 146.1719 - lr: 8.1000e-06 - 138ms/epoch - 4ms/step
# Epoch 21/50
# 36/36 - 0s - loss: 146.1854 - lr: 8.1000e-06 - 113ms/epoch - 3ms/step
# Epoch 22/50
# 36/36 - 0s - loss: 146.1641 - lr: 8.1000e-06 - 126ms/epoch - 4ms/step
# Epoch 23/50
# 36/36 - 0s - loss: 146.1346 - lr: 8.1000e-06 - 117ms/epoch - 3ms/step
# Epoch 24/50
# 36/36 - 0s - loss: 146.1176 - lr: 8.1000e-06 - 144ms/epoch - 4ms/step
# Epoch 25/50
# 36/36 - 0s - loss: 146.0671 - lr: 8.1000e-06 - 116ms/epoch - 3ms/step
# Epoch 26/50
# 36/36 - 0s - loss: 146.1537 - lr: 8.1000e-06 - 119ms/epoch - 3ms/step
# Epoch 27/50
# 36/36 - 0s - loss: 146.1167 - lr: 8.1000e-06 - 125ms/epoch - 3ms/step
# Epoch 28/50
# 36/36 - 0s - loss: 146.1277 - lr: 8.1000e-06 - 118ms/epoch - 3ms/step
# Epoch 29/50
# 36/36 - 0s - loss: 146.1654 - lr: 8.1000e-06 - 117ms/epoch - 3ms/step
# Epoch 30/50
# 36/36 - 0s - loss: 146.0790 - lr: 7.2900e-06 - 116ms/epoch - 3ms/step
# Epoch 31/50
# 36/36 - 0s - loss: 146.0550 - lr: 7.2900e-06 - 111ms/epoch - 3ms/step
# Epoch 32/50
# 36/36 - 0s - loss: 146.0456 - lr: 7.2900e-06 - 135ms/epoch - 4ms/step
# Epoch 33/50
# 36/36 - 0s - loss: 146.0598 - lr: 7.2900e-06 - 127ms/epoch - 4ms/step
# Epoch 34/50
# 36/36 - 0s - loss: 146.0877 - lr: 7.2900e-06 - 118ms/epoch - 3ms/step
# Epoch 35/50
# 36/36 - 0s - loss: 146.0283 - lr: 7.2900e-06 - 105ms/epoch - 3ms/step
# Epoch 36/50
# 36/36 - 0s - loss: 146.0945 - lr: 7.2900e-06 - 123ms/epoch - 3ms/step
# Epoch 37/50
# 36/36 - 0s - loss: 146.0461 - lr: 7.2900e-06 - 140ms/epoch - 4ms/step
# Epoch 38/50
# 36/36 - 0s - loss: 146.0798 - lr: 7.2900e-06 - 136ms/epoch - 4ms/step
# Epoch 39/50
# 36/36 - 0s - loss: 146.0323 - lr: 7.2900e-06 - 183ms/epoch - 5ms/step
# Epoch 40/50
# 36/36 - 0s - loss: 146.0383 - lr: 6.5610e-06 - 200ms/epoch - 6ms/step
# Epoch 41/50
# 36/36 - 0s - loss: 146.0039 - lr: 6.5610e-06 - 185ms/epoch - 5ms/step
# Epoch 42/50
# 36/36 - 0s - loss: 145.9839 - lr: 6.5610e-06 - 169ms/epoch - 5ms/step
# Epoch 43/50
# 36/36 - 0s - loss: 146.0722 - lr: 6.5610e-06 - 186ms/epoch - 5ms/step
# Epoch 44/50
# 36/36 - 0s - loss: 146.0233 - lr: 6.5610e-06 - 183ms/epoch - 5ms/step
# Epoch 45/50
# 36/36 - 0s - loss: 145.9875 - lr: 6.5610e-06 - 226ms/epoch - 6ms/step
# Epoch 46/50
# 36/36 - 0s - loss: 145.9917 - lr: 6.5610e-06 - 193ms/epoch - 5ms/step
# Epoch 47/50
# 36/36 - 0s - loss: 146.0121 - lr: 6.5610e-06 - 173ms/epoch - 5ms/step
# Epoch 48/50
# 36/36 - 0s - loss: 145.9879 - lr: 6.5610e-06 - 183ms/epoch - 5ms/step
# Epoch 49/50
# 36/36 - 0s - loss: 145.9775 - lr: 6.5610e-06 - 146ms/epoch - 4ms/step
# Epoch 50/50
# 36/36 - 0s - loss: 146.0009 - lr: 5.9049e-06 - 143ms/epoch - 4ms/step

# %%
z_vade = model_vade.encode_only_mu(metabol_exprs)
c_vade = model_vade.classify(metabol_exprs)

if LATENT_DIM == 2:
    draw_embeddings(z_vade, c_vade, alpha=1, figsize=(5,5), legend_title="Clusters")
    draw_embeddings(z_vade, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_vade, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")
else:
    tsne = TSNE(n_components=2, init='pca')
    z_vade_tsne = tsne.fit_transform(z_vade)
    draw_embeddings(z_vade_tsne, c_vade, alpha=1, figsize=(5,5), legend_title="Clusters")
    draw_embeddings(z_vade_tsne, asthma_class, alpha=1, figsize=(5,5), legend_title="Asthma")
    draw_embeddings(z_vade_tsne, bmi_class, alpha=1, figsize=(5,5), legend_title="BMI")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# # Compare the cluster assignments

# %% [markdown]
# ## DEC vs VaDE

# %%
# Compare the DEC cluster assignments over the VaDE embeddings
draw_clusters_assignments(z_vade_tsne, c_vade, c_dec, figsize=(10,5), alpha=0.7)

# %%
# Compare the VaDE cluster assignments over the DEC embeddings
draw_clusters_assignments(z_dec_tsne, c_dec, c_vade, figsize=(10,5), alpha=0.7)

# %%
evaluate_clustering(z_vade_tsne, c_vade, c_dec)
# Out:
# {'Acc': 0.7317708333333334,
#  'ARI': 0.42201612617018097,
#  'AMI': 0.4174464755681572,
#  'Sil': 0.15244614}

# %% [markdown]
# ## DEC vs PCA (K-means)

# %%
# Compare the PCA cluster assignments over the DEC embeddings
draw_clusters_assignments(z_dec_tsne, c_dec, c_pca_kmeans, figsize=(10,5), alpha=0.7)

# %%
evaluate_clustering(z_dec_tsne, c_dec, c_pca_kmeans)
# Out:
# {'Acc': 0.6085069444444444,
#  'ARI': 0.31248399166023666,
#  'AMI': 0.3305326861436916,
#  'Sil': 0.09937288}

# %% [markdown]
# ## VaDE vs PCA (K-means)

# %%
# Compare the PCA cluster assignments over the VaDE embeddings
draw_clusters_assignments(z_vade_tsne, c_vade, c_pca_kmeans, figsize=(10,5), alpha=0.7)

# %%
evaluate_clustering(z_vade_tsne, c_vade, c_pca_kmeans)
# Out:
# {'Acc': 0.7013888888888888,
#  'ARI': 0.41645520254769924,
#  'AMI': 0.39176457670249926,
#  'Sil': 0.16839042}

# %% [markdown]
# ## VaDE vs PCA (GMM)

# %%
# Compare the PCA cluster assignments over the VaDE embeddings
draw_clusters_assignments(z_vade_tsne, c_vade, c_pca_gmm, figsize=(10,5), alpha=0.7)

# %%
evaluate_clustering(z_vade_tsne, c_vade, c_pca_gmm)
# Out:
# {'Acc': 0.3220486111111111,
#  'ARI': 0.010732652910217359,
#  'AMI': 0.015963789310703046,
#  'Sil': -0.037580416}

# %% [markdown]
# # Discussion

# %% [markdown]
# The found clusters don't seem to explain the categorical groups of the phenotype we explored.
# But there is some agreement between the clusters found with the different methods (except GMM over PCA),
# especially between the two deep clustering models.
#
# Maybe we should study another biological interpretation.
