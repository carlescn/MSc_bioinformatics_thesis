# %% [markdown]
# # Prepare some things
# ## Load some modules

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from keras.utils import to_categorical

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler
import sklearn.metrics
from scipy.cluster import hierarchy

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../../')
from models import get_autoencoder_model, get_dec_model, get_vade_models, compute_p, compute_delta
from clustering_metrics import evaluate_clustering
from draw_embeddings import draw_multiple_labels

# %%
# Disable warnings output (TSNE outputs one very time)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the metabolomic data
# (alrady min-max normalized)

# %%
metabol_exprs = pd.read_csv("../ExposomeChallengeData/datasets/metabol_joint_corrected_minmax.csv", index_col=0)
metabol_exprs.head()
# Out:
#       serum_metab_1  serum_metab_2  serum_metab_3  serum_metab_4  \
# 430        0.255805       0.174073       0.455424       0.705842
# 1187       0.458543       0.503276       0.792203       0.350036
# 940        0.458543       0.510355       0.670443       0.577670
# 936        0.526658       0.531374       0.416194       0.485127
# 788        0.281546       0.524403       0.533113       0.451385
#
#       serum_metab_5  serum_metab_6  serum_metab_7  serum_metab_8  \
# 430        0.547657       0.513281       0.186493       0.374962
# 1187       0.455832       0.522648       0.310826       0.382502
# 940        0.578823       0.546612       0.332209       0.873855
# 936        0.521865       0.587852       0.307132       0.572293
# 788        0.456540       0.587852       0.463410       0.562230
#
#       serum_metab_9  serum_metab_10  ...  urine_metab_35  urine_metab_36  \
# 430        0.388030        0.441135  ...        0.485589        0.633808
# 1187       0.223065        0.236941  ...        0.463725        0.819370
# 940        0.350655        0.241779  ...        0.464682        0.632658
# 936        0.377900        0.418872  ...        0.448059        0.742009
# 788        0.508351        0.541046  ...        0.440414        0.644604
#
#       urine_metab_37  urine_metab_38  urine_metab_39  urine_metab_40  \
# 430         0.524837        0.827418        0.477779        0.720212
# 1187        0.480870        0.556330        0.603638        0.746636
# 940         0.552213        0.556330        0.398774        0.701953
# 936         0.342770        0.631332        0.551552        0.563774
# 788         0.378931        0.706334        0.305448        0.752022
#
#       urine_metab_41  urine_metab_42  urine_metab_43  urine_metab_44
# 430         0.837306        0.473094        0.623872        0.600398
# 1187        0.499879        0.515667        0.609734        0.618659
# 940         0.832476        0.045359        0.688976        0.676394
# 936         0.768223        0.045359        0.713443        0.755196
# 788         0.782983        0.455664        0.591956        0.671013
#
# [5 rows x 221 columns]

# %%
metabol_exprs = metabol_exprs.to_numpy()

# %%
print("Shape of the data set:", metabol_exprs.shape)
print("Number of data points:", np.multiply(*metabol_exprs.shape))
# Out:
# Shape of the data set: (1152, 221)
# Number of data points: 254592

# %% [markdown]
# ## Load the categorical variables
# (subset of phenotype and covariates data, already codified)

# %%
phenotype_cat = pd.read_csv("../ExposomeChallengeData/datasets/phenotype_cat.csv", index_col=0)
covariates_cat = pd.read_csv("../ExposomeChallengeData/datasets/covariates_cat.csv", index_col=0)
classes = pd.concat([phenotype_cat, covariates_cat], axis=1)
classes.head()
# Out:
#    birth_weight  iq  behaviour  asthma  bmi  cohort  age  sex  education  \
# 1             3   0          3       0    1       3    1    0          1
# 2             3   1          3       0    1       3    2    0          2
# 3             3   0          3       1    3       3    1    0          2
# 4             1   2          3       0    1       1    4    1          0
# 5             3   0          1       0    1       2    4    0          0
#
#    native  parity
# 1       2       0
# 2       2       1
# 3       2       1
# 4       2       1
# 5       2       0

# %%
print("Number of class variables:", classes.shape[1])
# Out:
# Number of class variables: 11

# %% [markdown]
# # Deep clustering models

# %%
categorical_variables = {2: ["asthma", "sex"],
                         3: ["education", "native", "parity"],
                         4: ["birth_weight", "iq", "behaviour", "bmi"],
                         6: ["cohort"],
                         7: ["age"]}

true_labels = {}
for k, variables in categorical_variables.items():
    true_labels[k] = {var: classes.loc[:,var] for var in variables}

cluster_labels = []
results = []

# %% [markdown]
# ## DEC

# %%
INPUT_DIM = metabol_exprs.shape[1]  # 221
INTERMEDIATE_DIMS = (64, 32)

EPOCHS_PRETRAIN = 100
LEARNING_RATE_PRETRAIN = 1
MOMENTUM_PRETRAIN = 0.5

EPOCHS_FINETUNE = 100
LEARNING_RATE_FINETUNE = 1e-4
MOMENTUM_FINETUNE = 0.9

BATCH_SIZE = 32
SCHEDULE = 10
DELTA_THRESHOLD = 0.001

# %%
def dec_callback(epoch, logs):
    global p
    global c_last
    
    if (epoch+1) % SCHEDULE == 0:
        q = model_dec.soft_assignment(metabol_exprs)
        p = compute_p(q)
        
        c_new = q.numpy().argmax(1)
        delta = compute_delta(c_new, c_last)
        c_last = np.copy(c_new)
        # print(f"Delta: {delta:.3f}")
        if (delta < DELTA_THRESHOLD):
            model_dec.stop_training = True
            
callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=dec_callback)

# %%
rl_method = "DEC"
clust_method = "K-Means"
data = metabol_exprs

for k, variables in categorical_variables.items():
    LATENT_DIM = k
    N_CLUSTERS = k
    
    # Construct and pretrain AE
    print(f"K={k} - Pretraining AE", end=" ")
    model_ae = get_autoencoder_model(INPUT_DIM, LATENT_DIM, INTERMEDIATE_DIMS)
    optimizer = keras.optimizers.SGD(learning_rate=LEARNING_RATE_PRETRAIN,
                                     momentum=MOMENTUM_PRETRAIN)
    loss = "mse"
    model_ae.compile(optimizer=optimizer, loss=loss)
    history = model_ae.fit(data, data,
                           epochs=EPOCHS_PRETRAIN,
                           batch_size=BATCH_SIZE,
                           verbose=0)
    print(f"[loss: {history.history['loss'][-1]:.4f}]", end=" ")
    
    # Construct DEC
    print("- Fine-tunning DEC", end=" ")
    model_dec = get_dec_model(model_ae.encoder, N_CLUSTERS)
    
    # Initialize parameters
    z_dec = model_dec.encode(data)
    kmeans = KMeans(n_clusters=N_CLUSTERS, n_init=30)
    kmeans.fit(z_dec)
    for weight in model_dec.trainable_weights:
        if weight.name == "centroids:0":
            weight.assign(K.constant(kmeans.cluster_centers_))

    p = compute_p(to_categorical(kmeans.labels_))
    c_last = kmeans.labels_

    # Fine-tune the model
    optimizer = keras.optimizers.SGD(learning_rate=LEARNING_RATE_FINETUNE, 
                                     momentum=MOMENTUM_FINETUNE)
    model_dec.compile(optimizer=optimizer)
    history = model_dec.fit(data, p,
                            epochs=EPOCHS_FINETUNE,
                            batch_size=BATCH_SIZE,
                            callbacks = callback,
                            verbose=0)
    print(f"[loss: {history.history['loss'][-1]:.4f}]")
    
    # Compute the cluster assignments
    c_dec = model_dec.classify(data)
    cluster_labels.append({"rl_method": rl_method, 
                           "clust_method": clust_method, 
                           "n_clusters": k, 
                           "labels": c_dec})
    
    # Compute metrics
    z_dec = model_dec.encode(data)
    for variable, labels in true_labels[k].items():
        metrics = evaluate_clustering(z_dec, labels, c_dec, False)
        print(variable, [f'{metric}: {value:.3f}' for metric, value in metrics.items()])
        result = {"rl_method": rl_method, 
                  "clust_method": clust_method, 
                  "n_clusters": k, 
                  "variable": variable}
        result.update(metrics)
        results.append(result)
    
    # Draw the embeddings
    tsne = TSNE(n_components=2, init='pca')
    z_dec_tsne = tsne.fit_transform(z_dec)

    labels = true_labels[k].copy()
    labels.update({rl_method: c_dec})
    draw_multiple_labels(z_dec_tsne, labels)
# Out:
# K=2 - Pretraining AE [loss: 0.0146] - Fine-tunning DEC [loss: 1.4216]
# asthma ['Acc: 0.893', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.691']
# sex ['Acc: 0.530', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.691']
# K=3 - Pretraining AE [loss: 0.0147] - Fine-tunning DEC [loss: 4.2581]
# education ['Acc: 0.513', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.426']
# native ['Acc: 0.838', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.426']
# parity ['Acc: 0.455', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.426']
# K=4 - Pretraining AE [loss: 0.0147] - Fine-tunning DEC [loss: 4.9590]
# birth_weight ['Acc: 0.268', 'ARI: -0.001', 'AMI: -0.001', 'Sil: 0.444']
# iq ['Acc: 0.299', 'ARI: 0.002', 'AMI: 0.002', 'Sil: 0.444']
# behaviour ['Acc: 0.277', 'ARI: 0.002', 'AMI: 0.002', 'Sil: 0.444']
# bmi ['Acc: 0.694', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.444']
# K=6 - Pretraining AE [loss: 0.0145] - Fine-tunning DEC [loss: 6.0378]
# cohort ['Acc: 0.208', 'ARI: 0.003', 'AMI: 0.001', 'Sil: 0.611']
# K=7 - Pretraining AE [loss: 0.0128] - Fine-tunning DEC [loss: 7.8415]
# age ['Acc: 0.319', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.317']

# %% [markdown]
# ## VaDE

# %%
INPUT_DIM = metabol_exprs.shape[1]  # 221
INTERMEDIATE_DIMS = (64, 32)

EPOCHS_PRETRAIN = 20
LEARNING_RATE_PRETRAIN = 1
MOMENTUM_PRETRAIN = 0.9

EPOCHS_FINETUNE = 50
LEARNING_RATE_FINETUNE = 1e-5
MOMENTUM_FINETUNE = 0.9

BATCH_SIZE = 32
SCHEDULE = 10

# %%
def scheduler(epoch, lr):
    if (epoch+1) % SCHEDULE == 0:
        lr = lr * 0.9
    return lr

callback = [tf.keras.callbacks.LearningRateScheduler(scheduler),]

# %%
rl_method = "VaDE"
clust_method = "GMM"
data = metabol_exprs

for k, variables in categorical_variables.items():
    LATENT_DIM = k
    N_CLUSTERS = k
    
    # Construct and train the VaDE model.
    # If loss == NaN: retry.
    while True:
        # Construct models and pretrain AE
        print(f"K={k} - Pretraining AE", end=" ")
        model_pretrain, model_vade = get_vade_models(N_CLUSTERS, INPUT_DIM, LATENT_DIM, INTERMEDIATE_DIMS)
        optimizer = keras.optimizers.SGD(learning_rate=LEARNING_RATE_PRETRAIN,
                                         momentum=MOMENTUM_PRETRAIN)
        loss = keras.losses.BinaryCrossentropy()
        model_pretrain.compile(optimizer=optimizer, loss=loss)
        history = model_pretrain.fit(data,
                                     epochs=EPOCHS_PRETRAIN,
                                     batch_size=BATCH_SIZE,
                                     verbose=0)
        print(f"[loss: {history.history['loss'][-1]:.4f}]", end=" ")

        # Initialize parameters
        z_vade = model_vade.encode_only_mu(data)
        gmm = GaussianMixture(n_components=N_CLUSTERS, covariance_type='diag', n_init=30)
        gmm.fit(z_vade)
        for weight in model_vade.trainable_weights:
            if weight.name == "pi:0":
                weight.assign(K.log(K.constant(gmm.weights_)))
            elif weight.name == "mu:0":
                weight.assign(K.constant(gmm.means_))
            elif weight.name == "logvar:0":
                weight.assign(K.log(K.constant(gmm.covariances_)))

        # Fine-tune the model
        print("- Fine-tunning VaDE", end=" ")
        optimizer = keras.optimizers.SGD(learning_rate=LEARNING_RATE_FINETUNE,
                                         momentum=MOMENTUM_FINETUNE)
        model_vade.compile(optimizer=optimizer)
        history = model_vade.fit(data,
                                 epochs=EPOCHS_FINETUNE,
                                 batch_size=BATCH_SIZE,
                                 callbacks = callback,
                                 verbose=0)
        #If loss == NaN: retry.
        if np.isnan(history.history['loss'][-1]):
            print("[Got NaN as loss. Retrying.]")
            continue
        else:
            print(f"[loss: {history.history['loss'][-1]:.4f}]")
            break

    # Compute the cluster assignments
    c_vade = model_vade.classify(data).numpy()
    cluster_labels.append({"rl_method": rl_method, 
                           "clust_method": clust_method, 
                           "n_clusters": k, 
                           "labels": c_vade})
    
    # Compute metrics
    z_vade = model_vade.encode_only_mu(data)
    for variable, labels in true_labels[k].items():
        metrics = evaluate_clustering(z_vade, labels, c_vade, False)
        print(variable, [f'{metric}: {value:.3f}' for metric, value in metrics.items()])
        result = {"rl_method": rl_method, 
                  "clust_method": clust_method, 
                  "n_clusters": k, 
                  "variable": variable}
        result.update(metrics)
        results.append(result)
    
    # Draw the embeddings
    tsne = TSNE(n_components=2, init='pca')
    z_vade_tsne = tsne.fit_transform(z_vade)

    labels = true_labels[k].copy()
    labels.update({rl_method: c_vade})
    draw_multiple_labels(z_vade_tsne, labels)
# Out:
# K=2 - Pretraining AE [loss: 0.6506] - Fine-tunning VaDE [loss: 145.8802]
# asthma ['Acc: 0.893', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.355']
# sex ['Acc: 0.530', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.355']
# K=3 - Pretraining AE [loss: 0.6490] - Fine-tunning VaDE [loss: 146.3293]
# education ['Acc: 0.513', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.244']
# native ['Acc: 0.838', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.244']
# parity ['Acc: 0.455', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.244']
# K=4 - Pretraining AE [loss: 0.6479] - Fine-tunning VaDE [loss: 146.7373]
# birth_weight ['Acc: 0.267', 'ARI: -0.001', 'AMI: -0.001', 'Sil: 0.177']
# iq ['Acc: 0.296', 'ARI: 0.002', 'AMI: -0.000', 'Sil: 0.177']
# behaviour ['Acc: 0.271', 'ARI: -0.001', 'AMI: -0.001', 'Sil: 0.177']
# bmi ['Acc: 0.694', 'ARI: 0.000', 'AMI: 0.000', 'Sil: 0.177']
# K=6 - Pretraining AE [loss: 0.6465] - Fine-tunning VaDE [Got NaN as loss. Retrying.]
# K=6 - Pretraining AE [loss: 0.6477] - Fine-tunning VaDE [loss: 147.9512]
# cohort ['Acc: 0.201', 'ARI: -0.000', 'AMI: -0.001', 'Sil: 0.162']
# K=7 - Pretraining AE [loss: 0.6466] - Fine-tunning VaDE [Got NaN as loss. Retrying.]
# K=7 - Pretraining AE [loss: 0.6452] - Fine-tunning VaDE [loss: 148.1818]
# age ['Acc: 0.324', 'ARI: 0.005', 'AMI: 0.001', 'Sil: 0.110']

# %% [markdown]
# # Results

# %% [markdown]
# ## Metrics

# %%
results = pd.DataFrame(results)
# Save the metrics on a CSV file
results.to_csv("results/metrics_deepclust_mpl.csv", index=False)

results_mean = results.set_index(["rl_method","clust_method"]).groupby(level=[0,1]).mean()
results_mean = results_mean.iloc[:,1:]
results_mean.style.background_gradient(axis=0, cmap="cividis", text_color_threshold=0.3, subset=['Acc','ARI','AMI','Sil']).format('{:.2f}', subset=['Acc','ARI','AMI','Sil'])
# Out:
# <style type="text/css">
# #T_ddca6_row0_col0, #T_ddca6_row0_col1, #T_ddca6_row0_col2, #T_ddca6_row0_col3 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_ddca6_row1_col0, #T_ddca6_row1_col1, #T_ddca6_row1_col2, #T_ddca6_row1_col3 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ddca6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddca6_level0_col0" class="col_heading level0 col0" >Acc</th>
#       <th id="T_ddca6_level0_col1" class="col_heading level0 col1" >ARI</th>
#       <th id="T_ddca6_level0_col2" class="col_heading level0 col2" >AMI</th>
#       <th id="T_ddca6_level0_col3" class="col_heading level0 col3" >Sil</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rl_method</th>
#       <th class="index_name level1" >clust_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddca6_level0_row0" class="row_heading level0 row0" >DEC</th>
#       <th id="T_ddca6_level1_row0" class="row_heading level1 row0" >K-Means</th>
#       <td id="T_ddca6_row0_col0" class="data row0 col0" >0.48</td>
#       <td id="T_ddca6_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_ddca6_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_ddca6_row0_col3" class="data row0 col3" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_ddca6_level0_row1" class="row_heading level0 row1" >VaDE</th>
#       <th id="T_ddca6_level1_row1" class="row_heading level1 row1" >GMM</th>
#       <td id="T_ddca6_row1_col0" class="data row1 col0" >0.48</td>
#       <td id="T_ddca6_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_ddca6_row1_col2" class="data row1 col2" >-0.00</td>
#       <td id="T_ddca6_row1_col3" class="data row1 col3" >0.22</td>
#     </tr>
#   </tbody>
# </table>

# %%
results.style.background_gradient(axis=0, cmap="cividis", text_color_threshold=0.3, subset=['Acc','ARI','AMI','Sil']).format('{:.2f}', subset=['Acc','ARI','AMI','Sil'])
# Out:
# <style type="text/css">
# #T_6c448_row0_col4, #T_6c448_row0_col7, #T_6c448_row1_col7, #T_6c448_row7_col6, #T_6c448_row11_col4, #T_6c448_row21_col5 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_6c448_row0_col5, #T_6c448_row1_col5, #T_6c448_row2_col5, #T_6c448_row3_col5, #T_6c448_row4_col5, #T_6c448_row8_col5, #T_6c448_row10_col5, #T_6c448_row11_col5, #T_6c448_row12_col5, #T_6c448_row13_col5, #T_6c448_row14_col5, #T_6c448_row15_col5, #T_6c448_row17_col4, #T_6c448_row19_col5 {
#   background-color: #203a6f;
#   color: #f1f1f1;
# }
# #T_6c448_row0_col6, #T_6c448_row1_col6, #T_6c448_row2_col6, #T_6c448_row3_col6, #T_6c448_row4_col6, #T_6c448_row8_col6, #T_6c448_row10_col6, #T_6c448_row11_col6, #T_6c448_row12_col6, #T_6c448_row13_col6, #T_6c448_row14_col6, #T_6c448_row15_col6, #T_6c448_row19_col6 {
#   background-color: #656870;
#   color: #f1f1f1;
# }
# #T_6c448_row1_col4, #T_6c448_row12_col4 {
#   background-color: #777776;
#   color: #f1f1f1;
# }
# #T_6c448_row2_col4, #T_6c448_row13_col4 {
#   background-color: #727274;
#   color: #f1f1f1;
# }
# #T_6c448_row2_col7, #T_6c448_row3_col7, #T_6c448_row4_col7 {
#   background-color: #878478;
#   color: #f1f1f1;
# }
# #T_6c448_row3_col4, #T_6c448_row14_col4 {
#   background-color: #ead34c;
#   color: #000000;
# }
# #T_6c448_row4_col4, #T_6c448_row15_col4 {
#   background-color: #5e636f;
#   color: #f1f1f1;
# }
# #T_6c448_row5_col4, #T_6c448_row16_col4 {
#   background-color: #053371;
#   color: #f1f1f1;
# }
# #T_6c448_row5_col5 {
#   background-color: #002758;
#   color: #f1f1f1;
# }
# #T_6c448_row5_col6 {
#   background-color: #1c396f;
#   color: #f1f1f1;
# }
# #T_6c448_row5_col7, #T_6c448_row6_col7, #T_6c448_row7_col7, #T_6c448_row8_col7 {
#   background-color: #8f8a78;
#   color: #f1f1f1;
# }
# #T_6c448_row6_col4 {
#   background-color: #213b6e;
#   color: #f1f1f1;
# }
# #T_6c448_row6_col5 {
#   background-color: #727374;
#   color: #f1f1f1;
# }
# #T_6c448_row6_col6 {
#   background-color: #d6c35d;
#   color: #000000;
# }
# #T_6c448_row7_col4 {
#   background-color: #0f3570;
#   color: #f1f1f1;
# }
# #T_6c448_row7_col5 {
#   background-color: #7e7c78;
#   color: #f1f1f1;
# }
# #T_6c448_row8_col4, #T_6c448_row19_col4 {
#   background-color: #b1a570;
#   color: #000000;
# }
# #T_6c448_row9_col4 {
#   background-color: #002451;
#   color: #f1f1f1;
# }
# #T_6c448_row9_col5 {
#   background-color: #918b78;
#   color: #f1f1f1;
# }
# #T_6c448_row9_col6 {
#   background-color: #898578;
#   color: #f1f1f1;
# }
# #T_6c448_row9_col7 {
#   background-color: #dac65b;
#   color: #000000;
# }
# #T_6c448_row10_col4 {
#   background-color: #2b406d;
#   color: #f1f1f1;
# }
# #T_6c448_row10_col7 {
#   background-color: #5d616e;
#   color: #f1f1f1;
# }
# #T_6c448_row11_col7, #T_6c448_row12_col7 {
#   background-color: #6b6d72;
#   color: #f1f1f1;
# }
# #T_6c448_row13_col7, #T_6c448_row14_col7, #T_6c448_row15_col7 {
#   background-color: #3e4b6c;
#   color: #f1f1f1;
# }
# #T_6c448_row16_col5 {
#   background-color: #002554;
#   color: #f1f1f1;
# }
# #T_6c448_row16_col6 {
#   background-color: #414d6c;
#   color: #f1f1f1;
# }
# #T_6c448_row16_col7, #T_6c448_row17_col7, #T_6c448_row18_col7, #T_6c448_row19_col7 {
#   background-color: #143670;
#   color: #f1f1f1;
# }
# #T_6c448_row17_col5 {
#   background-color: #636670;
#   color: #f1f1f1;
# }
# #T_6c448_row17_col6 {
#   background-color: #62656f;
#   color: #f1f1f1;
# }
# #T_6c448_row18_col4 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_6c448_row18_col5, #T_6c448_row18_col6, #T_6c448_row20_col4, #T_6c448_row21_col7 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_6c448_row20_col5 {
#   background-color: #002e6a;
#   color: #f1f1f1;
# }
# #T_6c448_row20_col6 {
#   background-color: #123570;
#   color: #f1f1f1;
# }
# #T_6c448_row20_col7 {
#   background-color: #003171;
#   color: #f1f1f1;
# }
# #T_6c448_row21_col4 {
#   background-color: #2e416d;
#   color: #f1f1f1;
# }
# #T_6c448_row21_col6 {
#   background-color: #baac6d;
#   color: #000000;
# }
# </style>
# <table id="T_6c448">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c448_level0_col0" class="col_heading level0 col0" >rl_method</th>
#       <th id="T_6c448_level0_col1" class="col_heading level0 col1" >clust_method</th>
#       <th id="T_6c448_level0_col2" class="col_heading level0 col2" >n_clusters</th>
#       <th id="T_6c448_level0_col3" class="col_heading level0 col3" >variable</th>
#       <th id="T_6c448_level0_col4" class="col_heading level0 col4" >Acc</th>
#       <th id="T_6c448_level0_col5" class="col_heading level0 col5" >ARI</th>
#       <th id="T_6c448_level0_col6" class="col_heading level0 col6" >AMI</th>
#       <th id="T_6c448_level0_col7" class="col_heading level0 col7" >Sil</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c448_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c448_row0_col0" class="data row0 col0" >DEC</td>
#       <td id="T_6c448_row0_col1" class="data row0 col1" >K-Means</td>
#       <td id="T_6c448_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_6c448_row0_col3" class="data row0 col3" >asthma</td>
#       <td id="T_6c448_row0_col4" class="data row0 col4" >0.89</td>
#       <td id="T_6c448_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_6c448_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_6c448_row0_col7" class="data row0 col7" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_6c448_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c448_row1_col0" class="data row1 col0" >DEC</td>
#       <td id="T_6c448_row1_col1" class="data row1 col1" >K-Means</td>
#       <td id="T_6c448_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_6c448_row1_col3" class="data row1 col3" >sex</td>
#       <td id="T_6c448_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_6c448_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_6c448_row1_col6" class="data row1 col6" >0.00</td>
#       <td id="T_6c448_row1_col7" class="data row1 col7" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_6c448_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c448_row2_col0" class="data row2 col0" >DEC</td>
#       <td id="T_6c448_row2_col1" class="data row2 col1" >K-Means</td>
#       <td id="T_6c448_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_6c448_row2_col3" class="data row2 col3" >education</td>
#       <td id="T_6c448_row2_col4" class="data row2 col4" >0.51</td>
#       <td id="T_6c448_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_6c448_row2_col6" class="data row2 col6" >0.00</td>
#       <td id="T_6c448_row2_col7" class="data row2 col7" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_6c448_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c448_row3_col0" class="data row3 col0" >DEC</td>
#       <td id="T_6c448_row3_col1" class="data row3 col1" >K-Means</td>
#       <td id="T_6c448_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_6c448_row3_col3" class="data row3 col3" >native</td>
#       <td id="T_6c448_row3_col4" class="data row3 col4" >0.84</td>
#       <td id="T_6c448_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_6c448_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_6c448_row3_col7" class="data row3 col7" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_6c448_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c448_row4_col0" class="data row4 col0" >DEC</td>
#       <td id="T_6c448_row4_col1" class="data row4 col1" >K-Means</td>
#       <td id="T_6c448_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_6c448_row4_col3" class="data row4 col3" >parity</td>
#       <td id="T_6c448_row4_col4" class="data row4 col4" >0.45</td>
#       <td id="T_6c448_row4_col5" class="data row4 col5" >0.00</td>
#       <td id="T_6c448_row4_col6" class="data row4 col6" >0.00</td>
#       <td id="T_6c448_row4_col7" class="data row4 col7" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_6c448_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6c448_row5_col0" class="data row5 col0" >DEC</td>
#       <td id="T_6c448_row5_col1" class="data row5 col1" >K-Means</td>
#       <td id="T_6c448_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_6c448_row5_col3" class="data row5 col3" >birth

# %% [markdown]
# There is no match between any of the clusters found and the categorical data. The high accuracy values on the variables "asthma" and "native" are due to there being a groups which contains the majority of the observations, so a random assignment would also get a high accuracy.

# %% [markdown]
# ## Compare assignments

# %%
labels = pd.DataFrame([d['labels'] for d in cluster_labels])
methods = pd.DataFrame(cluster_labels).loc[:,('rl_method', 'clust_method', 'n_clusters')]
cluster_labels_df = pd.concat((methods, labels), axis=1)

# Save the assignments on a CSV file
pd.DataFrame(cluster_labels_df).to_csv("results/assign_deepclust_mpl.csv", index=False)

# %%
cluster_labels = pd.DataFrame(cluster_labels)
for k in categorical_variables.keys():
    clusters = cluster_labels[cluster_labels.n_clusters==k]
    labels = {clusters.rl_method[i]: clusters.labels[i] for i in clusters.index}
    draw_multiple_labels(z_vade_tsne, labels, max_cols=6)
    metrics = evaluate_clustering(z_vade_tsne, labels["DEC"], labels["VaDE"], False)
    print(f'DEC vs VaDE           - K={k}', [f'{metric}: {value:.3f}' for metric, value in metrics.items()])
# Out:
# DEC vs VaDE           - K=2 ['Acc: 0.873', 'ARI: 0.557', 'AMI: 0.445', 'Sil: 0.296']
# DEC vs VaDE           - K=3 ['Acc: 0.588', 'ARI: 0.275', 'AMI: 0.276', 'Sil: 0.118']
# DEC vs VaDE           - K=4 ['Acc: 0.483', 'ARI: 0.178', 'AMI: 0.229', 'Sil: 0.058']
# DEC vs VaDE           - K=6 ['Acc: 0.405', 'ARI: 0.128', 'AMI: 0.229', 'Sil: 0.049']
# DEC vs VaDE           - K=7 ['Acc: 0.500', 'ARI: 0.239', 'AMI: 0.382', 'Sil: 0.041']

# %% [markdown]
# There seems to be some agreement between both methods, specially for K=2 and K=3.
