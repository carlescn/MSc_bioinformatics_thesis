# %% [markdown]
# # Load some modules and the data

# %%
# import numpy as np
# import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load all the metrics

results_metabol_uncorrected_classic = pd.read_csv("cluster_metabolome_uncorrected/results/metrics_classic.csv")
results_metabol_uncorrected_classic["Dataset"] = "Metabolome"
results_metabol_uncorrected_classic["Method"] = "Classic"

results_metabol_uncorrected_classic_featsel = pd.read_csv("cluster_metabolome_uncorrected/results/metrics_classic_featsel.csv")
results_metabol_uncorrected_classic_featsel["Dataset"] = "Metabolome"
results_metabol_uncorrected_classic_featsel["Method"] = "Classic (fet. sel.)"

results_metabol_uncorrected_deepclust_mpl = pd.read_csv("cluster_metabolome_uncorrected/results/metrics_deepclust_mpl.csv")
results_metabol_uncorrected_deepclust_mpl["Dataset"] = "Metabolome"
results_metabol_uncorrected_deepclust_mpl["Method"] = "Deep clustering"

results_metabol_uncorrected_deepclust_mpl_featsel = pd.read_csv("cluster_metabolome_uncorrected/results/metrics_deepclust_mpl_featsel.csv")
results_metabol_uncorrected_deepclust_mpl_featsel["Dataset"] = "Metabolome"
results_metabol_uncorrected_deepclust_mpl_featsel["Method"] = "Deep clustering (fet. sel.)"

results_metabol_uncorrected_deepclust_conv = pd.read_csv("cluster_metabolome_uncorrected/results/metrics_deepclust_conv.csv")
results_metabol_uncorrected_deepclust_conv["Dataset"] = "Metabolome"
results_metabol_uncorrected_deepclust_conv["Method"] = "Deep clustering (convolutional AE)"


results_metabol_corrected_classic = pd.read_csv("cluster_metabolome_corrected/results/metrics_classic.csv")
results_metabol_corrected_classic["Dataset"] = "Metabolome (corrected)"
results_metabol_corrected_classic["Method"] = "Classic"

results_metabol_corrected_deepclust = pd.read_csv("cluster_metabolome_corrected/results/metrics_deepclust_mpl.csv")
results_metabol_corrected_deepclust["Dataset"] = "Metabolome (corrected)"
results_metabol_corrected_deepclust["Method"] = "Deep clustering"


results_exposome_uncorrected_classic = pd.read_csv("cluster_exposome_uncorrected/results/metrics_classic.csv")
results_exposome_uncorrected_classic["Dataset"] = "Exposome"
results_exposome_uncorrected_classic["Method"] = "Classic"

results_exposome_uncorrected_deepclust = pd.read_csv("cluster_exposome_uncorrected/results/metrics_deepclust.csv")
results_exposome_uncorrected_deepclust["Dataset"] = "Exposome"
results_exposome_uncorrected_deepclust["Method"] = "Deep clustering"


results_exposome_corrected_classic = pd.read_csv("cluster_exposome_corrected/results/metrics_classic.csv")
results_exposome_corrected_classic["Dataset"] = "Exposome (corrected)"
results_exposome_corrected_classic["Method"] = "Classic"

results_exposome_corrected_deepclust = pd.read_csv("cluster_exposome_corrected/results/metrics_deepclust.csv")
results_exposome_corrected_deepclust["Dataset"] = "Exposome (corrected)"
results_exposome_corrected_deepclust["Method"] = "Deep clustering"

results = pd.concat((results_metabol_uncorrected_classic,
                     results_metabol_uncorrected_classic_featsel,
                     results_metabol_uncorrected_deepclust_mpl,
                     results_metabol_uncorrected_deepclust_mpl_featsel,
                     results_metabol_uncorrected_deepclust_conv,
                     results_metabol_corrected_classic,
                     results_metabol_corrected_deepclust,
                     results_exposome_uncorrected_classic,
                     results_exposome_uncorrected_deepclust,
                     results_exposome_corrected_classic,
                     results_exposome_corrected_deepclust), axis=0)

results = results[['Dataset', 'Method', 'rl_method', 'clust_method', 'n_clusters', 'variable', 'Acc', 'ARI', 'AMI', 'Sil']]
results.columns = ('Dataset', 'Method', 'FL method', 'CL method', 'num clusters', 'variable', 'Acc.', 'ARI.', 'AMI.', 'Sil.')

# %% [markdown]
# # Summary of the results

# %% [markdown]
# ## Breif discussion

# %% [markdown]
# For each data set (expsome and metabolome),
# I evaluated some classic clustering methods (K-means, GMM, agglomerative)
# over the raw data and the PCA learned features.
# Also, I evaluated some deep learning methods (DEC, VaDE).
#
# The same methods where evaluated for both datasets
# after correcting for the suspected batch effect.
#
# Only in the metabolomics (uncorrected) data,
# I also tried applying a data augmentation technique before the deep clustering methods,
# and modifying both deep clustering models with convolutional layers (1D and 2D) instead of MPL layers.
#
# Here I show a summary of the results (mean for each combination of methods).
# The full results for each method can be found at the end of its corresponing notebook.
# Next, I show the top results for each metric.
#
# It is evident that for the external validation metrics
# (Accuracy, Adjusted Rand Index, Adjusted Mutual Information),
# the best clustering quality is achieved with number of clusters of 6,
# where all the methods almost perfectly matched the cohort classes.
# This is the reason I suspected the presence of the batch effect.
#
# For the internal validation metric (Silhouette),
# the DEC model consistently achieves the best results,
# specially with a small number of clusters.
# But the found clusters do not seem to have a biological interpretation.

# %% [markdown]
# ## Summary of the metrics

# %%
results_mean = results.set_index(['Dataset', 'Method', 'FL method', 'CL method']).groupby(level=[0,1,2,3]).mean()
results_mean = results_mean.iloc[:,1:]
results_mean.style.background_gradient(axis=0, cmap="cividis", text_color_threshold=0.3, subset=['Acc.','ARI.','AMI.','Sil.']).format('{:.2f}', subset=['Acc.','ARI.','AMI.','Sil.'])
# Out:
# <style type="text/css">
# #T_76f4d_row0_col0, #T_76f4d_row5_col2 {
#   background-color: #f7de3e;
#   color: #000000;
# }
# #T_76f4d_row0_col1, #T_76f4d_row3_col2 {
#   background-color: #fce236;
#   color: #000000;
# }
# #T_76f4d_row0_col2, #T_76f4d_row2_col1, #T_76f4d_row3_col0 {
#   background-color: #f8df3c;
#   color: #000000;
# }
# #T_76f4d_row0_col3, #T_76f4d_row2_col3, #T_76f4d_row32_col0, #T_76f4d_row34_col0, #T_76f4d_row36_col0 {
#   background-color: #273e6e;
#   color: #f1f1f1;
# }
# #T_76f4d_row1_col0 {
#   background-color: #f2da44;
#   color: #000000;
# }
# #T_76f4d_row1_col1, #T_76f4d_row2_col2 {
#   background-color: #f6dd3f;
#   color: #000000;
# }
# #T_76f4d_row1_col2 {
#   background-color: #f5dc41;
#   color: #000000;
# }
# #T_76f4d_row1_col3 {
#   background-color: #213b6e;
#   color: #f1f1f1;
# }
# #T_76f4d_row2_col0 {
#   background-color: #edd54a;
#   color: #000000;
# }
# #T_76f4d_row3_col1, #T_76f4d_row6_col3 {
#   background-color: #fee434;
#   color: #000000;
# }
# #T_76f4d_row3_col3 {
#   background-color: #1a386f;
#   color: #f1f1f1;
# }
# #T_76f4d_row4_col0 {
#   background-color: #ead34c;
#   color: #000000;
# }
# #T_76f4d_row4_col1, #T_76f4d_row4_col2, #T_76f4d_row7_col0, #T_76f4d_row28_col3 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_76f4d_row4_col3 {
#   background-color: #143670;
#   color: #f1f1f1;
# }
# #T_76f4d_row5_col0 {
#   background-color: #eed649;
#   color: #000000;
# }
# #T_76f4d_row5_col1 {
#   background-color: #f9e03a;
#   color: #000000;
# }
# #T_76f4d_row5_col3 {
#   background-color: #18376f;
#   color: #f1f1f1;
# }
# #T_76f4d_row6_col0 {
#   background-color: #fde334;
#   color: #000000;
# }
# #T_76f4d_row6_col1 {
#   background-color: #dcc859;
#   color: #000000;
# }
# #T_76f4d_row6_col2 {
#   background-color: #d3c05f;
#   color: #000000;
# }
# #T_76f4d_row7_col1 {
#   background-color: #d0be62;
#   color: #000000;
# }
# #T_76f4d_row7_col2 {
#   background-color: #d2c060;
#   color: #000000;
# }
# #T_76f4d_row7_col3 {
#   background-color: #9b9476;
#   color: #f1f1f1;
# }
# #T_76f4d_row8_col0, #T_76f4d_row10_col3 {
#   background-color: #00295d;
#   color: #f1f1f1;
# }
# #T_76f4d_row8_col1, #T_76f4d_row9_col0, #T_76f4d_row14_col2, #T_76f4d_row15_col0, #T_76f4d_row18_col1, #T_76f4d_row21_col1, #T_76f4d_row22_col2, #T_76f4d_row23_col1, #T_76f4d_row27_col1, #T_76f4d_row29_col2, #T_76f4d_row30_col1, #T_76f4d_row33_col1, #T_76f4d_row33_col2, #T_76f4d_row37_col1, #T_76f4d_row37_col2 {
#   background-color: #00234f;
#   color: #f1f1f1;
# }
# #T_76f4d_row8_col2, #T_76f4d_row11_col1, #T_76f4d_row11_col2, #T_76f4d_row14_col1, #T_76f4d_row29_col1, #T_76f4d_row41_col0, #T_76f4d_row42_col0 {
#   background-color: #002451;
#   color: #f1f1f1;
# }
# #T_76f4d_row8_col3, #T_76f4d_row18_col0, #T_76f4d_row19_col0, #T_76f4d_row26_col0, #T_76f4d_row39_col3 {
#   background-color: #002758;
#   color: #f1f1f1;
# }
# #T_76f4d_row9_col1, #T_76f4d_row9_col2, #T_76f4d_row12_col3, #T_76f4d_row15_col1, #T_76f4d_row15_col2, #T_76f4d_row16_col1, #T_76f4d_row16_col2, #T_76f4d_row17_col1, #T_76f4d_row17_col2, #T_76f4d_row18_col2, #T_76f4d_row19_col1, #T_76f4d_row19_col2, #T_76f4d_row20_col1, #T_76f4d_row20_col2, #T_76f4d_row21_col2, #T_76f4d_row22_col1, #T_76f4d_row23_col2, #T_76f4d_row24_col1, #T_76f4d_row24_col2, #T_76f4d_row25_col1, #T_76f4d_row25_col2, #T_76f4d_row26_col1, #T_76f4d_row26_col2, #T_76f4d_row27_col2, #T_76f4d_row28_col1, #T_76f4d_row28_col2, #T_76f4d_row30_col2, #T_76f4d_row31_col1, #T_76f4d_row31_col2, #T_76f4d_row32_col1, #T_76f4d_row32_col2, #T_76f4d_row34_col1, #T_76f4d_row34_col2, #T_76f4d_row35_col1, #T_76f4d_row35_col2, #T_76f4d_row36_col1, #T_76f4d_row36_col2, #T_76f4d_row38_col1, #T_76f4d_row38_col2, #T_76f4d_row39_col0, #T_76f4d_row39_col1, #T_76f4d_row39_col2, #T_76f4d_row40_col1, #T_76f4d_row40_col2, #T_76f4d_row41_col1, #T_76f4d_row41_col2, #T_76f4d_row42_col1, #T_76f4d_row42_col2, #T_76f4d_row43_col1, #T_76f4d_row43_col2, #T_76f4d_row44_col1, #T_76f4d_row44_col2, #T_76f4d_row45_col1, #T_76f4d_row45_col2 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_76f4d_row9_col3, #T_76f4d_row11_col3, #T_76f4d_row22_col0, #T_76f4d_row23_col0, #T_76f4d_row25_col0, #T_76f4d_row38_col0 {
#   background-color: #002656;
#   color: #f1f1f1;
# }
# #T_76f4d_row10_col0, #T_76f4d_row13_col0, #T_76f4d_row18_col3 {
#   background-color: #002e6a;
#   color: #f1f1f1;
# }
# #T_76f4d_row10_col1, #T_76f4d_row10_col2, #T_76f4d_row13_col2, #T_76f4d_row16_col0, #T_76f4d_row16_col3, #T_76f4d_row40_col0, #T_76f4d_row43_col0 {
#   background-color: #002554;
#   color: #f1f1f1;
# }
# #T_76f4d_row11_col0 {
#   background-color: #002b62;
#   color: #f1f1f1;
# }
# #T_76f4d_row12_col0 {
#   background-color: #3b496c;
#   color: #f1f1f1;
# }
# #T_76f4d_row12_col1, #T_76f4d_row31_col0, #T_76f4d_row44_col0 {
#   background-color: #293f6e;
#   color: #f1f1f1;
# }
# #T_76f4d_row12_col2 {
#   background-color: #33446d;
#   color: #f1f1f1;
# }
# #T_76f4d_row13_col1, #T_76f4d_row17_col0, #T_76f4d_row20_col0, #T_76f4d_row24_col0 {
#   background-color: #002553;
#   color: #f1f1f1;
# }
# #T_76f4d_row13_col3 {
#   background-color: #002859;
#   color: #f1f1f1;
# }
# #T_76f4d_row14_col0 {
#   background-color: #34456c;
#   color: #f1f1f1;
# }
# #T_76f4d_row14_col3 {
#   background-color: #c0b16a;
#   color: #000000;
# }
# #T_76f4d_row15_col3, #T_76f4d_row19_col3 {
#   background-color: #00306f;
#   color: #f1f1f1;
# }
# #T_76f4d_row17_col3 {
#   background-color: #0f3570;
#   color: #f1f1f1;
# }
# #T_76f4d_row20_col3, #T_76f4d_row21_col3, #T_76f4d_row38_col3, #T_76f4d_row42_col3 {
#   background-color: #003170;
#   color: #f1f1f1;
# }
# #T_76f4d_row21_col0 {
#   background-color: #00285b;
#   color: #f1f1f1;
# }
# #T_76f4d_row22_col3 {
#   background-color: #002c66;
#   color: #f1f1f1;
# }
# #T_76f4d_row23_col3 {
#   background-color: #0c3470;
#   color: #f1f1f1;
# }
# #T_76f4d_row24_col3 {
#   background-color: #002f6d;
#   color: #f1f1f1;
# }
# #T_76f4d_row25_col3 {
#   background-color: #002d68;
#   color: #f1f1f1;
# }
# #T_76f4d_row26_col3 {
#   background-color: #013271;
#   color: #f1f1f1;
# }
# #T_76f4d_row27_col0 {
#   background-color: #2e416d;
#   color: #f1f1f1;
# }
# #T_76f4d_row27_col3 {
#   background-color: #9e9676;
#   color: #000000;
# }
# #T_76f4d_row28_col0, #T_76f4d_row30_col0, #T_76f4d_row35_col0 {
#   background-color: #2a3f6d;
#   color: #f1f1f1;
# }
# #T_76f4d_row29_col0 {
#   background-color: #32436d;
#   color: #f1f1f1;
# }
# #T_76f4d_row29_col3 {
#   background-color: #3d4a6c;
#   color: #f1f1f1;
# }
# #T_76f4d_row30_col3, #T_76f4d_row33_col3 {
#   background-color: #3e4b6c;
#   color: #f1f1f1;
# }
# #T_76f4d_row31_col3 {
#   background-color: #7f7e78;
#   color: #f1f1f1;
# }
# #T_76f4d_row32_col3 {
#   background-color: #828079;
#   color: #f1f1f1;
# }
# #T_76f4d_row33_col0 {
#   background-color: #31436d;
#   color: #f1f1f1;
# }
# #T_76f4d_row34_col3 {
#   background-color: #989277;
#   color: #f1f1f1;
# }
# #T_76f4d_row35_col3 {
#   background-color: #e9d34e;
#   color: #000000;
# }
# #T_76f4d_row36_col3 {
#   background-color: #4e566c;
#   color: #f1f1f1;
# }
# #T_76f4d_row37_col0, #T_76f4d_row45_col0 {
#   background-color: #2b406d;
#   color: #f1f1f1;
# }
# #T_76f4d_row37_col3, #T_76f4d_row45_col3 {
#   background-color: #46516c;
#   color: #f1f1f1;
# }
# #T_76f4d_row40_col3 {
#   background-color: #123570;
#   color: #f1f1f1;
# }
# #T_76f4d_row41_col3 {
#   background-color: #002e6c;
#   color: #f1f1f1;
# }
# #T_76f4d_row43_col3 {
#   background-color: #003171;
#   color: #f1f1f1;
# }
# #T_76f4d_row44_col3 {
#   background-color: #a59c74;
#   color: #000000;
# }
# </style>
# <table id="T_76f4d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76f4d_level0_col0" class="col_heading level0 col0" >Acc.</th>
#       <th id="T_76f4d_level0_col1" class="col_heading level0 col1" >ARI.</th>
#       <th id="T_76f4d_level0_col2" class="col_heading level0 col2" >AMI.</th>
#       <th id="T_76f4d_level0_col3" class="col_heading level0 col3" >Sil.</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Method</th>
#       <th class="index_name level2" >FL method</th>
#       <th class="index_name level3" >CL method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >

# %%
# Markdown-like table:
# !pip install tabulate
# from tabulate import tabulate
# print(tabulate(results_mean.reset_index().round(2), headers='keys', tablefmt='pipe', showindex=False))

# %% [markdown]
# ## Top results for Accuracy:

# %%
results.sort_values(by="Acc.", ascending=False).head(10).style.format('{:.2f}', subset=['Acc.','ARI.','AMI.','Sil.'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_55352">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55352_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_55352_level0_col1" class="col_heading level0 col1" >Method</th>
#       <th id="T_55352_level0_col2" class="col_heading level0 col2" >FL method</th>
#       <th id="T_55352_level0_col3" class="col_heading level0 col3" >CL method</th>
#       <th id="T_55352_level0_col4" class="col_heading level0 col4" >num clusters</th>
#       <th id="T_55352_level0_col5" class="col_heading level0 col5" >variable</th>
#       <th id="T_55352_level0_col6" class="col_heading level0 col6" >Acc.</th>
#       <th id="T_55352_level0_col7" class="col_heading level0 col7" >ARI.</th>
#       <th id="T_55352_level0_col8" class="col_heading level0 col8" >AMI.</th>
#       <th id="T_55352_level0_col9" class="col_heading level0 col9" >Sil.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55352_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_55352_row0_col0" class="data row0 col0" >Exposome</td>
#       <td id="T_55352_row0_col1" class="data row0 col1" >Classic</td>
#       <td id="T_55352_row0_col2" class="data row0 col2" >Raw data</td>
#       <td id="T_55352_row0_col3" class="data row0 col3" >Agglo.</td>
#       <td id="T_55352_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_55352_row0_col5" class="data row0 col5" >cohort</td>
#       <td id="T_55352_row0_col6" class="data row0 col6" >0.99</td>
#       <td id="T_55352_row0_col7" class="data row0 col7" >0.98</td>
#       <td id="T_55352_row0_col8" class="data row0 col8" >0.97</td>
#       <td id="T_55352_row0_col9" class="data row0 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_55352_row1_col0" class="data row1 col0" >Exposome</td>
#       <td id="T_55352_row1_col1" class="data row1 col1" >Classic</td>
#       <td id="T_55352_row1_col2" class="data row1 col2" >Raw data</td>
#       <td id="T_55352_row1_col3" class="data row1 col3" >K-Means</td>
#       <td id="T_55352_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_55352_row1_col5" class="data row1 col5" >cohort</td>
#       <td id="T_55352_row1_col6" class="data row1 col6" >0.99</td>
#       <td id="T_55352_row1_col7" class="data row1 col7" >0.98</td>
#       <td id="T_55352_row1_col8" class="data row1 col8" >0.97</td>
#       <td id="T_55352_row1_col9" class="data row1 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row2" class="row_heading level0 row2" >38</th>
#       <td id="T_55352_row2_col0" class="data row2 col0" >Exposome</td>
#       <td id="T_55352_row2_col1" class="data row2 col1" >Classic</td>
#       <td id="T_55352_row2_col2" class="data row2 col2" >PCA</td>
#       <td id="T_55352_row2_col3" class="data row2 col3" >K-Means</td>
#       <td id="T_55352_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_55352_row2_col5" class="data row2 col5" >cohort</td>
#       <td id="T_55352_row2_col6" class="data row2 col6" >0.99</td>
#       <td id="T_55352_row2_col7" class="data row2 col7" >0.98</td>
#       <td id="T_55352_row2_col8" class="data row2 col8" >0.97</td>
#       <td id="T_55352_row2_col9" class="data row2 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_55352_row3_col0" class="data row3 col0" >Exposome</td>
#       <td id="T_55352_row3_col1" class="data row3 col1" >Classic</td>
#       <td id="T_55352_row3_col2" class="data row3 col2" >PCA</td>
#       <td id="T_55352_row3_col3" class="data row3 col3" >GMM</td>
#       <td id="T_55352_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_55352_row3_col5" class="data row3 col5" >cohort</td>
#       <td id="T_55352_row3_col6" class="data row3 col6" >0.99</td>
#       <td id="T_55352_row3_col7" class="data row3 col7" >0.97</td>
#       <td id="T_55352_row3_col8" class="data row3 col8" >0.96</td>
#       <td id="T_55352_row3_col9" class="data row3 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row4" class="row_heading level0 row4" >58</th>
#       <td id="T_55352_row4_col0" class="data row4 col0" >Exposome</td>
#       <td id="T_55352_row4_col1" class="data row4 col1" >Classic</td>
#       <td id="T_55352_row4_col2" class="data row4 col2" >PCA</td>
#       <td id="T_55352_row4_col3" class="data row4 col3" >Agglo.</td>
#       <td id="T_55352_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_55352_row4_col5" class="data row4 col5" >cohort</td>
#       <td id="T_55352_row4_col6" class="data row4 col6" >0.99</td>
#       <td id="T_55352_row4_col7" class="data row4 col7" >0.97</td>
#       <td id="T_55352_row4_col8" class="data row4 col8" >0.96</td>
#       <td id="T_55352_row4_col9" class="data row4 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_55352_row5_col0" class="data row5 col0" >Exposome</td>
#       <td id="T_55352_row5_col1" class="data row5 col1" >Deep clustering</td>
#       <td id="T_55352_row5_col2" class="data row5 col2" >DEC</td>
#       <td id="T_55352_row5_col3" class="data row5 col3" >K-Means</td>
#       <td id="T_55352_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_55352_row5_col5" class="data row5 col5" >cohort</td>
#       <td id="T_55352_row5_col6" class="data row5 col6" >0.99</td>
#       <td id="T_55352_row5_col7" class="data row5 col7" >0.97</td>
#       <td id="T_55352_row5_col8" class="data row5 col8" >0.96</td>
#       <td id="T_55352_row5_col9" class="data row5 col9" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row6" class="row_heading level0 row6" >20</th>
#       <td id="T_55352_row6_col0" class="data row6 col0" >Exposome</td>
#       <td id="T_55352_row6_col1" class="data row6 col1" >Deep clustering</td>
#       <td id="T_55352_row6_col2" class="data row6 col2" >VaDE</td>
#       <td id="T_55352_row6_col3" class="data row6 col3" >GMM</td>
#       <td id="T_55352_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_55352_row6_col5" class="data row6 col5" >cohort</td>
#       <td id="T_55352_row6_col6" class="data row6 col6" >0.98</td>
#       <td id="T_55352_row6_col7" class="data row6 col7" >0.95</td>
#       <td id="T_55352_row6_col8" class="data row6 col8" >0.94</td>
#       <td id="T_55352_row6_col9" class="data row6 col9" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row7" class="row_heading level0 row7" >18</th>
#       <td id="T_55352_row7_col0" class="data row7 col0" >Exposome</td>
#       <td id="T_55352_row7_col1" class="data row7 col1" >Classic</td>
#       <td id="T_55352_row7_col2" class="data row7 col2" >Raw data</td>
#       <td id="T_55352_row7_col3" class="data row7 col3" >GMM</td>
#       <td id="T_55352_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_55352_row7_col5" class="data row7 col5" >cohort</td>
#       <td id="T_55352_row7_col6" class="data row7 col6" >0.96</td>
#       <td id="T_55352_row7_col7" class="data row7 col7" >0.93</td>
#       <td id="T_55352_row7_col8" class="data row7 col8" >0.94</td>
#       <td id="T_55352_row7_col9" class="data row7 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row8" class="row_heading level0 row8" >40</th>
#       <td id="T_55352_row8_col0" class="data row8 col0" >Metabolome (corrected)</td>
#       <td id="T_55352_row8_col1" class="data row8 col1" >Classic</td>
#       <td id="T_55352_row8_col2" class="data row8 col2" >PCA</td>
#       <td id="T_55352_row8_col3" class="data row8 col3" >GMM</td>
#       <td id="T_55352_row8_col4" class="data row8 col4" >2</td>
#       <td id="T_55352_row8_col5" class="data row8 col5" >asthma</td>
#       <td id="T_55352_row8_col6" class="data row8 col6" >0.89</td>
#       <td id="T_55352_row8_col7" class="data row8 col7" >0.00</td>
#       <td id="T_55352_row8_col8" class="data row8 col8" >0.00</td>
#       <td id="T_55352_row8_col9" class="data row8 col9" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_55352_level0_row9" class="row_heading

# %%
# Markdown-like table:
# print(tabulate(results.sort_values(by="Acc.", ascending=False).head(10).round(2), headers='keys', tablefmt='pipe', showindex=False))

# %% [markdown]
# ## Top results for Adjusted Rand Index:

# %%
results.sort_values(by="ARI.", ascending=False).head(10).style.format('{:.2f}', subset=['Acc.','ARI.','AMI.','Sil.'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b29b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b29b_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_0b29b_level0_col1" class="col_heading level0 col1" >Method</th>
#       <th id="T_0b29b_level0_col2" class="col_heading level0 col2" >FL method</th>
#       <th id="T_0b29b_level0_col3" class="col_heading level0 col3" >CL method</th>
#       <th id="T_0b29b_level0_col4" class="col_heading level0 col4" >num clusters</th>
#       <th id="T_0b29b_level0_col5" class="col_heading level0 col5" >variable</th>
#       <th id="T_0b29b_level0_col6" class="col_heading level0 col6" >Acc.</th>
#       <th id="T_0b29b_level0_col7" class="col_heading level0 col7" >ARI.</th>
#       <th id="T_0b29b_level0_col8" class="col_heading level0 col8" >AMI.</th>
#       <th id="T_0b29b_level0_col9" class="col_heading level0 col9" >Sil.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b29b_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_0b29b_row0_col0" class="data row0 col0" >Exposome</td>
#       <td id="T_0b29b_row0_col1" class="data row0 col1" >Classic</td>
#       <td id="T_0b29b_row0_col2" class="data row0 col2" >Raw data</td>
#       <td id="T_0b29b_row0_col3" class="data row0 col3" >Agglo.</td>
#       <td id="T_0b29b_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_0b29b_row0_col5" class="data row0 col5" >cohort</td>
#       <td id="T_0b29b_row0_col6" class="data row0 col6" >0.99</td>
#       <td id="T_0b29b_row0_col7" class="data row0 col7" >0.98</td>
#       <td id="T_0b29b_row0_col8" class="data row0 col8" >0.97</td>
#       <td id="T_0b29b_row0_col9" class="data row0 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row1" class="row_heading level0 row1" >38</th>
#       <td id="T_0b29b_row1_col0" class="data row1 col0" >Exposome</td>
#       <td id="T_0b29b_row1_col1" class="data row1 col1" >Classic</td>
#       <td id="T_0b29b_row1_col2" class="data row1 col2" >PCA</td>
#       <td id="T_0b29b_row1_col3" class="data row1 col3" >K-Means</td>
#       <td id="T_0b29b_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_0b29b_row1_col5" class="data row1 col5" >cohort</td>
#       <td id="T_0b29b_row1_col6" class="data row1 col6" >0.99</td>
#       <td id="T_0b29b_row1_col7" class="data row1 col7" >0.98</td>
#       <td id="T_0b29b_row1_col8" class="data row1 col8" >0.97</td>
#       <td id="T_0b29b_row1_col9" class="data row1 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_0b29b_row2_col0" class="data row2 col0" >Exposome</td>
#       <td id="T_0b29b_row2_col1" class="data row2 col1" >Classic</td>
#       <td id="T_0b29b_row2_col2" class="data row2 col2" >Raw data</td>
#       <td id="T_0b29b_row2_col3" class="data row2 col3" >K-Means</td>
#       <td id="T_0b29b_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_0b29b_row2_col5" class="data row2 col5" >cohort</td>
#       <td id="T_0b29b_row2_col6" class="data row2 col6" >0.99</td>
#       <td id="T_0b29b_row2_col7" class="data row2 col7" >0.98</td>
#       <td id="T_0b29b_row2_col8" class="data row2 col8" >0.97</td>
#       <td id="T_0b29b_row2_col9" class="data row2 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_0b29b_row3_col0" class="data row3 col0" >Exposome</td>
#       <td id="T_0b29b_row3_col1" class="data row3 col1" >Classic</td>
#       <td id="T_0b29b_row3_col2" class="data row3 col2" >PCA</td>
#       <td id="T_0b29b_row3_col3" class="data row3 col3" >GMM</td>
#       <td id="T_0b29b_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_0b29b_row3_col5" class="data row3 col5" >cohort</td>
#       <td id="T_0b29b_row3_col6" class="data row3 col6" >0.99</td>
#       <td id="T_0b29b_row3_col7" class="data row3 col7" >0.97</td>
#       <td id="T_0b29b_row3_col8" class="data row3 col8" >0.96</td>
#       <td id="T_0b29b_row3_col9" class="data row3 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row4" class="row_heading level0 row4" >58</th>
#       <td id="T_0b29b_row4_col0" class="data row4 col0" >Exposome</td>
#       <td id="T_0b29b_row4_col1" class="data row4 col1" >Classic</td>
#       <td id="T_0b29b_row4_col2" class="data row4 col2" >PCA</td>
#       <td id="T_0b29b_row4_col3" class="data row4 col3" >Agglo.</td>
#       <td id="T_0b29b_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_0b29b_row4_col5" class="data row4 col5" >cohort</td>
#       <td id="T_0b29b_row4_col6" class="data row4 col6" >0.99</td>
#       <td id="T_0b29b_row4_col7" class="data row4 col7" >0.97</td>
#       <td id="T_0b29b_row4_col8" class="data row4 col8" >0.96</td>
#       <td id="T_0b29b_row4_col9" class="data row4 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_0b29b_row5_col0" class="data row5 col0" >Exposome</td>
#       <td id="T_0b29b_row5_col1" class="data row5 col1" >Deep clustering</td>
#       <td id="T_0b29b_row5_col2" class="data row5 col2" >DEC</td>
#       <td id="T_0b29b_row5_col3" class="data row5 col3" >K-Means</td>
#       <td id="T_0b29b_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_0b29b_row5_col5" class="data row5 col5" >cohort</td>
#       <td id="T_0b29b_row5_col6" class="data row5 col6" >0.99</td>
#       <td id="T_0b29b_row5_col7" class="data row5 col7" >0.97</td>
#       <td id="T_0b29b_row5_col8" class="data row5 col8" >0.96</td>
#       <td id="T_0b29b_row5_col9" class="data row5 col9" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row6" class="row_heading level0 row6" >20</th>
#       <td id="T_0b29b_row6_col0" class="data row6 col0" >Exposome</td>
#       <td id="T_0b29b_row6_col1" class="data row6 col1" >Deep clustering</td>
#       <td id="T_0b29b_row6_col2" class="data row6 col2" >VaDE</td>
#       <td id="T_0b29b_row6_col3" class="data row6 col3" >GMM</td>
#       <td id="T_0b29b_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_0b29b_row6_col5" class="data row6 col5" >cohort</td>
#       <td id="T_0b29b_row6_col6" class="data row6 col6" >0.98</td>
#       <td id="T_0b29b_row6_col7" class="data row6 col7" >0.95</td>
#       <td id="T_0b29b_row6_col8" class="data row6 col8" >0.94</td>
#       <td id="T_0b29b_row6_col9" class="data row6 col9" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row7" class="row_heading level0 row7" >18</th>
#       <td id="T_0b29b_row7_col0" class="data row7 col0" >Exposome</td>
#       <td id="T_0b29b_row7_col1" class="data row7 col1" >Classic</td>
#       <td id="T_0b29b_row7_col2" class="data row7 col2" >Raw data</td>
#       <td id="T_0b29b_row7_col3" class="data row7 col3" >GMM</td>
#       <td id="T_0b29b_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_0b29b_row7_col5" class="data row7 col5" >cohort</td>
#       <td id="T_0b29b_row7_col6" class="data row7 col6" >0.96</td>
#       <td id="T_0b29b_row7_col7" class="data row7 col7" >0.93</td>
#       <td id="T_0b29b_row7_col8" class="data row7 col8" >0.94</td>
#       <td id="T_0b29b_row7_col9" class="data row7 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row8" class="row_heading level0 row8" >19</th>
#       <td id="T_0b29b_row8_col0" class="data row8 col0" >Exposome</td>
#       <td id="T_0b29b_row8_col1" class="data row8 col1" >Classic</td>
#       <td id="T_0b29b_row8_col2" class="data row8 col2" >Raw data</td>
#       <td id="T_0b29b_row8_col3" class="data row8 col3" >GMM</td>
#       <td id="T_0b29b_row8_col4" class="data row8 col4" >7</td>
#       <td id="T_0b29b_row8_col5" class="data row8 col5" >age</td>
#       <td id="T_0b29b_row8_col6" class="data row8 col6" >0.59</td>
#       <td id="T_0b29b_row8_col7" class="data row8 col7" >0.48</td>
#       <td id="T_0b29b_row8_col8" class="data row8 col8" >0.59</td>
#       <td id="T_0b29b_row8_col9" class="data row8 col9" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_0b29b_level0_row9" class="row_heading level0 row9

# %%
# Markdown-like table:
# print(tabulate(results.sort_values(by="ARI.", ascending=False).head(10).round(2), headers='keys', tablefmt='pipe', showindex=False))

# %% [markdown]
# ## Top results for Adjusted Mutual Information:

# %%
results.sort_values(by="AMI.", ascending=False).head(10).style.format('{:.2f}', subset=['Acc.','ARI.','AMI.','Sil.'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a611">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a611_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_4a611_level0_col1" class="col_heading level0 col1" >Method</th>
#       <th id="T_4a611_level0_col2" class="col_heading level0 col2" >FL method</th>
#       <th id="T_4a611_level0_col3" class="col_heading level0 col3" >CL method</th>
#       <th id="T_4a611_level0_col4" class="col_heading level0 col4" >num clusters</th>
#       <th id="T_4a611_level0_col5" class="col_heading level0 col5" >variable</th>
#       <th id="T_4a611_level0_col6" class="col_heading level0 col6" >Acc.</th>
#       <th id="T_4a611_level0_col7" class="col_heading level0 col7" >ARI.</th>
#       <th id="T_4a611_level0_col8" class="col_heading level0 col8" >AMI.</th>
#       <th id="T_4a611_level0_col9" class="col_heading level0 col9" >Sil.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a611_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_4a611_row0_col0" class="data row0 col0" >Exposome</td>
#       <td id="T_4a611_row0_col1" class="data row0 col1" >Classic</td>
#       <td id="T_4a611_row0_col2" class="data row0 col2" >Raw data</td>
#       <td id="T_4a611_row0_col3" class="data row0 col3" >Agglo.</td>
#       <td id="T_4a611_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_4a611_row0_col5" class="data row0 col5" >cohort</td>
#       <td id="T_4a611_row0_col6" class="data row0 col6" >0.99</td>
#       <td id="T_4a611_row0_col7" class="data row0 col7" >0.98</td>
#       <td id="T_4a611_row0_col8" class="data row0 col8" >0.97</td>
#       <td id="T_4a611_row0_col9" class="data row0 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row1" class="row_heading level0 row1" >38</th>
#       <td id="T_4a611_row1_col0" class="data row1 col0" >Exposome</td>
#       <td id="T_4a611_row1_col1" class="data row1 col1" >Classic</td>
#       <td id="T_4a611_row1_col2" class="data row1 col2" >PCA</td>
#       <td id="T_4a611_row1_col3" class="data row1 col3" >K-Means</td>
#       <td id="T_4a611_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_4a611_row1_col5" class="data row1 col5" >cohort</td>
#       <td id="T_4a611_row1_col6" class="data row1 col6" >0.99</td>
#       <td id="T_4a611_row1_col7" class="data row1 col7" >0.98</td>
#       <td id="T_4a611_row1_col8" class="data row1 col8" >0.97</td>
#       <td id="T_4a611_row1_col9" class="data row1 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_4a611_row2_col0" class="data row2 col0" >Exposome</td>
#       <td id="T_4a611_row2_col1" class="data row2 col1" >Classic</td>
#       <td id="T_4a611_row2_col2" class="data row2 col2" >Raw data</td>
#       <td id="T_4a611_row2_col3" class="data row2 col3" >K-Means</td>
#       <td id="T_4a611_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_4a611_row2_col5" class="data row2 col5" >cohort</td>
#       <td id="T_4a611_row2_col6" class="data row2 col6" >0.99</td>
#       <td id="T_4a611_row2_col7" class="data row2 col7" >0.98</td>
#       <td id="T_4a611_row2_col8" class="data row2 col8" >0.97</td>
#       <td id="T_4a611_row2_col9" class="data row2 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_4a611_row3_col0" class="data row3 col0" >Exposome</td>
#       <td id="T_4a611_row3_col1" class="data row3 col1" >Classic</td>
#       <td id="T_4a611_row3_col2" class="data row3 col2" >PCA</td>
#       <td id="T_4a611_row3_col3" class="data row3 col3" >GMM</td>
#       <td id="T_4a611_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_4a611_row3_col5" class="data row3 col5" >cohort</td>
#       <td id="T_4a611_row3_col6" class="data row3 col6" >0.99</td>
#       <td id="T_4a611_row3_col7" class="data row3 col7" >0.97</td>
#       <td id="T_4a611_row3_col8" class="data row3 col8" >0.96</td>
#       <td id="T_4a611_row3_col9" class="data row3 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_4a611_row4_col0" class="data row4 col0" >Exposome</td>
#       <td id="T_4a611_row4_col1" class="data row4 col1" >Deep clustering</td>
#       <td id="T_4a611_row4_col2" class="data row4 col2" >DEC</td>
#       <td id="T_4a611_row4_col3" class="data row4 col3" >K-Means</td>
#       <td id="T_4a611_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_4a611_row4_col5" class="data row4 col5" >cohort</td>
#       <td id="T_4a611_row4_col6" class="data row4 col6" >0.99</td>
#       <td id="T_4a611_row4_col7" class="data row4 col7" >0.97</td>
#       <td id="T_4a611_row4_col8" class="data row4 col8" >0.96</td>
#       <td id="T_4a611_row4_col9" class="data row4 col9" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row5" class="row_heading level0 row5" >58</th>
#       <td id="T_4a611_row5_col0" class="data row5 col0" >Exposome</td>
#       <td id="T_4a611_row5_col1" class="data row5 col1" >Classic</td>
#       <td id="T_4a611_row5_col2" class="data row5 col2" >PCA</td>
#       <td id="T_4a611_row5_col3" class="data row5 col3" >Agglo.</td>
#       <td id="T_4a611_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_4a611_row5_col5" class="data row5 col5" >cohort</td>
#       <td id="T_4a611_row5_col6" class="data row5 col6" >0.99</td>
#       <td id="T_4a611_row5_col7" class="data row5 col7" >0.97</td>
#       <td id="T_4a611_row5_col8" class="data row5 col8" >0.96</td>
#       <td id="T_4a611_row5_col9" class="data row5 col9" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row6" class="row_heading level0 row6" >20</th>
#       <td id="T_4a611_row6_col0" class="data row6 col0" >Exposome</td>
#       <td id="T_4a611_row6_col1" class="data row6 col1" >Deep clustering</td>
#       <td id="T_4a611_row6_col2" class="data row6 col2" >VaDE</td>
#       <td id="T_4a611_row6_col3" class="data row6 col3" >GMM</td>
#       <td id="T_4a611_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_4a611_row6_col5" class="data row6 col5" >cohort</td>
#       <td id="T_4a611_row6_col6" class="data row6 col6" >0.98</td>
#       <td id="T_4a611_row6_col7" class="data row6 col7" >0.95</td>
#       <td id="T_4a611_row6_col8" class="data row6 col8" >0.94</td>
#       <td id="T_4a611_row6_col9" class="data row6 col9" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row7" class="row_heading level0 row7" >18</th>
#       <td id="T_4a611_row7_col0" class="data row7 col0" >Exposome</td>
#       <td id="T_4a611_row7_col1" class="data row7 col1" >Classic</td>
#       <td id="T_4a611_row7_col2" class="data row7 col2" >Raw data</td>
#       <td id="T_4a611_row7_col3" class="data row7 col3" >GMM</td>
#       <td id="T_4a611_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_4a611_row7_col5" class="data row7 col5" >cohort</td>
#       <td id="T_4a611_row7_col6" class="data row7 col6" >0.96</td>
#       <td id="T_4a611_row7_col7" class="data row7 col7" >0.93</td>
#       <td id="T_4a611_row7_col8" class="data row7 col8" >0.94</td>
#       <td id="T_4a611_row7_col9" class="data row7 col9" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row8" class="row_heading level0 row8" >19</th>
#       <td id="T_4a611_row8_col0" class="data row8 col0" >Exposome</td>
#       <td id="T_4a611_row8_col1" class="data row8 col1" >Classic</td>
#       <td id="T_4a611_row8_col2" class="data row8 col2" >Raw data</td>
#       <td id="T_4a611_row8_col3" class="data row8 col3" >GMM</td>
#       <td id="T_4a611_row8_col4" class="data row8 col4" >7</td>
#       <td id="T_4a611_row8_col5" class="data row8 col5" >age</td>
#       <td id="T_4a611_row8_col6" class="data row8 col6" >0.59</td>
#       <td id="T_4a611_row8_col7" class="data row8 col7" >0.48</td>
#       <td id="T_4a611_row8_col8" class="data row8 col8" >0.59</td>
#       <td id="T_4a611_row8_col9" class="data row8 col9" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_4a611_level0_row9" class="row_heading level0 row9

# %%
# Markdown-like table:
# print(tabulate(results.sort_values(by="AMI.", ascending=False).head(10).round(2), headers='keys', tablefmt='pipe', showindex=False))

# %% [markdown]
# ## Top results for Silhouette:

# %%
results.sort_values(by="Sil.", ascending=False).head(10).style.format('{:.2f}', subset=['Acc.','ARI.','AMI.','Sil.'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_b540c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b540c_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_b540c_level0_col1" class="col_heading level0 col1" >Method</th>
#       <th id="T_b540c_level0_col2" class="col_heading level0 col2" >FL method</th>
#       <th id="T_b540c_level0_col3" class="col_heading level0 col3" >CL method</th>
#       <th id="T_b540c_level0_col4" class="col_heading level0 col4" >num clusters</th>
#       <th id="T_b540c_level0_col5" class="col_heading level0 col5" >variable</th>
#       <th id="T_b540c_level0_col6" class="col_heading level0 col6" >Acc.</th>
#       <th id="T_b540c_level0_col7" class="col_heading level0 col7" >ARI.</th>
#       <th id="T_b540c_level0_col8" class="col_heading level0 col8" >AMI.</th>
#       <th id="T_b540c_level0_col9" class="col_heading level0 col9" >Sil.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b540c_level0_row0" class="row_heading level0 row0" >22</th>
#       <td id="T_b540c_row0_col0" class="data row0 col0" >Metabolome</td>
#       <td id="T_b540c_row0_col1" class="data row0 col1" >Deep clustering</td>
#       <td id="T_b540c_row0_col2" class="data row0 col2" >DEC + DA</td>
#       <td id="T_b540c_row0_col3" class="data row0 col3" >K-Means</td>
#       <td id="T_b540c_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_b540c_row0_col5" class="data row0 col5" >asthma</td>
#       <td id="T_b540c_row0_col6" class="data row0 col6" >0.89</td>
#       <td id="T_b540c_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_b540c_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_b540c_row0_col9" class="data row0 col9" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row1" class="row_heading level0 row1" >23</th>
#       <td id="T_b540c_row1_col0" class="data row1 col0" >Metabolome</td>
#       <td id="T_b540c_row1_col1" class="data row1 col1" >Deep clustering</td>
#       <td id="T_b540c_row1_col2" class="data row1 col2" >DEC + DA</td>
#       <td id="T_b540c_row1_col3" class="data row1 col3" >K-Means</td>
#       <td id="T_b540c_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_b540c_row1_col5" class="data row1 col5" >sex</td>
#       <td id="T_b540c_row1_col6" class="data row1 col6" >0.53</td>
#       <td id="T_b540c_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_b540c_row1_col8" class="data row1 col8" >0.00</td>
#       <td id="T_b540c_row1_col9" class="data row1 col9" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row2" class="row_heading level0 row2" >23</th>
#       <td id="T_b540c_row2_col0" class="data row2 col0" >Metabolome</td>
#       <td id="T_b540c_row2_col1" class="data row2 col1" >Deep clustering (fet. sel.)</td>
#       <td id="T_b540c_row2_col2" class="data row2 col2" >DEC + DA</td>
#       <td id="T_b540c_row2_col3" class="data row2 col3" >K-Means</td>
#       <td id="T_b540c_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_b540c_row2_col5" class="data row2 col5" >sex</td>
#       <td id="T_b540c_row2_col6" class="data row2 col6" >0.53</td>
#       <td id="T_b540c_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_b540c_row2_col8" class="data row2 col8" >0.00</td>
#       <td id="T_b540c_row2_col9" class="data row2 col9" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_b540c_row3_col0" class="data row3 col0" >Metabolome</td>
#       <td id="T_b540c_row3_col1" class="data row3 col1" >Deep clustering (fet. sel.)</td>
#       <td id="T_b540c_row3_col2" class="data row3 col2" >DEC + DA</td>
#       <td id="T_b540c_row3_col3" class="data row3 col3" >K-Means</td>
#       <td id="T_b540c_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_b540c_row3_col5" class="data row3 col5" >asthma</td>
#       <td id="T_b540c_row3_col6" class="data row3 col6" >0.89</td>
#       <td id="T_b540c_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_b540c_row3_col8" class="data row3 col8" >0.00</td>
#       <td id="T_b540c_row3_col9" class="data row3 col9" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_b540c_row4_col0" class="data row4 col0" >Exposome</td>
#       <td id="T_b540c_row4_col1" class="data row4 col1" >Deep clustering</td>
#       <td id="T_b540c_row4_col2" class="data row4 col2" >DEC</td>
#       <td id="T_b540c_row4_col3" class="data row4 col3" >K-Means</td>
#       <td id="T_b540c_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_b540c_row4_col5" class="data row4 col5" >education</td>
#       <td id="T_b540c_row4_col6" class="data row4 col6" >0.52</td>
#       <td id="T_b540c_row4_col7" class="data row4 col7" >0.05</td>
#       <td id="T_b540c_row4_col8" class="data row4 col8" >0.02</td>
#       <td id="T_b540c_row4_col9" class="data row4 col9" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_b540c_row5_col0" class="data row5 col0" >Exposome</td>
#       <td id="T_b540c_row5_col1" class="data row5 col1" >Deep clustering</td>
#       <td id="T_b540c_row5_col2" class="data row5 col2" >DEC</td>
#       <td id="T_b540c_row5_col3" class="data row5 col3" >K-Means</td>
#       <td id="T_b540c_row5_col4" class="data row5 col4" >3</td>
#       <td id="T_b540c_row5_col5" class="data row5 col5" >native</td>
#       <td id="T_b540c_row5_col6" class="data row5 col6" >0.84</td>
#       <td id="T_b540c_row5_col7" class="data row5 col7" >0.00</td>
#       <td id="T_b540c_row5_col8" class="data row5 col8" >0.00</td>
#       <td id="T_b540c_row5_col9" class="data row5 col9" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_b540c_row6_col0" class="data row6 col0" >Exposome</td>
#       <td id="T_b540c_row6_col1" class="data row6 col1" >Deep clustering</td>
#       <td id="T_b540c_row6_col2" class="data row6 col2" >DEC</td>
#       <td id="T_b540c_row6_col3" class="data row6 col3" >K-Means</td>
#       <td id="T_b540c_row6_col4" class="data row6 col4" >3</td>
#       <td id="T_b540c_row6_col5" class="data row6 col5" >parity</td>
#       <td id="T_b540c_row6_col6" class="data row6 col6" >0.45</td>
#       <td id="T_b540c_row6_col7" class="data row6 col7" >0.00</td>
#       <td id="T_b540c_row6_col8" class="data row6 col8" >0.00</td>
#       <td id="T_b540c_row6_col9" class="data row6 col9" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row7" class="row_heading level0 row7" >26</th>
#       <td id="T_b540c_row7_col0" class="data row7 col0" >Metabolome</td>
#       <td id="T_b540c_row7_col1" class="data row7 col1" >Deep clustering</td>
#       <td id="T_b540c_row7_col2" class="data row7 col2" >DEC + DA</td>
#       <td id="T_b540c_row7_col3" class="data row7 col3" >K-Means</td>
#       <td id="T_b540c_row7_col4" class="data row7 col4" >3</td>
#       <td id="T_b540c_row7_col5" class="data row7 col5" >parity</td>
#       <td id="T_b540c_row7_col6" class="data row7 col6" >0.45</td>
#       <td id="T_b540c_row7_col7" class="data row7 col7" >0.00</td>
#       <td id="T_b540c_row7_col8" class="data row7 col8" >0.00</td>
#       <td id="T_b540c_row7_col9" class="data row7 col9" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_b540c_level0_row8" class="row_heading level0 row8" >25</th>
#       <td id="T_b540c_row8_col0" class="data row8 col0" >Metabolome</td>
#       <td id="T_b540c_row8_col1" class="data row8 col1" >Deep clustering</td>
#       <td id="T_b540c_row8_col2" class="data row8 col2" >DEC + DA</td>
#       <td id="T_b540c_row8_col3" class="data row8 col3" >K-Means</td>
#       <td id="T_b540c_row8_col4" class="data row8 col4" >3</td>
#       <td id="T_b540c_row8_col5" class="data row8 col5" >native</td>
#       <td id="T_b540c_row8_col6" class="data row8 col6" >0.84</td>
#       <td id="T_b540c_row8_col7" class="data row8 col7" >0.00</td>
#       <td id="T_b540c_row8_col8" class="data row8 col8" >0.00</td>
#       <td id="T_b540c_row8_col9"

# %%
# Markdown-like table:
# print(tabulate(results.sort_values(by="Sil.", ascending=False).head(10).round(2), headers='keys', tablefmt='pipe', showindex=False))
