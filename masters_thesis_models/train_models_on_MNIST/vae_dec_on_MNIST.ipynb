# %% [markdown]
# # Prepare some things

# %% [markdown]
# ## Load some modules

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import backend as K
from keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

import numpy as np

import sklearn.metrics
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, DBSCAN
from sklearn.mixture import GaussianMixture

# %%
# Load the model class and some custom functions
import sys
sys.path.append('../')
from models import get_vae_model, get_dec_model, compute_p, compute_delta
from clustering_metrics import evaluate_model
from draw_embeddings import draw_embeddings, draw_clusters_assignments, compare_reconstructed_images_MNIST

# %% [markdown]
# ## Load and prepare the MNIST data set

# %%
(x_train, y_train), (x_test, y_test) = (mnist.load_data())

x_train = x_train.reshape(-1, 28*28).astype("float")/255
x_test = x_test.reshape(-1, 28*28).astype("float")/255

# %% [markdown]
# # Construct the VAE based DEC model

# %% [markdown]
# ## Load the pretrained VAE model
#
# Construct the model and load the pretrained weights from the notebook [vae_on_MNIST.ipynb](./vae_on_MNIST.ipynb)

# %%
IMG_DIM = 28*28
LATENT_DIM = 10
INTERMEDIATE_DIMS = (512, 512, 2048)
N_CLUSTERS = 10

model_vae = get_vae_model(IMG_DIM, LATENT_DIM, INTERMEDIATE_DIMS)
model_vae.load_weights("model_weights/cvae/pretrained/vae")

# %% [markdown]
# ## Construc the DEC model

# %%
encoder = models.Model(model_vae.encoder.inputs, model_vae.encoder.outputs[0])

model_dec = get_dec_model(encoder, N_CLUSTERS)

# %% [markdown]
# ## Show the resulting embeddings

# %%
if LATENT_DIM == 2:
    z_train = model_dec.encode(x_train)
    draw_embeddings(z_train, y_train)
else:
    z_test = model_dec.encode(x_test)
    tsne = TSNE(n_components=2, init='pca')
    z_tsne = tsne.fit_transform(z_test[0:2000])
    draw_embeddings(z_tsne, y_test[0:2000], alpha=0.7)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# # Fine-tune the model (K-Means)

# %% [markdown]
# ## Initialize the parameters

# %%
EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 1e-4
# MOMENTUM = 0.9
SCHEDULE = 10
DELTA_THRESHOLD = 0.001

# %% [markdown]
# Initialize the model parameters from a K-means:

# %%
z_train = model_dec.encode(x_train)

kmeans = KMeans(n_clusters=N_CLUSTERS, n_init=30)
kmeans.fit(z_train)

for weight in model_dec.trainable_weights:
    if weight.name == "centroids:0":
        weight.assign(K.constant(kmeans.cluster_centers_))

# %% [markdown]
# Initialize `p`, the auxiliary distribution to compute the clustering loss, and `c_last`, the last cluster assignments to compute the number of points that changed clusters.

# %%
p = compute_p(to_categorical(kmeans.labels_))
c_last = kmeans.labels_

# %% [markdown]
# Evaluate the clustering performance before fine-tunning the model:

# %%
evaluate_model(model_dec.classify, model_dec.encode, x_test, y_test)
# Out:
# {'Acc': 0.6112,
#  'ARI': 0.4178752076334356,
#  'AMI': 0.5339191645912688,
#  'Sil': 0.16384485}

# %% [markdown]
# ## Train the model

# %% [markdown]
# Train the model:

# %%
def dec_callback(epoch, logs):
    global p
    global c_last
    
    if (epoch+1) % SCHEDULE == 0:
        q = model_dec.soft_assignment(x_train)
        p = compute_p(q)
        
        c_new = q.numpy().argmax(1)
        delta = compute_delta(c_new, c_last)
        c_last = np.copy(c_new)
        print(f"Delta: {delta:.3f}")
        if (delta < DELTA_THRESHOLD):
            model_dec.stop_training = True
            
callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=dec_callback)

# %%
model_dec.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE))

model_dec.fit(x_train, p,
              epochs=EPOCHS,
              batch_size=BATCH_SIZE,
              callbacks = callback,
              verbose=2,
             )

model_dec.save_weights("model_weights/vae_dec/finetuned/dec_kmeans")

model_dec.load_weights("model_weights/vae_dec/finetuned/dec_kmeans")
# Out:
# Epoch 1/100
# 469/469 - 2s - loss: 8.4336 - 2s/epoch - 5ms/step
# Epoch 2/100
# 469/469 - 2s - loss: 7.6293 - 2s/epoch - 4ms/step
# Epoch 3/100
# 469/469 - 2s - loss: 7.1749 - 2s/epoch - 4ms/step
# Epoch 4/100
# 469/469 - 2s - loss: 6.7650 - 2s/epoch - 3ms/step
# Epoch 5/100
# 469/469 - 2s - loss: 6.3762 - 2s/epoch - 4ms/step
# Epoch 6/100
# 469/469 - 2s - loss: 6.0133 - 2s/epoch - 3ms/step
# Epoch 7/100
# 469/469 - 2s - loss: 5.6710 - 2s/epoch - 3ms/step
# Epoch 8/100
# 469/469 - 2s - loss: 5.3488 - 2s/epoch - 4ms/step
# Epoch 9/100
# 469/469 - 2s - loss: 5.0487 - 2s/epoch - 4ms/step
# Epoch 10/100
# Delta: 0.021
# 469/469 - 2s - loss: 4.7657 - 2s/epoch - 5ms/step
# Epoch 11/100
# 469/469 - 2s - loss: 4.5006 - 2s/epoch - 3ms/step
# Epoch 12/100
# 469/469 - 2s - loss: 4.2549 - 2s/epoch - 3ms/step
# Epoch 13/100
# 469/469 - 2s - loss: 4.0220 - 2s/epoch - 4ms/step
# Epoch 14/100
# 469/469 - 2s - loss: 3.8080 - 2s/epoch - 4ms/step
# Epoch 15/100
# 469/469 - 2s - loss: 3.6028 - 2s/epoch - 3ms/step
# Epoch 16/100
# 469/469 - 2s - loss: 3.4150 - 2s/epoch - 4ms/step
# Epoch 17/100
# 469/469 - 2s - loss: 3.2395 - 2s/epoch - 3ms/step
# Epoch 18/100
# 469/469 - 2s - loss: 3.0742 - 2s/epoch - 3ms/step
# Epoch 19/100
# 469/469 - 2s - loss: 2.9182 - 2s/epoch - 4ms/step
# Epoch 20/100
# Delta: 0.013
# 469/469 - 2s - loss: 2.7729 - 2s/epoch - 4ms/step
# Epoch 21/100
# 469/469 - 2s - loss: 2.6397 - 2s/epoch - 4ms/step
# Epoch 22/100
# 469/469 - 2s - loss: 2.5081 - 2s/epoch - 3ms/step
# Epoch 23/100
# 469/469 - 2s - loss: 2.3945 - 2s/epoch - 4ms/step
# Epoch 24/100
# 469/469 - 2s - loss: 2.2815 - 2s/epoch - 3ms/step
# Epoch 25/100
# 469/469 - 2s - loss: 2.1774 - 2s/epoch - 3ms/step
# Epoch 26/100
# 469/469 - 2s - loss: 2.0734 - 2s/epoch - 3ms/step
# Epoch 27/100
# 469/469 - 2s - loss: 1.9801 - 2s/epoch - 3ms/step
# Epoch 28/100
# 469/469 - 2s - loss: 1.8993 - 2s/epoch - 3ms/step
# Epoch 29/100
# 469/469 - 2s - loss: 1.8153 - 2s/epoch - 3ms/step
# Epoch 30/100
# Delta: 0.005
# 469/469 - 2s - loss: 1.7343 - 2s/epoch - 5ms/step
# Epoch 31/100
# 469/469 - 2s - loss: 1.6597 - 2s/epoch - 3ms/step
# Epoch 32/100
# 469/469 - 2s - loss: 1.5979 - 2s/epoch - 3ms/step
# Epoch 33/100
# 469/469 - 2s - loss: 1.5288 - 2s/epoch - 3ms/step
# Epoch 34/100
# 469/469 - 2s - loss: 1.4631 - 2s/epoch - 3ms/step
# Epoch 35/100
# 469/469 - 2s - loss: 1.4110 - 2s/epoch - 3ms/step
# Epoch 36/100
# 469/469 - 2s - loss: 1.3526 - 2s/epoch - 3ms/step
# Epoch 37/100
# 469/469 - 2s - loss: 1.3000 - 2s/epoch - 3ms/step
# Epoch 38/100
# 469/469 - 2s - loss: 1.2513 - 2s/epoch - 3ms/step
# Epoch 39/100
# 469/469 - 2s - loss: 1.2085 - 2s/epoch - 3ms/step
# Epoch 40/100
# Delta: 0.002
# 469/469 - 2s - loss: 1.1582 - 2s/epoch - 4ms/step
# Epoch 41/100
# 469/469 - 2s - loss: 1.1243 - 2s/epoch - 3ms/step
# Epoch 42/100
# 469/469 - 2s - loss: 1.0791 - 2s/epoch - 3ms/step
# Epoch 43/100
# 469/469 - 2s - loss: 1.0454 - 2s/epoch - 3ms/step
# Epoch 44/100
# 469/469 - 2s - loss: 1.0115 - 2s/epoch - 3ms/step
# Epoch 45/100
# 469/469 - 2s - loss: 0.9748 - 2s/epoch - 3ms/step
# Epoch 46/100
# 469/469 - 2s - loss: 0.9455 - 2s/epoch - 4ms/step
# Epoch 47/100
# 469/469 - 2s - loss: 0.9077 - 2s/epoch - 4ms/step
# Epoch 48/100
# 469/469 - 2s - loss: 0.8795 - 2s/epoch - 3ms/step
# Epoch 49/100
# 469/469 - 2s - loss: 0.8564 - 2s/epoch - 3ms/step
# Epoch 50/100
# Delta: 0.001
# 469/469 - 2s - loss: 0.8282 - 2s/epoch - 4ms/step
# Epoch 51/100
# 469/469 - 2s - loss: 0.7976 - 2s/epoch - 4ms/step
# Epoch 52/100
# 469/469 - 2s - loss: 0.7726 - 2s/epoch - 3ms/step
# Epoch 53/100
# 469/469 - 2s - loss: 0.7576 - 2s/epoch - 4ms/step
# Epoch 54/100
# 469/469 - 2s - loss: 0.7400 - 2s/epoch - 3ms/step
# Epoch 55/100
# 469/469 - 2s - loss: 0.7113 - 2s/epoch - 3ms/step
# Epoch 56/100
# 469/469 - 2s - loss: 0.6924 - 2s/epoch - 3ms/step
# Epoch 57/100
# 469/469 - 2s - loss: 0.6692 - 2s/epoch - 4ms/step
# Epoch 58/100
# 469/469 - 2s - loss: 0.6550 - 2s/epoch - 4ms/step
# Epoch 59/100
# 469/469 - 2s - loss: 0.6302 - 2s/epoch - 3ms/step
# Epoch 60/100
# Delta: 0.001
# 469/469 - 2s - loss: 0.6152 - 2s/epoch - 4ms/step

# %% [markdown]
# ## Show the resulting embeddings

# %%
z_test = model_dec.encode(x_test)
c_test = model_dec.classify(x_test)

if LATENT_DIM == 2:
    draw_clusters_assignments(z_test, y_test, c_test)
else:
    tsne = TSNE(n_components=2, init='pca')
    z_tsne = tsne.fit_transform(z_test[0:2000])
    draw_clusters_assignments(z_tsne, y_test[0:2000], c_test[0:2000], alpha=0.7)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# ## Evaluate the model

# %%
evaluate_model(model_dec.classify, model_dec.encode, x_test, y_test)
# Out:
# {'Acc': 0.6132,
#  'ARI': 0.4222826526935391,
#  'AMI': 0.5384342740683908,
#  'Sil': 0.9043608}

# %% [markdown]
# # Fine-tune the model (GMM)

# %% [markdown]
# ## Construct the model and load the pretrained weights

# %% [markdown]
# Load the pretrained weights for the encoder and decoder modules:

# %%
model_vae = get_vae_model(IMG_DIM, LATENT_DIM, INTERMEDIATE_DIMS)
model_vae.load_weights("model_weights/cvae/pretrained/vae")
encoder = models.Model(model_vae.encoder.inputs, model_vae.encoder.outputs[0])
model_dec = get_dec_model(encoder, N_CLUSTERS)

# %%
EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 1e-4
# MOMENTUM = 0.9
SCHEDULE = 10
DELTA_THRESHOLD = 0.001

# %% [markdown]
# ## Initialize the parameters

# %%
z_train = model_dec.encode(x_train)

gmm = GaussianMixture(n_components=N_CLUSTERS, covariance_type='diag', n_init=10)
gmm.fit(z_train)

for weight in model_dec.trainable_weights:
    if weight.name == "centroids:0":
        weight.assign(K.constant(gmm.means_))

# %%
p = compute_p(to_categorical(gmm.predict(z_train)))
c_last = gmm.predict(z_train)

# %% [markdown]
# Evaluate the clustering performance before fine-tunning the model:

# %%
evaluate_model(model_dec.classify, model_dec.encode, x_test, y_test)
# Out:
# {'Acc': 0.6376,
#  'ARI': 0.43526931590780904,
#  'AMI': 0.5476284318561647,
#  'Sil': 0.134405}

# %% [markdown]
# ## Train the model

# %%
model_dec.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE))

model_dec.fit(x_train, p,
              epochs=EPOCHS,
              batch_size=128,
              callbacks = callback,
              verbose=2,
             )

model_dec.save_weights("model_weights/vae_dec/finetuned/dec_gmm")

model_dec.load_weights("model_weights/vae_dec/finetuned/dec_gmm")
# Out:
# Epoch 1/100
# 469/469 - 2s - loss: 9.4136 - 2s/epoch - 5ms/step
# Epoch 2/100
# 469/469 - 2s - loss: 8.7736 - 2s/epoch - 4ms/step
# Epoch 3/100
# 469/469 - 2s - loss: 8.3356 - 2s/epoch - 4ms/step
# Epoch 4/100
# 469/469 - 2s - loss: 7.9267 - 2s/epoch - 3ms/step
# Epoch 5/100
# 469/469 - 2s - loss: 7.5354 - 2s/epoch - 3ms/step
# Epoch 6/100
# 469/469 - 2s - loss: 7.1620 - 2s/epoch - 3ms/step
# Epoch 7/100
# 469/469 - 2s - loss: 6.8056 - 2s/epoch - 4ms/step
# Epoch 8/100
# 469/469 - 2s - loss: 6.4688 - 2s/epoch - 3ms/step
# Epoch 9/100
# 469/469 - 2s - loss: 6.1484 - 2s/epoch - 5ms/step
# Epoch 10/100
# Delta: 0.076
# 469/469 - 2s - loss: 5.8492 - 2s/epoch - 5ms/step
# Epoch 11/100
# 469/469 - 2s - loss: 5.5593 - 2s/epoch - 4ms/step
# Epoch 12/100
# 469/469 - 2s - loss: 5.2939 - 2s/epoch - 4ms/step
# Epoch 13/100
# 469/469 - 2s - loss: 5.0441 - 2s/epoch - 3ms/step
# Epoch 14/100
# 469/469 - 2s - loss: 4.8072 - 2s/epoch - 3ms/step
# Epoch 15/100
# 469/469 - 2s - loss: 4.5798 - 2s/epoch - 3ms/step
# Epoch 16/100
# 469/469 - 2s - loss: 4.3739 - 2s/epoch - 3ms/step
# Epoch 17/100
# 469/469 - 2s - loss: 4.1711 - 2s/epoch - 3ms/step
# Epoch 18/100
# 469/469 - 2s - loss: 3.9822 - 2s/epoch - 3ms/step
# Epoch 19/100
# 469/469 - 2s - loss: 3.8033 - 2s/epoch - 3ms/step
# Epoch 20/100
# Delta: 0.032
# 469/469 - 2s - loss: 3.6355 - 2s/epoch - 4ms/step
# Epoch 21/100
# 469/469 - 2s - loss: 3.4870 - 2s/epoch - 3ms/step
# Epoch 22/100
# 469/469 - 2s - loss: 3.3359 - 2s/epoch - 3ms/step
# Epoch 23/100
# 469/469 - 2s - loss: 3.1928 - 2s/epoch - 3ms/step
# Epoch 24/100
# 469/469 - 2s - loss: 3.0590 - 2s/epoch - 4ms/step
# Epoch 25/100
# 469/469 - 2s - loss: 2.9367 - 2s/epoch - 3ms/step
# Epoch 26/100
# 469/469 - 2s - loss: 2.8229 - 2s/epoch - 4ms/step
# Epoch 27/100
# 469/469 - 2s - loss: 2.7065 - 2s/epoch - 3ms/step
# Epoch 28/100
# 469/469 - 2s - loss: 2.6081 - 2s/epoch - 3ms/step
# Epoch 29/100
# 469/469 - 2s - loss: 2.5085 - 2s/epoch - 3ms/step
# Epoch 30/100
# Delta: 0.018
# 469/469 - 2s - loss: 2.4125 - 2s/epoch - 5ms/step
# Epoch 31/100
# 469/469 - 2s - loss: 2.3236 - 2s/epoch - 4ms/step
# Epoch 32/100
# 469/469 - 2s - loss: 2.2454 - 2s/epoch - 3ms/step
# Epoch 33/100
# 469/469 - 2s - loss: 2.1639 - 2s/epoch - 3ms/step
# Epoch 34/100
# 469/469 - 2s - loss: 2.0881 - 2s/epoch - 4ms/step
# Epoch 35/100
# 469/469 - 2s - loss: 2.0134 - 2s/epoch - 3ms/step
# Epoch 36/100
# 469/469 - 2s - loss: 1.9514 - 2s/epoch - 4ms/step
# Epoch 37/100
# 469/469 - 2s - loss: 1.8889 - 2s/epoch - 3ms/step
# Epoch 38/100
# 469/469 - 2s - loss: 1.8236 - 2s/epoch - 3ms/step
# Epoch 39/100
# 469/469 - 2s - loss: 1.7738 - 2s/epoch - 3ms/step
# Epoch 40/100
# Delta: 0.012
# 469/469 - 2s - loss: 1.7127 - 2s/epoch - 5ms/step
# Epoch 41/100
# 469/469 - 2s - loss: 1.6657 - 2s/epoch - 3ms/step
# Epoch 42/100
# 469/469 - 2s - loss: 1.6110 - 2s/epoch - 4ms/step
# Epoch 43/100
# 469/469 - 2s - loss: 1.5671 - 2s/epoch - 3ms/step
# Epoch 44/100
# 469/469 - 2s - loss: 1.5269 - 2s/epoch - 3ms/step
# Epoch 45/100
# 469/469 - 2s - loss: 1.4933 - 2s/epoch - 4ms/step
# Epoch 46/100
# 469/469 - 2s - loss: 1.4403 - 2s/epoch - 4ms/step
# Epoch 47/100
# 469/469 - 2s - loss: 1.3970 - 2s/epoch - 4ms/step
# Epoch 48/100
# 469/469 - 2s - loss: 1.3691 - 2s/epoch - 4ms/step
# Epoch 49/100
# 469/469 - 2s - loss: 1.3333 - 2s/epoch - 3ms/step
# Epoch 50/100
# Delta: 0.008
# 469/469 - 2s - loss: 1.2996 - 2s/epoch - 4ms/step
# Epoch 51/100
# 469/469 - 2s - loss: 1.2757 - 2s/epoch - 4ms/step
# Epoch 52/100
# 469/469 - 2s - loss: 1.2397 - 2s/epoch - 3ms/step
# Epoch 53/100
# 469/469 - 2s - loss: 1.2098 - 2s/epoch - 3ms/step
# Epoch 54/100
# 469/469 - 2s - loss: 1.1849 - 2s/epoch - 4ms/step
# Epoch 55/100
# 469/469 - 2s - loss: 1.1562 - 2s/epoch - 3ms/step
# Epoch 56/100
# 469/469 - 2s - loss: 1.1252 - 2s/epoch - 3ms/step
# Epoch 57/100
# 469/469 - 2s - loss: 1.1059 - 2s/epoch - 3ms/step
# Epoch 58/100
# 469/469 - 2s - loss: 1.0791 - 2s/epoch - 3ms/step
# Epoch 59/100
# 469/469 - 2s - loss: 1.0536 - 2s/epoch - 3ms/step
# Epoch 60/100
# Delta: 0.007
# 469/469 - 2s - loss: 1.0358 - 2s/epoch - 4ms/step
# Epoch 61/100
# 469/469 - 2s - loss: 1.0144 - 2s/epoch - 3ms/step
# Epoch 62/100
# 469/469 - 2s - loss: 0.9926 - 2s/epoch - 3ms/step
# Epoch 63/100
# 469/469 - 2s - loss: 0.9713 - 2s/epoch - 3ms/step
# Epoch 64/100
# 469/469 - 2s - loss: 0.9632 - 2s/epoch - 3ms/step
# Epoch 65/100
# 469/469 - 2s - loss: 0.9419 - 2s/epoch - 3ms/step
# Epoch 66/100
# 469/469 - 2s - loss: 0.9164 - 2s/epoch - 3ms/step
# Epoch 67/100
# 469/469 - 2s - loss: 0.9159 - 2s/epoch - 3ms/step
# Epoch 68/100
# 469/469 - 2s - loss: 0.8860 - 2s/epoch - 3ms/step
# Epoch 69/100
# 469/469 - 2s - loss: 0.8662 - 2s/epoch - 3ms/step
# Epoch 70/100
# Delta: 0.006
# 469/469 - 2s - loss: 0.8559 - 2s/epoch - 4ms/step
# Epoch 71/100
# 469/469 - 2s - loss: 0.8334 - 2s/epoch - 4ms/step
# Epoch 72/100
# 469/469 - 2s - loss: 0.8361 - 2s/epoch - 5ms/step
# Epoch 73/100
# 469/469 - 2s - loss: 0.8064 - 2s/epoch - 3ms/step
# Epoch 74/100
# 469/469 - 2s - loss: 0.8004 - 2s/epoch - 4ms/step
# Epoch 75/100
# 469/469 - 2s - loss: 0.7875 - 2s/epoch - 4ms/step
# Epoch 76/100
# 469/469 - 2s - loss: 0.7756 - 2s/epoch - 3ms/step
# Epoch 77/100
# 469/469 - 2s - loss: 0.7667 - 2s/epoch - 3ms/step
# Epoch 78/100
# 469/469 - 2s - loss: 0.7467 - 2s/epoch - 3ms/step
# Epoch 79/100
# 469/469 - 2s - loss: 0.7326 - 2s/epoch - 3ms/step
# Epoch 80/100
# Delta: 0.006
# 469/469 - 2s - loss: 0.7329 - 2s/epoch - 4ms/step
# Epoch 81/100
# 469/469 - 2s - loss: 0.7188 - 2s/epoch - 3ms/step
# Epoch 82/100
# 469/469 - 2s - loss: 0.7086 - 2s/epoch - 3ms/step
# Epoch 83/100
# 469/469 - 2s - loss: 0.6893 - 2s/epoch - 4ms/step
# Epoch 84/100
# 469/469 - 2s - loss: 0.6910 - 2s/epoch - 3ms/step
# Epoch 85/100
# 469/469 - 2s - loss: 0.6854 - 2s/epoch - 3ms/step
# Epoch 86/100
# 469/469 - 2s - loss: 0.6652 - 2s/epoch - 3ms/step
# Epoch 87/100
# 469/469 - 2s - loss: 0.6535 - 2s/epoch - 3ms/step
# Epoch 88/100
# 469/469 - 2s - loss: 0.6568 - 2s/epoch - 3ms/step
# Epoch 89/100
# 469/469 - 2s - loss: 0.6391 - 2s/epoch - 3ms/step
# Epoch 90/100
# Delta: 0.005
# 469/469 - 2s - loss: 0.6351 - 2s/epoch - 4ms/step
# Epoch 91/100
# 469/469 - 2s - loss: 0.6253 - 2s/epoch - 3ms/step
# Epoch 92/100
# 469/469 - 2s - loss: 0.6238 - 2s/epoch - 4ms/step
# Epoch 93/100
# 469/469 - 2s - loss: 0.6058 - 2s/epoch - 4ms/step
# Epoch 94/100
# 469/469 - 2s - loss: 0.6018 - 2s/epoch - 3ms/step
# Epoch 95/100
# 469/469 - 2s - loss: 0.5932 - 2s/epoch - 3ms/step
# Epoch 96/100
# 469/469 - 2s - loss: 0.5873 - 2s/epoch - 3ms/step
# Epoch 97/100
# 469/469 - 2s - loss: 0.5676 - 2s/epoch - 4ms/step
# Epoch 98/100
# 469/469 - 2s - loss: 0.5734 - 2s/epoch - 3ms/step
# Epoch 99/100
# 469/469 - 2s - loss: 0.5655 - 2s/epoch - 3ms/step
# Epoch 100/100
# Delta: 0.004
# 469/469 - 2s - loss: 0.5573 - 2s/epoch - 4ms/step

# %% [markdown]
# ## Show the resulting embeddings

# %%
z_test = model_dec.encode(x_test)
c_test = model_dec.classify(x_test)

if LATENT_DIM == 2:
    draw_clusters_assignments(z_test, y_test, c_test)
else:
    tsne = TSNE(n_components=2, init='pca')
    z_tsne = tsne.fit_transform(z_test[0:2000])
    draw_clusters_assignments(z_tsne, y_test[0:2000], c_test[0:2000], alpha=0.7)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# ## Evaluate the model

# %%
evaluate_model(model_dec.classify, model_dec.encode, x_test, y_test)
# Out:
# {'Acc': 0.569,
#  'ARI': 0.3129097737276735,
#  'AMI': 0.4690800405814185,
#  'Sil': 0.8670885}
