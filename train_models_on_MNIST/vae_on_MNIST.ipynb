# %% [markdown]
# # Prepare some things

# %% [markdown]
# ## Load some modules

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

import numpy as np

import sklearn.metrics
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, DBSCAN
from sklearn.mixture import GaussianMixture

# %%
# Load the model class and some custom functions
import sys
sys.path.append('../')
from models import get_vae_model, get_clustering_vae_model, compute_p, compute_delta
from clustering_metrics import evaluate_model
from draw_embeddings import draw_embeddings, draw_clusters_assignments, compare_reconstructed_images_MNIST

# %% [markdown]
# ## Load and prepare the MNIST data set

# %%
(x_train, y_train), (x_test, y_test) = (mnist.load_data())

x_train = x_train.reshape(-1, 28*28).astype("float")/255
x_test = x_test.reshape(-1, 28*28).astype("float")/255

# %% [markdown]
# # Pretrain the model

# %% [markdown]
# ## Construct and pretrain the autoencoder

# %%
IMG_DIM = 28*28
LATENT_DIM = 10
INTERMEDIATE_DIMS = (512, 512, 2048)

EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 1e-4
# MOMENTUM = 0.9

model_vae = get_vae_model(IMG_DIM, LATENT_DIM, INTERMEDIATE_DIMS)

# model_vae.encoder.summary()
# model_vae.decoder.summary()

# %%
model_vae.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE))
# model_vae.compile(optimizer=keras.optimizers.SGD(learning_rate=LEARNING_RATE, momentum=MOMENTUM))

model_vae.fit(x_train,
              epochs=EPOCHS,
              batch_size=BATCH_SIZE,
              verbose=2,
              )

model_vae.save_weights("model_weights/cvae/pretrained/vae")

model_vae.load_weights("model_weights/cvae/pretrained/vae")
# Out:
# Epoch 1/100
# 469/469 - 3s - total_loss: 37.5671 - reg_loss: 0.4483 - rec_loss: 37.1188 - 3s/epoch - 7ms/step
# Epoch 2/100
# 469/469 - 2s - total_loss: 32.9639 - reg_loss: 0.7229 - rec_loss: 32.2411 - 2s/epoch - 4ms/step
# Epoch 3/100
# 469/469 - 2s - total_loss: 32.0144 - reg_loss: 1.2493 - rec_loss: 30.7652 - 2s/epoch - 4ms/step
# Epoch 4/100
# 469/469 - 2s - total_loss: 31.1594 - reg_loss: 1.8574 - rec_loss: 29.3021 - 2s/epoch - 5ms/step
# Epoch 5/100
# 469/469 - 2s - total_loss: 30.4693 - reg_loss: 2.2128 - rec_loss: 28.2566 - 2s/epoch - 4ms/step
# Epoch 6/100
# 469/469 - 2s - total_loss: 30.0514 - reg_loss: 2.4599 - rec_loss: 27.5915 - 2s/epoch - 4ms/step
# Epoch 7/100
# 469/469 - 2s - total_loss: 29.5954 - reg_loss: 2.8923 - rec_loss: 26.7031 - 2s/epoch - 4ms/step
# Epoch 8/100
# 469/469 - 2s - total_loss: 29.0090 - reg_loss: 3.4063 - rec_loss: 25.6026 - 2s/epoch - 4ms/step
# Epoch 9/100
# 469/469 - 2s - total_loss: 28.5446 - reg_loss: 3.7778 - rec_loss: 24.7667 - 2s/epoch - 4ms/step
# Epoch 10/100
# 469/469 - 2s - total_loss: 28.1985 - reg_loss: 4.0784 - rec_loss: 24.1200 - 2s/epoch - 4ms/step
# Epoch 11/100
# 469/469 - 2s - total_loss: 27.9755 - reg_loss: 4.2770 - rec_loss: 23.6985 - 2s/epoch - 4ms/step
# Epoch 12/100
# 469/469 - 2s - total_loss: 27.7876 - reg_loss: 4.4303 - rec_loss: 23.3573 - 2s/epoch - 4ms/step
# Epoch 13/100
# 469/469 - 2s - total_loss: 27.6271 - reg_loss: 4.5827 - rec_loss: 23.0444 - 2s/epoch - 4ms/step
# Epoch 14/100
# 469/469 - 2s - total_loss: 27.4783 - reg_loss: 4.6773 - rec_loss: 22.8011 - 2s/epoch - 5ms/step
# Epoch 15/100
# 469/469 - 2s - total_loss: 27.3836 - reg_loss: 4.7803 - rec_loss: 22.6033 - 2s/epoch - 4ms/step
# Epoch 16/100
# 469/469 - 2s - total_loss: 27.2762 - reg_loss: 4.8572 - rec_loss: 22.4190 - 2s/epoch - 4ms/step
# Epoch 17/100
# 469/469 - 2s - total_loss: 27.2039 - reg_loss: 4.9275 - rec_loss: 22.2764 - 2s/epoch - 4ms/step
# Epoch 18/100
# 469/469 - 2s - total_loss: 27.1118 - reg_loss: 4.9703 - rec_loss: 22.1416 - 2s/epoch - 4ms/step
# Epoch 19/100
# 469/469 - 2s - total_loss: 27.0705 - reg_loss: 5.0470 - rec_loss: 22.0235 - 2s/epoch - 4ms/step
# Epoch 20/100
# 469/469 - 2s - total_loss: 27.0122 - reg_loss: 5.1058 - rec_loss: 21.9064 - 2s/epoch - 4ms/step
# Epoch 21/100
# 469/469 - 2s - total_loss: 26.9448 - reg_loss: 5.1388 - rec_loss: 21.8060 - 2s/epoch - 4ms/step
# Epoch 22/100
# 469/469 - 2s - total_loss: 26.8962 - reg_loss: 5.1932 - rec_loss: 21.7030 - 2s/epoch - 4ms/step
# Epoch 23/100
# 469/469 - 2s - total_loss: 26.8465 - reg_loss: 5.2265 - rec_loss: 21.6200 - 2s/epoch - 4ms/step
# Epoch 24/100
# 469/469 - 2s - total_loss: 26.7944 - reg_loss: 5.2646 - rec_loss: 21.5298 - 2s/epoch - 4ms/step
# Epoch 25/100
# 469/469 - 2s - total_loss: 26.7561 - reg_loss: 5.2962 - rec_loss: 21.4598 - 2s/epoch - 4ms/step
# Epoch 26/100
# 469/469 - 2s - total_loss: 26.7197 - reg_loss: 5.3354 - rec_loss: 21.3843 - 2s/epoch - 4ms/step
# Epoch 27/100
# 469/469 - 2s - total_loss: 26.6952 - reg_loss: 5.3719 - rec_loss: 21.3233 - 2s/epoch - 4ms/step
# Epoch 28/100
# 469/469 - 2s - total_loss: 26.6629 - reg_loss: 5.4057 - rec_loss: 21.2573 - 2s/epoch - 4ms/step
# Epoch 29/100
# 469/469 - 2s - total_loss: 26.6185 - reg_loss: 5.4194 - rec_loss: 21.1991 - 2s/epoch - 4ms/step
# Epoch 30/100
# 469/469 - 2s - total_loss: 26.5879 - reg_loss: 5.4618 - rec_loss: 21.1260 - 2s/epoch - 4ms/step
# Epoch 31/100
# 469/469 - 2s - total_loss: 26.5713 - reg_loss: 5.4836 - rec_loss: 21.0877 - 2s/epoch - 5ms/step
# Epoch 32/100
# 469/469 - 2s - total_loss: 26.5310 - reg_loss: 5.5007 - rec_loss: 21.0303 - 2s/epoch - 4ms/step
# Epoch 33/100
# 469/469 - 2s - total_loss: 26.5164 - reg_loss: 5.5337 - rec_loss: 20.9827 - 2s/epoch - 4ms/step
# Epoch 34/100
# 469/469 - 2s - total_loss: 26.4957 - reg_loss: 5.5536 - rec_loss: 20.9422 - 2s/epoch - 4ms/step
# Epoch 35/100
# 469/469 - 2s - total_loss: 26.4648 - reg_loss: 5.5765 - rec_loss: 20.8884 - 2s/epoch - 4ms/step
# Epoch 36/100
# 469/469 - 2s - total_loss: 26.4456 - reg_loss: 5.6089 - rec_loss: 20.8368 - 2s/epoch - 5ms/step
# Epoch 37/100
# 469/469 - 2s - total_loss: 26.4246 - reg_loss: 5.6251 - rec_loss: 20.7995 - 2s/epoch - 5ms/step
# Epoch 38/100
# 469/469 - 2s - total_loss: 26.3762 - reg_loss: 5.6253 - rec_loss: 20.7508 - 2s/epoch - 4ms/step
# Epoch 39/100
# 469/469 - 2s - total_loss: 26.3724 - reg_loss: 5.6624 - rec_loss: 20.7100 - 2s/epoch - 4ms/step
# Epoch 40/100
# 469/469 - 2s - total_loss: 26.3296 - reg_loss: 5.6576 - rec_loss: 20.6720 - 2s/epoch - 4ms/step
# Epoch 41/100
# 469/469 - 2s - total_loss: 26.3349 - reg_loss: 5.6973 - rec_loss: 20.6376 - 2s/epoch - 4ms/step
# Epoch 42/100
# 469/469 - 2s - total_loss: 26.3243 - reg_loss: 5.7280 - rec_loss: 20.5964 - 2s/epoch - 5ms/step
# Epoch 43/100
# 469/469 - 2s - total_loss: 26.2869 - reg_loss: 5.7285 - rec_loss: 20.5583 - 2s/epoch - 4ms/step
# Epoch 44/100
# 469/469 - 2s - total_loss: 26.2781 - reg_loss: 5.7512 - rec_loss: 20.5269 - 2s/epoch - 4ms/step
# Epoch 45/100
# 469/469 - 2s - total_loss: 26.2622 - reg_loss: 5.7724 - rec_loss: 20.4899 - 2s/epoch - 4ms/step
# Epoch 46/100
# 469/469 - 2s - total_loss: 26.2473 - reg_loss: 5.7908 - rec_loss: 20.4564 - 2s/epoch - 5ms/step
# Epoch 47/100
# 469/469 - 2s - total_loss: 26.2213 - reg_loss: 5.7961 - rec_loss: 20.4252 - 2s/epoch - 4ms/step
# Epoch 48/100
# 469/469 - 2s - total_loss: 26.2091 - reg_loss: 5.8234 - rec_loss: 20.3857 - 2s/epoch - 4ms/step
# Epoch 49/100
# 469/469 - 2s - total_loss: 26.1938 - reg_loss: 5.8382 - rec_loss: 20.3555 - 2s/epoch - 4ms/step
# Epoch 50/100
# 469/469 - 2s - total_loss: 26.1702 - reg_loss: 5.8471 - rec_loss: 20.3231 - 2s/epoch - 4ms/step
# Epoch 51/100
# 469/469 - 2s - total_loss: 26.1673 - reg_loss: 5.8740 - rec_loss: 20.2932 - 2s/epoch - 4ms/step
# Epoch 52/100
# 469/469 - 2s - total_loss: 26.1508 - reg_loss: 5.8862 - rec_loss: 20.2647 - 2s/epoch - 4ms/step
# Epoch 53/100
# 469/469 - 2s - total_loss: 26.1186 - reg_loss: 5.8906 - rec_loss: 20.2280 - 2s/epoch - 5ms/step
# Epoch 54/100
# 469/469 - 2s - total_loss: 26.1282 - reg_loss: 5.9384 - rec_loss: 20.1897 - 2s/epoch - 4ms/step
# Epoch 55/100
# 469/469 - 2s - total_loss: 26.0923 - reg_loss: 5.9251 - rec_loss: 20.1672 - 2s/epoch - 4ms/step
# Epoch 56/100
# 469/469 - 2s - total_loss: 26.0941 - reg_loss: 5.9521 - rec_loss: 20.1420 - 2s/epoch - 4ms/step
# Epoch 57/100
# 469/469 - 2s - total_loss: 26.0666 - reg_loss: 5.9694 - rec_loss: 20.0972 - 2s/epoch - 4ms/step
# Epoch 58/100
# 469/469 - 2s - total_loss: 26.0507 - reg_loss: 5.9762 - rec_loss: 20.0746 - 2s/epoch - 4ms/step
# Epoch 59/100
# 469/469 - 2s - total_loss: 26.0428 - reg_loss: 5.9912 - rec_loss: 20.0516 - 2s/epoch - 4ms/step
# Epoch 60/100
# 469/469 - 2s - total_loss: 26.0473 - reg_loss: 6.0261 - rec_loss: 20.0212 - 2s/epoch - 4ms/step
# Epoch 61/100
# 469/469 - 2s - total_loss: 26.0245 - reg_loss: 6.0307 - rec_loss: 19.9938 - 2s/epoch - 4ms/step
# Epoch 62/100
# 469/469 - 2s - total_loss: 26.0092 - reg_loss: 6.0520 - rec_loss: 19.9572 - 2s/epoch - 4ms/step
# Epoch 63/100
# 469/469 - 2s - total_loss: 26.0085 - reg_loss: 6.0754 - rec_loss: 19.9331 - 2s/epoch - 4ms/step
# Epoch 64/100
# 469/469 - 2s - total_loss: 25.9922 - reg_loss: 6.0872 - rec_loss: 19.9050 - 2s/epoch - 4ms/step
# Epoch 65/100
# 469/469 - 2s - total_loss: 25.9844 - reg_loss: 6.1145 - rec_loss: 19.8699 - 2s/epoch - 4ms/step
# Epoch 66/100
# 469/469 - 2s - total_loss: 25.9471 - reg_loss: 6.1039 - rec_loss: 19.8433 - 2s/epoch - 4ms/step
# Epoch 67/100
# 469/469 - 2s - total_loss: 25.9545 - reg_loss: 6.1376 - rec_loss: 19.8168 - 2s/epoch - 4ms/step
# Epoch 68/100
# 469/469 - 2s - total_loss: 25.9386 - reg_loss: 6.1587 - rec_loss: 19.7799 - 2s/epoch - 4ms/step
# Epoch 69/100
# 469/469 - 2s - total_loss: 25.9453 - reg_loss: 6.1867 - rec_loss: 19.7586 - 2s/epoch - 4ms/step
# Epoch 70/100
# 469/469 - 2s - total_loss: 25.9130 - reg_loss: 6.1992 - rec_loss: 19.7138 - 2s/epoch - 4ms/step
# Epoch 71/100
# 469/469 - 2s - total_loss: 25.9032 - reg_loss: 6.2085 - rec_loss: 19.6947 - 2s/epoch - 4ms/step
# Epoch 72/100
# 469/469 - 2s - total_loss: 25.8810 - reg_loss: 6.2263 - rec_loss: 19.6547 - 2s/epoch - 4ms/step
# Epoch 73/100
# 469/469 - 2s - total_loss: 25.8748 - reg_loss: 6.2414 - rec_loss: 19.6334 - 2s/epoch - 4ms/step
# Epoch 74/100
# 469/469 - 2s - total_loss: 25.8707 - reg_loss: 6.2633 - rec_loss: 19.6074 - 2s/epoch - 4ms/step
# Epoch 75/100
# 469/469 - 2s - total_loss: 25.8516 - reg_loss: 6.2660 - rec_loss: 19.5856 - 2s/epoch - 4ms/step
# Epoch 76/100
# 469/469 - 2s - total_loss: 25.8583 - reg_loss: 6.3003 - rec_loss: 19.5581 - 2s/epoch - 4ms/step
# Epoch 77/100
# 469/469 - 2s - total_loss: 25.8286 - reg_loss: 6.3067 - rec_loss: 19.5218 - 2s/epoch - 4ms/step
# Epoch 78/100
# 469/469 - 2s - total_loss: 25.8271 - reg_loss: 6.3237 - rec_loss: 19.5034 - 2s/epoch - 4ms/step
# Epoch 79/100
# 469/469 - 2s - total_loss: 25.8125 - reg_loss: 6.3360 - rec_loss: 19.4765 - 2s/epoch - 4ms/step
# Epoch 80/100
# 469/469 - 2s - total_loss: 25.7851 - reg_loss: 6.3364 - rec_loss: 19.4487 - 2s/epoch - 5ms/step
# Epoch 81/100
# 469/469 - 2s - total_loss: 25.7906 - reg_loss: 6.3626 - rec_loss: 19.4280 - 2s/epoch - 4ms/step
# Epoch 82/100
# 469/469 - 2s - total_loss: 25.7839 - reg_loss: 6.3873 - rec_loss: 19.3967 - 2s/epoch - 4ms/step
# Epoch 83/100
# 469/469 - 2s - total_loss: 25.7837 - reg_loss: 6.4098 - rec_loss: 19.3739 - 2s/epoch - 4ms/step
# Epoch 84/100
# 469/469 - 2s - total_loss: 25.7521 - reg_loss: 6.3926 - rec_loss: 19.3595 - 2s/epoch - 4ms/step
# Epoch 85/100
# 469/469 - 2s - total_loss: 25.7463 - reg_loss: 6.4060 - rec_loss: 19.3403 - 2s/epoch - 4ms/step
# Epoch 86/100
# 469/469 - 2s - total_loss: 25.7269 - reg_loss: 6.4131 - rec_loss: 19.3138 - 2s/epoch - 4ms/step
# Epoch 87/100
# 469/469 - 2s - total_loss: 25.7298 - reg_loss: 6.4246 - rec_loss: 19.3053 - 2s/epoch - 4ms/step
# Epoch 88/100
# 469/469 - 2s - total_loss: 25.7095 - reg_loss: 6.4338 - rec_loss: 19.2758 - 2s/epoch - 4ms/step
# Epoch 89/100
# 469/469 - 2s - total_loss: 25.7100 - reg_loss: 6.4530 - rec_loss: 19.2570 - 2s/epoch - 4ms/step
# Epoch 90/100
# 469/469 - 2s - total_loss: 25.7069 - reg_loss: 6.4566 - rec_loss: 19.2503 - 2s/epoch - 4ms/step
# Epoch 91/100
# 469/469 - 2s - total_loss: 25.6980 - reg_loss: 6.4742 - rec_loss: 19.2238 - 2s/epoch - 5ms/step
# Epoch 92/100
# 469/469 - 2s - total_loss: 25.6864 - reg_loss: 6.4669 - rec_loss: 19.2195 - 2s/epoch - 4ms/step
# Epoch 93/100
# 469/469 - 2s - total_loss: 25.6880 - reg_loss: 6.4974 - rec_loss: 19.1906 - 2s/epoch - 4ms/step
# Epoch 94/100
# 469/469 - 2s - total_loss: 25.6725 - reg_loss: 6.4885 - rec_loss: 19.1840 - 2s/epoch - 4ms/step
# Epoch 95/100
# 469/469 - 2s - total_loss: 25.6730 - reg_loss: 6.5170 - rec_loss: 19.1560 - 2s/epoch - 4ms/step
# Epoch 96/100
# 469/469 - 2s - total_loss: 25.6549 - reg_loss: 6.5168 - rec_loss: 19.1382 - 2s/epoch - 4ms/step
# Epoch 97/100
# 469/469 - 2s - total_loss: 25.6666 - reg_loss: 6.5285 - rec_loss: 19.1381 - 2s/epoch - 4ms/step
# Epoch 98/100
# 469/469 - 2s - total_loss: 25.6436 - reg_loss: 6.5347 - rec_loss: 19.1089 - 2s/epoch - 4ms/step
# Epoch 99/100
# 469/469 - 2s - total_loss: 25.6524 - reg_loss: 6.5478 - rec_loss: 19.1046 - 2s/epoch - 4ms/step
# Epoch 100/100
# 469/469 - 2s - total_loss: 25.6358 - reg_loss: 6.5518 - rec_loss: 19.0841 - 2s/epoch - 4ms/step

# %% [markdown]
# ## Show the resulting embeddings

# %%
if LATENT_DIM == 2:
    z_train = model_vae.encode_only_mu(x_train)
    draw_embeddings(z_train, y_train)
else:
    z_test = model_vae.encode_only_mu(x_test)
    tsne = TSNE(n_components=2, init='pca')
    z_tsne = tsne.fit_transform(z_test[0:2000])
    draw_embeddings(z_tsne, y_test[0:2000], alpha=0.7)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
compare_orig_vs_pretrained = compare_reconstructed_images_MNIST(x_test, model_vae.encoder, model_vae.decoder, ("Original", "Pretrained"))

# %% [markdown]
# # Fine-tune the model (K-Means)

# %% [markdown]
# ## Construct the full VaDE model

# %% [markdown]
# Load the pretrained weights for the encoder and decoder modules:

# %%
model_vae.load_weights("model_weights/cvae/pretrained/vae")

# %% [markdown]
# Construct the VaDE model:

# %%
N_CLUSTERS = 10
CLUSTERING_LOSS_WEIGHT = 1

EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 1e-4
SCHEDULE = 10
DELTA_THRESHOLD = 0.001

model_cvae = get_clustering_vae_model(model_vae, N_CLUSTERS, CLUSTERING_LOSS_WEIGHT)

# %% [markdown]
# ## Initialize the parameters

# %% [markdown]
# Initialize the model parameters from a K-means:

# %%
z_train = model_cvae.encode_only_mu(x_train)

kmeans = KMeans(n_clusters=N_CLUSTERS, n_init=30)
kmeans.fit(z_train)

for weight in model_cvae.trainable_weights:
    if weight.name == "centroids:0":
        weight.assign(K.constant(kmeans.cluster_centers_))

# %% [markdown]
# Initialize `p`, the auxiliary distribution to compute the clustering loss, and `c_last`, the last cluster assignments to compute the number of points that changed clusters.

# %%
p = compute_p(to_categorical(kmeans.labels_))
c_last = kmeans.labels_

# %% [markdown]
# Evaluate the clustering performance before fine-tunning the model:

# %%
# Show the embeddings and the cluster centroids on the latent space
if LATENT_DIM == 2:
    z_train = model_vae.encode_only_mu(x_train)
    draw_embeddings(z_train, y_train, centroids=kmeans.cluster_centers_)

# %%
evaluate_model(model_cvae.classify, model_cvae.encode_only_mu, x_test, y_test)
# Out:
# Acc: 0.563100
# ARI: 0.344431
# AMI: 0.452036
# Sil: 0.118431

# %% [markdown]
# ## Train the model

# %% [markdown]
# Train the model:

# %%
def cvae_callback(epoch, logs):
    global p
    global c_last
    
    if (epoch+1) % SCHEDULE == 0:
        q = model_cvae.soft_assignment(x_train)
        p = compute_p(q)
        
        c_new = q.numpy().argmax(1)
        delta = compute_delta(c_new, c_last)
        c_last = np.copy(c_new)
        print(f"Delta: {delta:.3f}")
        if (delta < DELTA_THRESHOLD):
            model_cvae.stop_training = True
            
callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=cvae_callback)

# %%
model_cvae.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE))

model_cvae.fit(x_train, p,
               epochs=EPOCHS,
               batch_size=BATCH_SIZE,
               callbacks = callback,
               verbose=2,
              )

model_cvae.save_weights("model_weights/cvae/finetuned/cvae_kmeans")

model_cvae.load_weights("model_weights/cvae/finetuned/cvae_kmeans")
# Out:
# Epoch 1/100
# 469/469 - 4s - total_loss: 36.9037 - reg_loss: 6.6944 - rec_loss: 18.9964 - clust_loss: 11.2128 - 4s/epoch - 9ms/step
# Epoch 2/100
# 469/469 - 3s - total_loss: 36.8432 - reg_loss: 6.7104 - rec_loss: 18.9845 - clust_loss: 11.1483 - 3s/epoch - 6ms/step
# Epoch 3/100
# 469/469 - 3s - total_loss: 36.7904 - reg_loss: 6.7364 - rec_loss: 18.9590 - clust_loss: 11.0950 - 3s/epoch - 6ms/step
# Epoch 4/100
# 469/469 - 3s - total_loss: 36.7373 - reg_loss: 6.7580 - rec_loss: 18.9370 - clust_loss: 11.0423 - 3s/epoch - 6ms/step
# Epoch 5/100
# 469/469 - 3s - total_loss: 36.7010 - reg_loss: 6.7700 - rec_loss: 18.9372 - clust_loss: 10.9937 - 3s/epoch - 6ms/step
# Epoch 6/100
# 469/469 - 3s - total_loss: 36.6581 - reg_loss: 6.7975 - rec_loss: 18.9118 - clust_loss: 10.9489 - 3s/epoch - 6ms/step
# Epoch 7/100
# 469/469 - 3s - total_loss: 36.6341 - reg_loss: 6.8389 - rec_loss: 18.8863 - clust_loss: 10.9089 - 3s/epoch - 6ms/step
# Epoch 8/100
# 469/469 - 3s - total_loss: 36.5966 - reg_loss: 6.8578 - rec_loss: 18.8768 - clust_loss: 10.8620 - 3s/epoch - 6ms/step
# Epoch 9/100
# 469/469 - 3s - total_loss: 36.5620 - reg_loss: 6.8816 - rec_loss: 18.8586 - clust_loss: 10.8217 - 3s/epoch - 6ms/step
# Epoch 10/100
# Delta: 0.149
# 469/469 - 3s - total_loss: 36.5373 - reg_loss: 6.9023 - rec_loss: 18.8535 - clust_loss: 10.7814 - 3s/epoch - 7ms/step
# Epoch 11/100
# 469/469 - 3s - total_loss: 36.4904 - reg_loss: 6.9172 - rec_loss: 18.8265 - clust_loss: 10.7467 - 3s/epoch - 6ms/step
# Epoch 12/100
# 469/469 - 3s - total_loss: 36.4786 - reg_loss: 6.9499 - rec_loss: 18.8202 - clust_loss: 10.7085 - 3s/epoch - 7ms/step
# Epoch 13/100
# 469/469 - 3s - total_loss: 36.4414 - reg_loss: 6.9536 - rec_loss: 18.8094 - clust_loss: 10.6783 - 3s/epoch - 6ms/step
# Epoch 14/100
# 469/469 - 3s - total_loss: 36.4158 - reg_loss: 6.9700 - rec_loss: 18.7964 - clust_loss: 10.6494 - 3s/epoch - 6ms/step
# Epoch 15/100
# 469/469 - 3s - total_loss: 36.3838 - reg_loss: 6.9845 - rec_loss: 18.7819 - clust_loss: 10.6174 - 3s/epoch - 7ms/step
# Epoch 16/100
# 469/469 - 3s - total_loss: 36.3672 - reg_loss: 6.9981 - rec_loss: 18.7747 - clust_loss: 10.5944 - 3s/epoch - 7ms/step
# Epoch 17/100
# 469/469 - 3s - total_loss: 36.3408 - reg_loss: 7.0215 - rec_loss: 18.7528 - clust_loss: 10.5664 - 3s/epoch - 6ms/step
# Epoch 18/100
# 469/469 - 3s - total_loss: 36.3211 - reg_loss: 7.0352 - rec_loss: 18.7476 - clust_loss: 10.5384 - 3s/epoch - 6ms/step
# Epoch 19/100
# 469/469 - 3s - total_loss: 36.3100 - reg_loss: 7.0668 - rec_loss: 18.7292 - clust_loss: 10.5140 - 3s/epoch - 6ms/step
# Epoch 20/100
# Delta: 0.197
# 469/469 - 3s - total_loss: 36.2913 - reg_loss: 7.0730 - rec_loss: 18.7203 - clust_loss: 10.4981 - 3s/epoch - 7ms/step
# Epoch 21/100
# 469/469 - 3s - total_loss: 36.2805 - reg_loss: 7.0925 - rec_loss: 18.7121 - clust_loss: 10.4759 - 3s/epoch - 6ms/step
# Epoch 22/100
# 469/469 - 3s - total_loss: 36.2718 - reg_loss: 7.1192 - rec_loss: 18.6998 - clust_loss: 10.4529 - 3s/epoch - 6ms/step
# Epoch 23/100
# 469/469 - 3s - total_loss: 36.2550 - reg_loss: 7.1196 - rec_loss: 18.6923 - clust_loss: 10.4432 - 3s/epoch - 7ms/step
# Epoch 24/100
# 469/469 - 3s - total_loss: 36.2390 - reg_loss: 7.1284 - rec_loss: 18.6830 - clust_loss: 10.4276 - 3s/epoch - 6ms/step
# Epoch 25/100
# 469/469 - 3s - total_loss: 36.2257 - reg_loss: 7.1478 - rec_loss: 18.6675 - clust_loss: 10.4104 - 3s/epoch - 7ms/step
# Epoch 26/100
# 469/469 - 3s - total_loss: 36.2189 - reg_loss: 7.1550 - rec_loss: 18.6638 - clust_loss: 10.4001 - 3s/epoch - 7ms/step
# Epoch 27/100
# 469/469 - 3s - total_loss: 36.1978 - reg_loss: 7.1511 - rec_loss: 18.6583 - clust_loss: 10.3884 - 3s/epoch - 6ms/step
# Epoch 28/100
# 469/469 - 3s - total_loss: 36.1883 - reg_loss: 7.1681 - rec_loss: 18.6487 - clust_loss: 10.3714 - 3s/epoch - 7ms/step
# Epoch 29/100
# 469/469 - 3s - total_loss: 36.1846 - reg_loss: 7.1775 - rec_loss: 18.6376 - clust_loss: 10.3695 - 3s/epoch - 7ms/step
# Epoch 30/100
# Delta: 0.186
# 469/469 - 3s - total_loss: 36.1552 - reg_loss: 7.1824 - rec_loss: 18.6189 - clust_loss: 10.3539 - 3s/epoch - 7ms/step
# Epoch 31/100
# 469/469 - 3s - total_loss: 36.1657 - reg_loss: 7.2094 - rec_loss: 18.6130 - clust_loss: 10.3432 - 3s/epoch - 6ms/step
# Epoch 32/100
# 469/469 - 3s - total_loss: 36.1532 - reg_loss: 7.2160 - rec_loss: 18.6043 - clust_loss: 10.3330 - 3s/epoch - 7ms/step
# Epoch 33/100
# 469/469 - 3s - total_loss: 36.1474 - reg_loss: 7.2257 - rec_loss: 18.5922 - clust_loss: 10.3295 - 3s/epoch - 6ms/step
# Epoch 34/100
# 469/469 - 3s - total_loss: 36.1356 - reg_loss: 7.2316 - rec_loss: 18.5834 - clust_loss: 10.3206 - 3s/epoch - 7ms/step
# Epoch 35/100
# 469/469 - 3s - total_loss: 36.1318 - reg_loss: 7.2446 - rec_loss: 18.5709 - clust_loss: 10.3163 - 3s/epoch - 7ms/step
# Epoch 36/100
# 469/469 - 3s - total_loss: 36.1271 - reg_loss: 7.2514 - rec_loss: 18.5703 - clust_loss: 10.3055 - 3s/epoch - 6ms/step
# Epoch 37/100
# 469/469 - 3s - total_loss: 36.1379 - reg_loss: 7.2677 - rec_loss: 18.5665 - clust_loss: 10.3036 - 3s/epoch - 6ms/step
# Epoch 38/100
# 469/469 - 3s - total_loss: 36.1076 - reg_loss: 7.2580 - rec_loss: 18.5508 - clust_loss: 10.2988 - 3s/epoch - 6ms/step
# Epoch 39/100
# 469/469 - 3s - total_loss: 36.1093 - reg_loss: 7.2754 - rec_loss: 18.5460 - clust_loss: 10.2879 - 3s/epoch - 6ms/step
# Epoch 40/100
# Delta: 0.181
# 469/469 - 3s - total_loss: 36.1020 - reg_loss: 7.2883 - rec_loss: 18.5284 - clust_loss: 10.2853 - 3s/epoch - 7ms/step
# Epoch 41/100
# 469/469 - 3s - total_loss: 36.0905 - reg_loss: 7.2898 - rec_loss: 18.5211 - clust_loss: 10.2796 - 3s/epoch - 6ms/step
# Epoch 42/100
# 469/469 - 3s - total_loss: 36.0911 - reg_loss: 7.2967 - rec_loss: 18.5163 - clust_loss: 10.2782 - 3s/epoch - 7ms/step
# Epoch 43/100
# 469/469 - 3s - total_loss: 36.0844 - reg_loss: 7.3045 - rec_loss: 18.5029 - clust_loss: 10.2770 - 3s/epoch - 6ms/step
# Epoch 44/100
# 469/469 - 3s - total_loss: 36.0848 - reg_loss: 7.3133 - rec_loss: 18.5035 - clust_loss: 10.2679 - 3s/epoch - 6ms/step
# Epoch 45/100
# 469/469 - 3s - total_loss: 36.0726 - reg_loss: 7.3121 - rec_loss: 18.4918 - clust_loss: 10.2688 - 3s/epoch - 6ms/step
# Epoch 46/100
# 469/469 - 3s - total_loss: 36.0768 - reg_loss: 7.3181 - rec_loss: 18.4907 - clust_loss: 10.2681 - 3s/epoch - 6ms/step
# Epoch 47/100
# 469/469 - 3s - total_loss: 36.0624 - reg_loss: 7.3230 - rec_loss: 18.4751 - clust_loss: 10.2644 - 3s/epoch - 6ms/step
# Epoch 48/100
# 469/469 - 3s - total_loss: 36.0543 - reg_loss: 7.3201 - rec_loss: 18.4738 - clust_loss: 10.2603 - 3s/epoch - 6ms/step
# Epoch 49/100
# 469/469 - 3s - total_loss: 36.0561 - reg_loss: 7.3336 - rec_loss: 18.4665 - clust_loss: 10.2560 - 3s/epoch - 6ms/step
# Epoch 50/100
# Delta: 0.178
# 469/469 - 4s - total_loss: 36.0585 - reg_loss: 7.3422 - rec_loss: 18.4597 - clust_loss: 10.2566 - 4s/epoch - 8ms/step
# Epoch 51/100
# 469/469 - 3s - total_loss: 36.0450 - reg_loss: 7.3476 - rec_loss: 18.4492 - clust_loss: 10.2482 - 3s/epoch - 6ms/step
# Epoch 52/100
# 469/469 - 3s - total_loss: 36.0631 - reg_loss: 7.3627 - rec_loss: 18.4496 - clust_loss: 10.2509 - 3s/epoch - 6ms/step
# Epoch 53/100
# 469/469 - 3s - total_loss: 36.0335 - reg_loss: 7.3522 - rec_loss: 18.4361 - clust_loss: 10.2452 - 3s/epoch - 7ms/step
# Epoch 54/100
# 469/469 - 3s - total_loss: 36.0367 - reg_loss: 7.3671 - rec_loss: 18.4269 - clust_loss: 10.2426 - 3s/epoch - 6ms/step
# Epoch 55/100
# 469/469 - 3s - total_loss: 36.0369 - reg_loss: 7.3761 - rec_loss: 18.4217 - clust_loss: 10.2391 - 3s/epoch - 6ms/step
# Epoch 56/100
# 469/469 - 3s - total_loss: 36.0109 - reg_loss: 7.3544 - rec_loss: 18.4162 - clust_loss: 10.2403 - 3s/epoch - 6ms/step
# Epoch 57/100
# 469/469 - 3s - total_loss: 36.0304 - reg_loss: 7.3784 - rec_loss: 18.4127 - clust_loss: 10.2392 - 3s/epoch - 6ms/step
# Epoch 58/100
# 469/469 - 3s - total_loss: 36.0296 - reg_loss: 7.3850 - rec_loss: 18.4101 - clust_loss: 10.2346 - 3s/epoch - 6ms/step
# Epoch 59/100
# 469/469 - 3s - total_loss: 36.0215 - reg_loss: 7.3847 - rec_loss: 18.4059 - clust_loss: 10.2308 - 3s/epoch - 6ms/step
# Epoch 60/100
# Delta: 0.177
# 469/469 - 3s - total_loss: 36.0039 - reg_loss: 7.3755 - rec_loss: 18.3972 - clust_loss: 10.2312 - 3s/epoch - 7ms/step
# Epoch 61/100
# 469/469 - 3s - total_loss: 36.0155 - reg_loss: 7.3981 - rec_loss: 18.3861 - clust_loss: 10.2314 - 3s/epoch - 6ms/step
# Epoch 62/100
# 469/469 - 3s - total_loss: 36.0184 - reg_loss: 7.4049 - rec_loss: 18.3806 - clust_loss: 10.2330 - 3s/epoch - 7ms/step
# Epoch 63/100
# 469/469 - 3s - total_loss: 36.0095 - reg_loss: 7.4093 - rec_loss: 18.3723 - clust_loss: 10.2280 - 3s/epoch - 7ms/step
# Epoch 64/100
# 469/469 - 3s - total_loss: 35.9935 - reg_loss: 7.4099 - rec_loss: 18.3540 - clust_loss: 10.2296 - 3s/epoch - 7ms/step
# Epoch 65/100
# 469/469 - 3s - total_loss: 36.0073 - reg_loss: 7.4134 - rec_loss: 18.3643 - clust_loss: 10.2296 - 3s/epoch - 7ms/step
# Epoch 66/100
# 469/469 - 3s - total_loss: 35.9853 - reg_loss: 7.4031 - rec_loss: 18.3517 - clust_loss: 10.2304 - 3s/epoch - 7ms/step
# Epoch 67/100
# 469/469 - 3s - total_loss: 35.9727 - reg_loss: 7.4052 - rec_loss: 18.3508 - clust_loss: 10.2168 - 3s/epoch - 7ms/step
# Epoch 68/100
# 469/469 - 3s - total_loss: 36.0126 - reg_loss: 7.4357 - rec_loss: 18.3495 - clust_loss: 10.2275 - 3s/epoch - 7ms/step
# Epoch 69/100
# 469/469 - 3s - total_loss: 35.9734 - reg_loss: 7.4145 - rec_loss: 18.3374 - clust_loss: 10.2215 - 3s/epoch - 6ms/step
# Epoch 70/100
# Delta: 0.177
# 469/469 - 3s - total_loss: 35.9796 - reg_loss: 7.4344 - rec_loss: 18.3299 - clust_loss: 10.2153 - 3s/epoch - 7ms/step
# Epoch 71/100
# 469/469 - 3s - total_loss: 35.9821 - reg_loss: 7.4288 - rec_loss: 18.3302 - clust_loss: 10.2231 - 3s/epoch - 6ms/step
# Epoch 72/100
# 469/469 - 3s - total_loss: 35.9825 - reg_loss: 7.4442 - rec_loss: 18.3235 - clust_loss: 10.2148 - 3s/epoch - 7ms/step
# Epoch 73/100
# 469/469 - 3s - total_loss: 35.9680 - reg_loss: 7.4432 - rec_loss: 18.3085 - clust_loss: 10.2163 - 3s/epoch - 7ms/step
# Epoch 74/100
# 469/469 - 3s - total_loss: 35.9723 - reg_loss: 7.4469 - rec_loss: 18.3093 - clust_loss: 10.2161 - 3s/epoch - 6ms/step
# Epoch 75/100
# 469/469 - 3s - total_loss: 35.9685 - reg_loss: 7.4428 - rec_loss: 18.3061 - clust_loss: 10.2195 - 3s/epoch - 7ms/step
# Epoch 76/100
# 469/469 - 3s - total_loss: 35.9752 - reg_loss: 7.4565 - rec_loss: 18.3004 - clust_loss: 10.2183 - 3s/epoch - 6ms/step
# Epoch 77/100
# 469/469 - 3s - total_loss: 35.9453 - reg_loss: 7.4463 - rec_loss: 18.2862 - clust_loss: 10.2128 - 3s/epoch - 6ms/step
# Epoch 78/100
# 469/469 - 3s - total_loss: 35.9705 - reg_loss: 7.4641 - rec_loss: 18.2895 - clust_loss: 10.2170 - 3s/epoch - 7ms/step
# Epoch 79/100
# 469/469 - 3s - total_loss: 35.9535 - reg_loss: 7.4628 - rec_loss: 18.2787 - clust_loss: 10.2120 - 3s/epoch - 6ms/step
# Epoch 80/100
# Delta: 0.179
# 469/469 - 3s - total_loss: 35.9614 - reg_loss: 7.4718 - rec_loss: 18.2767 - clust_loss: 10.2128 - 3s/epoch - 7ms/step
# Epoch 81/100
# 469/469 - 3s - total_loss: 35.9421 - reg_loss: 7.4671 - rec_loss: 18.2606 - clust_loss: 10.2143 - 3s/epoch - 7ms/step
# Epoch 82/100
# 469/469 - 3s - total_loss: 35.9562 - reg_loss: 7.4817 - rec_loss: 18.2644 - clust_loss: 10.2102 - 3s/epoch - 7ms/step
# Epoch 83/100
# 469/469 - 3s - total_loss: 35.9434 - reg_loss: 7.4845 - rec_loss: 18.2507 - clust_loss: 10.2082 - 3s/epoch - 6ms/step
# Epoch 84/100
# 469/469 - 3s - total_loss: 35.9414 - reg_loss: 7.4825 - rec_loss: 18.2502 - clust_loss: 10.2087 - 3s/epoch - 7ms/step
# Epoch 85/100
# 469/469 - 3s - total_loss: 35.9453 - reg_loss: 7.4879 - rec_loss: 18.2506 - clust_loss: 10.2068 - 3s/epoch - 6ms/step
# Epoch 86/100
# 469/469 - 3s - total_loss: 35.9475 - reg_loss: 7.4987 - rec_loss: 18.2413 - clust_loss: 10.2075 - 3s/epoch - 6ms/step
# Epoch 87/100
# 469/469 - 3s - total_loss: 35.9347 - reg_loss: 7.4951 - rec_loss: 18.2330 - clust_loss: 10.2067 - 3s/epoch - 7ms/step
# Epoch 88/100
# 469/469 - 3s - total_loss: 35.9318 - reg_loss: 7.4994 - rec_loss: 18.2209 - clust_loss: 10.2115 - 3s/epoch - 6ms/step
# Epoch 89/100
# 469/469 - 3s - total_loss: 35.9225 - reg_loss: 7.4954 - rec_loss: 18.2264 - clust_loss: 10.2007 - 3s/epoch - 6ms/step
# Epoch 90/100
# Delta: 0.179
# 469/469 - 3s - total_loss: 35.9336 - reg_loss: 7.5084 - rec_loss: 18.2214 - clust_loss: 10.2038 - 3s/epoch - 7ms/step
# Epoch 91/100
# 469/469 - 3s - total_loss: 35.9342 - reg_loss: 7.5066 - rec_loss: 18.2226 - clust_loss: 10.2049 - 3s/epoch - 6ms/step
# Epoch 92/100
# 469/469 - 3s - total_loss: 35.9317 - reg_loss: 7.5139 - rec_loss: 18.2099 - clust_loss: 10.2079 - 3s/epoch - 6ms/step
# Epoch 93/100
# 469/469 - 3s - total_loss: 35.9200 - reg_loss: 7.5087 - rec_loss: 18.2139 - clust_loss: 10.1974 - 3s/epoch - 6ms/step
# Epoch 94/100
# 469/469 - 3s - total_loss: 35.9117 - reg_loss: 7.5095 - rec_loss: 18.1996 - clust_loss: 10.2026 - 3s/epoch - 7ms/step
# Epoch 95/100
# 469/469 - 3s - total_loss: 35.9076 - reg_loss: 7.5089 - rec_loss: 18.1959 - clust_loss: 10.2028 - 3s/epoch - 7ms/step
# Epoch 96/100
# 469/469 - 3s - total_loss: 35.9264 - reg_loss: 7.5280 - rec_loss: 18.1914 - clust_loss: 10.2070 - 3s/epoch - 6ms/step
# Epoch 97/100
# 469/469 - 3s - total_loss: 35.9072 - reg_loss: 7.5238 - rec_loss: 18.1870 - clust_loss: 10.1963 - 3s/epoch - 6ms/step
# Epoch 98/100
# 469/469 - 3s - total_loss: 35.9097 - reg_loss: 7.5328 - rec_loss: 18.1739 - clust_loss: 10.2031 - 3s/epoch - 6ms/step
# Epoch 99/100
# 469/469 - 3s - total_loss: 35.9109 - reg_loss: 7.5332 - rec_loss: 18.1759 - clust_loss: 10.2017 - 3s/epoch - 7ms/step
# Epoch 100/100
# Delta: 0.178
# 469/469 - 3s - total_loss: 35.9142 - reg_loss: 7.5338 - rec_loss: 18.1817 - clust_loss: 10.1987 - 3s/epoch - 7ms/step

# %% [markdown]
# ## Show the resulting embeddings

# %%
z_test = model_cvae.encode_only_mu(x_test)
c_test = model_cvae.classify(x_test)

if LATENT_DIM == 2:
    draw_clusters_assignments(z_test, y_test, c_test)
else:
    tsne = TSNE(n_components=2, init='pca')
    z_tsne = tsne.fit_transform(z_test[0:2000])
    draw_clusters_assignments(z_tsne, y_test[0:2000], c_test[0:2000], alpha=0.7)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
_ = compare_reconstructed_images_MNIST(x_test, model_cvae.encoder, model_cvae.decoder, ("Original", "Pretrained", "Finetuned"), old_figure=compare_orig_vs_pretrained)

# %% [markdown]
# ## Evaluate the model

# %%
evaluate_model(model_cvae.classify, model_cvae.encode_only_mu, x_test, y_test)
# Out:
# Acc: 0.572600
# ARI: 0.377826
# AMI: 0.495910
# Sil: 0.204126

# %% [markdown]
# # Fine-tune the model (GMM)

# %% [markdown]
# ## Construct the model and load the pretrained weights

# %% [markdown]
# Load the pretrained weights for the encoder and decoder modules:

# %%
model_vae.load_weights("model_weights/cvae/pretrained/vae")

# %%
N_CLUSTERS = 10
CLUSTERING_LOSS_WEIGHT = 1

EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 1e-5
SCHEDULE = 10
DELTA_THRESHOLD = 0.001

model_cvae = get_clustering_vae_model(model_vae, N_CLUSTERS, CLUSTERING_LOSS_WEIGHT)

# %% [markdown]
# ## Initialize the parameters

# %%
z_train = model_cvae.encode_only_mu(x_train)

gmm = GaussianMixture(n_components=N_CLUSTERS, covariance_type='diag')
gmm.fit(z_train)

for weight in model_cvae.trainable_weights:
    if weight.name == "centroids:0":
        weight.assign(K.constant(gmm.means_))

# %%
p = compute_p(to_categorical(gmm.predict(z_train)))
c_last = gmm.predict(z_train)

# %% [markdown]
# Evaluate the clustering performance before fine-tunning the model:

# %%
# Show the embeddings and the cluster centroids on the latent space
if LATENT_DIM == 2:
    z_train = model_vae.encode_only_mu(x_train)
    draw_embeddings(z_train, y_train, centroids=gmm.means_)

# %%
evaluate_model(model_cvae.classify, model_cvae.encode_only_mu, x_test, y_test)
# Out:
# Acc: 0.584300
# ARI: 0.353963
# AMI: 0.462427
# Sil: 0.091265

# %% [markdown]
# ## Train the model

# %%
model_cvae.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE))

model_cvae.fit(x_train, p,
               epochs=EPOCHS,
               batch_size=BATCH_SIZE,
               callbacks = callback,
               verbose=2,
              )

model_cvae.save_weights("model_weights/cvae/finetuned/cvae_gmm")

model_cvae.load_weights("model_weights/cvae/finetuned/cvae_gmm")
# Out:
# Epoch 1/100
# 469/469 - 4s - total_loss: 37.0644 - reg_loss: 6.6302 - rec_loss: 18.9149 - clust_loss: 11.5193 - 4s/epoch - 9ms/step
# Epoch 2/100
# 469/469 - 3s - total_loss: 37.0105 - reg_loss: 6.6367 - rec_loss: 18.8729 - clust_loss: 11.5009 - 3s/epoch - 6ms/step
# Epoch 3/100
# 469/469 - 3s - total_loss: 37.0300 - reg_loss: 6.6739 - rec_loss: 18.8662 - clust_loss: 11.4898 - 3s/epoch - 6ms/step
# Epoch 4/100
# 469/469 - 3s - total_loss: 37.0069 - reg_loss: 6.6629 - rec_loss: 18.8585 - clust_loss: 11.4854 - 3s/epoch - 6ms/step
# Epoch 5/100
# 469/469 - 3s - total_loss: 36.9816 - reg_loss: 6.6674 - rec_loss: 18.8375 - clust_loss: 11.4767 - 3s/epoch - 6ms/step
# Epoch 6/100
# 469/469 - 3s - total_loss: 36.9716 - reg_loss: 6.6627 - rec_loss: 18.8361 - clust_loss: 11.4727 - 3s/epoch - 7ms/step
# Epoch 7/100
# 469/469 - 3s - total_loss: 36.9886 - reg_loss: 6.6856 - rec_loss: 18.8356 - clust_loss: 11.4675 - 3s/epoch - 6ms/step
# Epoch 8/100
# 469/469 - 3s - total_loss: 36.9862 - reg_loss: 6.6875 - rec_loss: 18.8361 - clust_loss: 11.4626 - 3s/epoch - 6ms/step
# Epoch 9/100
# 469/469 - 3s - total_loss: 36.9700 - reg_loss: 6.6919 - rec_loss: 18.8209 - clust_loss: 11.4572 - 3s/epoch - 6ms/step
# Epoch 10/100
# Delta: 0.358
# 469/469 - 3s - total_loss: 36.9478 - reg_loss: 6.6855 - rec_loss: 18.8084 - clust_loss: 11.4539 - 3s/epoch - 7ms/step
# Epoch 11/100
# 469/469 - 3s - total_loss: 36.9594 - reg_loss: 6.6963 - rec_loss: 18.8137 - clust_loss: 11.4495 - 3s/epoch - 6ms/step
# Epoch 12/100
# 469/469 - 3s - total_loss: 36.9484 - reg_loss: 6.6933 - rec_loss: 18.8102 - clust_loss: 11.4448 - 3s/epoch - 6ms/step
# Epoch 13/100
# 469/469 - 3s - total_loss: 36.9532 - reg_loss: 6.7073 - rec_loss: 18.8029 - clust_loss: 11.4429 - 3s/epoch - 7ms/step
# Epoch 14/100
# 469/469 - 3s - total_loss: 36.9642 - reg_loss: 6.7124 - rec_loss: 18.8127 - clust_loss: 11.4390 - 3s/epoch - 6ms/step
# Epoch 15/100
# 469/469 - 3s - total_loss: 36.9436 - reg_loss: 6.7153 - rec_loss: 18.7953 - clust_loss: 11.4331 - 3s/epoch - 6ms/step
# Epoch 16/100
# 469/469 - 3s - total_loss: 36.9240 - reg_loss: 6.7120 - rec_loss: 18.7864 - clust_loss: 11.4257 - 3s/epoch - 6ms/step
# Epoch 17/100
# 469/469 - 3s - total_loss: 36.9380 - reg_loss: 6.7225 - rec_loss: 18.7964 - clust_loss: 11.4191 - 3s/epoch - 6ms/step
# Epoch 18/100
# 469/469 - 3s - total_loss: 36.9171 - reg_loss: 6.7198 - rec_loss: 18.7785 - clust_loss: 11.4188 - 3s/epoch - 6ms/step
# Epoch 19/100
# 469/469 - 3s - total_loss: 36.9388 - reg_loss: 6.7312 - rec_loss: 18.7937 - clust_loss: 11.4139 - 3s/epoch - 6ms/step
# Epoch 20/100
# Delta: 0.270
# 469/469 - 3s - total_loss: 36.9148 - reg_loss: 6.7225 - rec_loss: 18.7817 - clust_loss: 11.4106 - 3s/epoch - 7ms/step
# Epoch 21/100
# 469/469 - 3s - total_loss: 36.9147 - reg_loss: 6.7308 - rec_loss: 18.7788 - clust_loss: 11.4051 - 3s/epoch - 6ms/step
# Epoch 22/100
# 469/469 - 3s - total_loss: 36.9066 - reg_loss: 6.7380 - rec_loss: 18.7664 - clust_loss: 11.4021 - 3s/epoch - 6ms/step
# Epoch 23/100
# 469/469 - 3s - total_loss: 36.9002 - reg_loss: 6.7262 - rec_loss: 18.7739 - clust_loss: 11.4001 - 3s/epoch - 6ms/step
# Epoch 24/100
# 469/469 - 3s - total_loss: 36.9041 - reg_loss: 6.7387 - rec_loss: 18.7719 - clust_loss: 11.3934 - 3s/epoch - 6ms/step
# Epoch 25/100
# 469/469 - 3s - total_loss: 36.8899 - reg_loss: 6.7352 - rec_loss: 18.7659 - clust_loss: 11.3888 - 3s/epoch - 6ms/step
# Epoch 26/100
# 469/469 - 3s - total_loss: 36.8749 - reg_loss: 6.7317 - rec_loss: 18.7589 - clust_loss: 11.3844 - 3s/epoch - 6ms/step
# Epoch 27/100
# 469/469 - 3s - total_loss: 36.8965 - reg_loss: 6.7525 - rec_loss: 18.7617 - clust_loss: 11.3823 - 3s/epoch - 6ms/step
# Epoch 28/100
# 469/469 - 3s - total_loss: 36.8755 - reg_loss: 6.7493 - rec_loss: 18.7502 - clust_loss: 11.3761 - 3s/epoch - 6ms/step
# Epoch 29/100
# 469/469 - 3s - total_loss: 36.8695 - reg_loss: 6.7414 - rec_loss: 18.7529 - clust_loss: 11.3752 - 3s/epoch - 6ms/step
# Epoch 30/100
# Delta: 0.268
# 469/469 - 3s - total_loss: 36.8654 - reg_loss: 6.7532 - rec_loss: 18.7435 - clust_loss: 11.3687 - 3s/epoch - 7ms/step
# Epoch 31/100
# 469/469 - 3s - total_loss: 36.8786 - reg_loss: 6.7684 - rec_loss: 18.7474 - clust_loss: 11.3628 - 3s/epoch - 6ms/step
# Epoch 32/100
# 469/469 - 3s - total_loss: 36.8464 - reg_loss: 6.7430 - rec_loss: 18.7433 - clust_loss: 11.3601 - 3s/epoch - 6ms/step
# Epoch 33/100
# 469/469 - 3s - total_loss: 36.8551 - reg_loss: 6.7553 - rec_loss: 18.7434 - clust_loss: 11.3564 - 3s/epoch - 6ms/step
# Epoch 34/100
# 469/469 - 3s - total_loss: 36.8360 - reg_loss: 6.7560 - rec_loss: 18.7271 - clust_loss: 11.3529 - 3s/epoch - 6ms/step
# Epoch 35/100
# 469/469 - 3s - total_loss: 36.8540 - reg_loss: 6.7704 - rec_loss: 18.7355 - clust_loss: 11.3481 - 3s/epoch - 6ms/step
# Epoch 36/100
# 469/469 - 3s - total_loss: 36.8682 - reg_loss: 6.7816 - rec_loss: 18.7396 - clust_loss: 11.3470 - 3s/epoch - 6ms/step
# Epoch 37/100
# 469/469 - 3s - total_loss: 36.8457 - reg_loss: 6.7752 - rec_loss: 18.7313 - clust_loss: 11.3391 - 3s/epoch - 6ms/step
# Epoch 38/100
# 469/469 - 3s - total_loss: 36.8412 - reg_loss: 6.7798 - rec_loss: 18.7227 - clust_loss: 11.3387 - 3s/epoch - 6ms/step
# Epoch 39/100
# 469/469 - 3s - total_loss: 36.8381 - reg_loss: 6.7820 - rec_loss: 18.7236 - clust_loss: 11.3325 - 3s/epoch - 6ms/step
# Epoch 40/100
# Delta: 0.265
# 469/469 - 3s - total_loss: 36.8309 - reg_loss: 6.7817 - rec_loss: 18.7208 - clust_loss: 11.3284 - 3s/epoch - 7ms/step
# Epoch 41/100
# 469/469 - 3s - total_loss: 36.8257 - reg_loss: 6.7813 - rec_loss: 18.7189 - clust_loss: 11.3255 - 3s/epoch - 7ms/step
# Epoch 42/100
# 469/469 - 3s - total_loss: 36.8312 - reg_loss: 6.7905 - rec_loss: 18.7167 - clust_loss: 11.3240 - 3s/epoch - 6ms/step
# Epoch 43/100
# 469/469 - 3s - total_loss: 36.8279 - reg_loss: 6.7921 - rec_loss: 18.7168 - clust_loss: 11.3190 - 3s/epoch - 6ms/step
# Epoch 44/100
# 469/469 - 3s - total_loss: 36.8013 - reg_loss: 6.7779 - rec_loss: 18.7077 - clust_loss: 11.3158 - 3s/epoch - 6ms/step
# Epoch 45/100
# 469/469 - 3s - total_loss: 36.7943 - reg_loss: 6.7813 - rec_loss: 18.7018 - clust_loss: 11.3112 - 3s/epoch - 6ms/step
# Epoch 46/100
# 469/469 - 3s - total_loss: 36.7988 - reg_loss: 6.7819 - rec_loss: 18.7109 - clust_loss: 11.3060 - 3s/epoch - 6ms/step
# Epoch 47/100
# 469/469 - 3s - total_loss: 36.7997 - reg_loss: 6.7963 - rec_loss: 18.7001 - clust_loss: 11.3033 - 3s/epoch - 6ms/step
# Epoch 48/100
# 469/469 - 3s - total_loss: 36.7945 - reg_loss: 6.7954 - rec_loss: 18.7008 - clust_loss: 11.2984 - 3s/epoch - 6ms/step
# Epoch 49/100
# 469/469 - 3s - total_loss: 36.7926 - reg_loss: 6.8062 - rec_loss: 18.6910 - clust_loss: 11.2954 - 3s/epoch - 6ms/step
# Epoch 50/100
# Delta: 0.266
# 469/469 - 4s - total_loss: 36.7900 - reg_loss: 6.8049 - rec_loss: 18.6937 - clust_loss: 11.2914 - 4s/epoch - 8ms/step
# Epoch 51/100
# 469/469 - 3s - total_loss: 36.7747 - reg_loss: 6.7992 - rec_loss: 18.6893 - clust_loss: 11.2862 - 3s/epoch - 6ms/step
# Epoch 52/100
# 469/469 - 3s - total_loss: 36.7872 - reg_loss: 6.8160 - rec_loss: 18.6863 - clust_loss: 11.2849 - 3s/epoch - 6ms/step
# Epoch 53/100
# 469/469 - 3s - total_loss: 36.7722 - reg_loss: 6.8056 - rec_loss: 18.6888 - clust_loss: 11.2778 - 3s/epoch - 7ms/step
# Epoch 54/100
# 469/469 - 3s - total_loss: 36.7785 - reg_loss: 6.8173 - rec_loss: 18.6848 - clust_loss: 11.2764 - 3s/epoch - 6ms/step
# Epoch 55/100
# 469/469 - 3s - total_loss: 36.7711 - reg_loss: 6.8070 - rec_loss: 18.6907 - clust_loss: 11.2735 - 3s/epoch - 6ms/step
# Epoch 56/100
# 469/469 - 3s - total_loss: 36.7603 - reg_loss: 6.8164 - rec_loss: 18.6773 - clust_loss: 11.2666 - 3s/epoch - 6ms/step
# Epoch 57/100
# 469/469 - 3s - total_loss: 36.7694 - reg_loss: 6.8246 - rec_loss: 18.6797 - clust_loss: 11.2652 - 3s/epoch - 6ms/step
# Epoch 58/100
# 469/469 - 3s - total_loss: 36.7546 - reg_loss: 6.8197 - rec_loss: 18.6723 - clust_loss: 11.2627 - 3s/epoch - 6ms/step
# Epoch 59/100
# 469/469 - 3s - total_loss: 36.7554 - reg_loss: 6.8218 - rec_loss: 18.6790 - clust_loss: 11.2547 - 3s/epoch - 7ms/step
# Epoch 60/100
# Delta: 0.264
# 469/469 - 3s - total_loss: 36.7618 - reg_loss: 6.8279 - rec_loss: 18.6796 - clust_loss: 11.2542 - 3s/epoch - 7ms/step
# Epoch 61/100
# 469/469 - 3s - total_loss: 36.7495 - reg_loss: 6.8278 - rec_loss: 18.6721 - clust_loss: 11.2495 - 3s/epoch - 7ms/step
# Epoch 62/100
# 469/469 - 3s - total_loss: 36.7320 - reg_loss: 6.8156 - rec_loss: 18.6695 - clust_loss: 11.2469 - 3s/epoch - 6ms/step
# Epoch 63/100
# 469/469 - 3s - total_loss: 36.7427 - reg_loss: 6.8291 - rec_loss: 18.6699 - clust_loss: 11.2437 - 3s/epoch - 6ms/step
# Epoch 64/100
# 469/469 - 3s - total_loss: 36.7408 - reg_loss: 6.8284 - rec_loss: 18.6712 - clust_loss: 11.2411 - 3s/epoch - 6ms/step
# Epoch 65/100
# 469/469 - 3s - total_loss: 36.7396 - reg_loss: 6.8437 - rec_loss: 18.6591 - clust_loss: 11.2368 - 3s/epoch - 6ms/step
# Epoch 66/100
# 469/469 - 3s - total_loss: 36.7378 - reg_loss: 6.8476 - rec_loss: 18.6551 - clust_loss: 11.2352 - 3s/epoch - 6ms/step
# Epoch 67/100
# 469/469 - 3s - total_loss: 36.7322 - reg_loss: 6.8466 - rec_loss: 18.6563 - clust_loss: 11.2293 - 3s/epoch - 6ms/step
# Epoch 68/100
# 469/469 - 3s - total_loss: 36.7281 - reg_loss: 6.8438 - rec_loss: 18.6582 - clust_loss: 11.2261 - 3s/epoch - 6ms/step
# Epoch 69/100
# 469/469 - 3s - total_loss: 36.7192 - reg_loss: 6.8386 - rec_loss: 18.6594 - clust_loss: 11.2212 - 3s/epoch - 6ms/step
# Epoch 70/100
# Delta: 0.263
# 469/469 - 3s - total_loss: 36.7159 - reg_loss: 6.8467 - rec_loss: 18.6496 - clust_loss: 11.2196 - 3s/epoch - 7ms/step
# Epoch 71/100
# 469/469 - 3s - total_loss: 36.7237 - reg_loss: 6.8599 - rec_loss: 18.6485 - clust_loss: 11.2153 - 3s/epoch - 6ms/step
# Epoch 72/100
# 469/469 - 3s - total_loss: 36.7090 - reg_loss: 6.8429 - rec_loss: 18.6536 - clust_loss: 11.2125 - 3s/epoch - 6ms/step
# Epoch 73/100
# 469/469 - 3s - total_loss: 36.6953 - reg_loss: 6.8532 - rec_loss: 18.6347 - clust_loss: 11.2074 - 3s/epoch - 6ms/step
# Epoch 74/100
# 469/469 - 3s - total_loss: 36.6998 - reg_loss: 6.8478 - rec_loss: 18.6467 - clust_loss: 11.2052 - 3s/epoch - 6ms/step
# Epoch 75/100
# 469/469 - 3s - total_loss: 36.6824 - reg_loss: 6.8375 - rec_loss: 18.6445 - clust_loss: 11.2004 - 3s/epoch - 7ms/step
# Epoch 76/100
# 469/469 - 3s - total_loss: 36.7074 - reg_loss: 6.8742 - rec_loss: 18.6381 - clust_loss: 11.1951 - 3s/epoch - 6ms/step
# Epoch 77/100
# 469/469 - 3s - total_loss: 36.6887 - reg_loss: 6.8583 - rec_loss: 18.6371 - clust_loss: 11.1933 - 3s/epoch - 6ms/step
# Epoch 78/100
# 469/469 - 3s - total_loss: 36.6889 - reg_loss: 6.8657 - rec_loss: 18.6335 - clust_loss: 11.1897 - 3s/epoch - 6ms/step
# Epoch 79/100
# 469/469 - 3s - total_loss: 36.6792 - reg_loss: 6.8651 - rec_loss: 18.6276 - clust_loss: 11.1865 - 3s/epoch - 6ms/step
# Epoch 80/100
# Delta: 0.265
# 469/469 - 3s - total_loss: 36.6852 - reg_loss: 6.8727 - rec_loss: 18.6296 - clust_loss: 11.1828 - 3s/epoch - 7ms/step
# Epoch 81/100
# 469/469 - 3s - total_loss: 36.6760 - reg_loss: 6.8719 - rec_loss: 18.6225 - clust_loss: 11.1815 - 3s/epoch - 6ms/step
# Epoch 82/100
# 469/469 - 3s - total_loss: 36.6707 - reg_loss: 6.8671 - rec_loss: 18.6296 - clust_loss: 11.1740 - 3s/epoch - 6ms/step
# Epoch 83/100
# 469/469 - 3s - total_loss: 36.6589 - reg_loss: 6.8631 - rec_loss: 18.6229 - clust_loss: 11.1729 - 3s/epoch - 6ms/step
# Epoch 84/100
# 469/469 - 3s - total_loss: 36.6579 - reg_loss: 6.8659 - rec_loss: 18.6200 - clust_loss: 11.1721 - 3s/epoch - 7ms/step
# Epoch 85/100
# 469/469 - 3s - total_loss: 36.6569 - reg_loss: 6.8678 - rec_loss: 18.6212 - clust_loss: 11.1679 - 3s/epoch - 6ms/step
# Epoch 86/100
# 469/469 - 3s - total_loss: 36.6541 - reg_loss: 6.8778 - rec_loss: 18.6136 - clust_loss: 11.1627 - 3s/epoch - 7ms/step
# Epoch 87/100
# 469/469 - 3s - total_loss: 36.6443 - reg_loss: 6.8699 - rec_loss: 18.6159 - clust_loss: 11.1585 - 3s/epoch - 6ms/step
# Epoch 88/100
# 469/469 - 3s - total_loss: 36.6448 - reg_loss: 6.8782 - rec_loss: 18.6098 - clust_loss: 11.1568 - 3s/epoch - 7ms/step
# Epoch 89/100
# 469/469 - 3s - total_loss: 36.6443 - reg_loss: 6.8757 - rec_loss: 18.6182 - clust_loss: 11.1504 - 3s/epoch - 7ms/step
# Epoch 90/100
# Delta: 0.258
# 469/469 - 3s - total_loss: 36.6579 - reg_loss: 6.9004 - rec_loss: 18.6102 - clust_loss: 11.1472 - 3s/epoch - 7ms/step
# Epoch 91/100
# 469/469 - 3s - total_loss: 36.6275 - reg_loss: 6.8755 - rec_loss: 18.6085 - clust_loss: 11.1436 - 3s/epoch - 7ms/step
# Epoch 92/100
# 469/469 - 3s - total_loss: 36.6281 - reg_loss: 6.8823 - rec_loss: 18.6039 - clust_loss: 11.1419 - 3s/epoch - 7ms/step
# Epoch 93/100
# 469/469 - 3s - total_loss: 36.6246 - reg_loss: 6.8849 - rec_loss: 18.6009 - clust_loss: 11.1388 - 3s/epoch - 7ms/step
# Epoch 94/100
# 469/469 - 3s - total_loss: 36.6344 - reg_loss: 6.8941 - rec_loss: 18.6060 - clust_loss: 11.1343 - 3s/epoch - 6ms/step
# Epoch 95/100
# 469/469 - 3s - total_loss: 36.6423 - reg_loss: 6.9026 - rec_loss: 18.6030 - clust_loss: 11.1367 - 3s/epoch - 7ms/step
# Epoch 96/100
# 469/469 - 3s - total_loss: 36.6264 - reg_loss: 6.9003 - rec_loss: 18.5944 - clust_loss: 11.1318 - 3s/epoch - 7ms/step
# Epoch 97/100
# 469/469 - 3s - total_loss: 36.6308 - reg_loss: 6.9040 - rec_loss: 18.5990 - clust_loss: 11.1278 - 3s/epoch - 6ms/step
# Epoch 98/100
# 469/469 - 3s - total_loss: 36.6279 - reg_loss: 6.9049 - rec_loss: 18.5976 - clust_loss: 11.1254 - 3s/epoch - 6ms/step
# Epoch 99/100
# 469/469 - 3s - total_loss: 36.6216 - reg_loss: 6.9040 - rec_loss: 18.5973 - clust_loss: 11.1203 - 3s/epoch - 7ms/step
# Epoch 100/100
# Delta: 0.259
# 469/469 - 4s - total_loss: 36.6220 - reg_loss: 6.9156 - rec_loss: 18.5895 - clust_loss: 11.1169 - 4s/epoch - 8ms/step

# %% [markdown]
# ## Show the resulting embeddings

# %%
z_test = model_cvae.encode_only_mu(x_test)
c_test = model_cvae.classify(x_test)

if LATENT_DIM == 2:
    draw_clusters_assignments(z_test, y_test, c_test)
else:
    tsne = TSNE(n_components=2, init='pca')
    z_tsne = tsne.fit_transform(z_test[0:2000])
    draw_clusters_assignments(z_tsne, y_test[0:2000], c_test[0:2000], alpha=0.7)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
_ = compare_reconstructed_images_MNIST(x_test, model_cvae.encoder, model_cvae.decoder, ("Original", "Pretrained", "Finetuned"), old_figure=compare_orig_vs_pretrained)

# %% [markdown]
# ## Evaluate the model

# %%
evaluate_model(model_cvae.classify, model_cvae.encode_only_mu, x_test, y_test)
# Out:
# Acc: 0.587400
# ARI: 0.342110
# AMI: 0.473455
# Sil: 0.123701
